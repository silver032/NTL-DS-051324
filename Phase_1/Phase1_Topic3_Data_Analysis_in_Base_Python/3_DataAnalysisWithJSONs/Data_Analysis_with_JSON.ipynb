# %% [markdown]
# <div style="color:white;
#            display:fill;
#            border-radius:5px;
#            background-color:#5642C5;
#            font-size:200%;
#            font-family:Arial;letter-spacing:0.5px">
#
# <p width = 20%, style="padding: 10px;
#               color:white;">
# Data Analysis with JSON Files
# </p>
# </div>
#
#
# NTL-DS-051324
# <p>Phase 1: Topic 3.3</p>
# <br>
# <br>
#
# <div align = "right">
# <img src="images/flatiron-school-logo.png" align = "right" width="200"/>
# </div>

# %%
import json
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
from collections import defaultdict

# %% [markdown]
# # Learning Objectives

# %% [markdown]
# - Load and explore a .json file in Python
# - Create a clean data structure from a .json file
# - Conduct descriptive analysis
# - Visualize the results

# %% [markdown]
# Part of being a good data scientist is having the capacity to work with data in many different forms. Much data online is stored in JSON format. So let's see if we can conduct a descriptive analysis of data when it's given to us in that form!

# %% [markdown]
# ## What is JSON?
#
# JSON stands for Java Script Object Notation.
#
#     - **plain text** format.
#     - Object structure of data encoded in hierarchical syntax.
#
# JSON objects are one common way that data is transmitted over the web.  It is notable for being lightweight, which makes it [preferred](https://stackoverflow.com/questions/383692/what-is-json-and-why-would-i-use-it), generally, over XML.

# %% [markdown]
# ```json
# {"menu": {
#   "id": 12412,
#   "istest": true,
#   "value": "File",
#   "popup": {
#     "menuitem": [
#       {"value": "New", "onclick": "CreateNewDoc()"},
#       {"value": "Open", "onclick": "OpenDoc()"},
#       {"value": "Close", "onclick": "CloseDoc()"}
#     ]
#   }
# }}
# ```

# %% [markdown]
# ## JSON Format

# %% [markdown]
# JSON objects store data in a format similar to a nested Python dictionary. The JSON format makes it easy to store as a file, transfer between users, and use in other languages.
#
# For more information about the syntax of JSON files, check out this [link](https://www.json.org/json-en.html) to the JSON website.

# %% [markdown]
# Can have these types in it (all relatable to Python types):
#
# |JavaScript|JS Example               |Python Equivalent|Python Example           |
# |----------|-------------------------|-----------------|-------------------------|
# |Objects   |`{'key0':'v12','v':1}`   |Dictionaries     |`{'key0':'v12','v':1}`   |
# |Arrays    |`[1, 'one', 'two', 3, 5]`|Lists            |`[1, 'one', 'two', 3, 5]`|
# |Strings   |`'One'` or `"Two"`       |Strings          |`'One'` or `"Two"`       |
# |Numbers   |`1234.5` or `8675309`    |Numbers          |`1234.5` or `8675309`    |
# |Boolean   |`true` or `false`        |Boolean          |`True` or `False`        |
# |Null Value|`null`                   |None Value       |`None`                   |

# %% [markdown]
# # Loading a JSON File

# %% [markdown]
# For this example, we've created a `new_releases.json` file containing data on 20 newly released music albums. We got this from the Spotify API - we'll explain what this means later.
#
# Let's begin by importing the `json` package, opening a file with python's `open()` function, and then loading that data from the JSON file into a new `data` object.

# %% [markdown]
# #### json.load()
#
# To load data from a JSON file:
# 1. `open` file with context manager.
# 2. Pass the file object to the `json.load` function.
# 3. Returns Python object representing contents of file.
#
# In the cell below, we open the campaign finance JSON file previewed above:

# %%
with open('data/new_releases.json') as f:
    data = json.load(f)

# %% [markdown]
# The Spotify API returned the data in the form of JSON object, which the `json` module transforms into a Python object.

# %% [markdown]
# ## Exploring JSON Schemas

# %% [markdown]
# Recall that JSON files have a nested structure. The deepest levels of our object will contain individual values: numbers, booleans or strings. These in turn will be stored in the equivalents of Python lists and dictionaries, usually with many levels of nesting.
#
# If you try to look at a raw JSON file, you will likely have a hard time understanding the structure. To more easily make sense of it, we will proceed through each level methodically.

# %%
## This will look messy
print(data)
# Out:
# {'albums': {'href': 'https://api.spotify.com/v1/browse/new-releases?offset=0&limit=20', 'items': [{'album_type': 'album', 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1RyvyyTE3xzB2ZywiAwp0i'}, 'href': 'https://api.spotify.com/v1/artists/1RyvyyTE3xzB2ZywiAwp0i', 'id': '1RyvyyTE3xzB2ZywiAwp0i', 'name': 'Future', 'type': 'artist', 'uri': 'spotify:artist:1RyvyyTE3xzB2ZywiAwp0i'}], 'available_markets': ['AD', 'AE', 'AR', 'AT', 'AU', 'BE', 'BG', 'BH', 'BO', 'BR', 'CA', 'CH', 'CL', 'CO', 'CR', 'CY', 'CZ', 'DE', 'DK', 'DO', 'DZ', 'EC', 'EE', 'EG', 'ES', 'FI', 'FR', 'GB', 'GR', 'GT', 'HK', 'HN', 'HU', 'ID', 'IE', 'IL', 'IN', 'IS', 'IT', 'JO', 'JP', 'KW', 'LB', 'LI', 'LT', 'LU', 'LV', 'MA', 'MC', 'MT', 'MX', 'MY', 'NI', 'NL', 'NO', 'NZ', 'OM', 'PA', 'PE', 'PH', 'PL', 'PS', 'PT', 'PY', 'QA', 'RO', 'SA', 'SE', 'SG', 'SK', 'SV', 'TH', 'TN', 'TR', 'TW', 'US', 'UY', 'VN', 'ZA'], 'external_urls': {'spotify': 'https://open.spotify.com/album/4bNPOFOzxGhF5jhfIK6lit'}, 'href': 'https://api.spotify.com/v1/albums/4bNPOFOzxGhF5jhfIK6lit', 'id': '4bNPOFOzxGhF5jhfIK6lit', 'images': [{'height': 640, 'url': 'https://i.scdn.co/image/ab67616d0000b273935d8d5369bc55e74a39303e', 'width': 640}, {'height': 300, 'url': 'https://i.scdn.co/image/ab67616d00001e02935d8d5369bc55e74a39303e', 'width': 300}, {'height': 64, 'url': 'https://i.scdn.co/image/ab67616d00004851935d8d5369bc55e74a39303e', 'width': 64}], 'name': 'High Off Life', 'release_date': '2020-05-15', 'release_date_precision': 'day', 'total_tracks': 21, 'type': 'album', 'uri': 'spotify:album:4bNPOFOzxGhF5jhfIK6lit'}, {'album_type': 'single', 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/23fqKkggKUBHNkbKtXEls4'}, 'href': 'https://api.spotify.com/v1/artists/23fqKkggKUBHNkbKtXEls4', 'id': '23fqKkggKUBHNkbKtXEls4', 'name': 'Kygo', 'type': 'artist', 'uri': 'spotify:artist:23fqKkggKUBHNkbKtXEls4'}, {'external_urls': {'spotify': 'https://open.spotify.com/artist/5Pwc4xIPtQLFEnJriah9YJ'}, 'href': 'https://api.spotify.com/v1/artists/5Pwc4xIPtQLFEnJriah9YJ', 'id': '5Pwc4xIPtQLFEnJriah9YJ', 'name': 'OneRepublic', 'type': 'artist', 'uri': 'spotify:artist:5Pwc4xIPtQLFEnJriah9YJ'}], 'available_markets': ['AD', 'AE', 'AR', 'AT', 'AU', 'BE', 'BG', 'BH', 'BO', 'BR', 'CA', 'CH', 'CL', 'CO', 'CR', 'CY', 'CZ', 'DE', 'DK', 'DO', 'DZ', 'EC', 'EE', 'EG', 'ES', 'FI', 'FR', 'GB', 'GR', 'GT', 'HK', 'HN', 'HU', 'ID', 'IE', 'IL', 'IN', 'IS', 'IT', 'JO', 'JP', 'KW', 'LB', 'LI', 'LT', 'LU', 'LV', 'MA', 'MC', 'MT', 'MX', 'MY', 'NI', 'NL', 'NO', 'NZ', 'OM', 'PA', 'PE', 'PH', 'PL', 'PS', 'PT', 'PY', 'QA', 'RO', 'SA', 'SE', 'SG', 'SK', 'SV', 'TH', 'TN', 'TR', 'TW', 'US', 'UY', 'VN', 'ZA'], 'external_urls': {'spotify': 'https://open.spotify.com/album/3LhriqAiHJYw7rxvtlkvQc'}, 'href': 'https://api.spotify.com/v1/albums/3LhriqAiHJYw7rxvtlkvQc', 'id': '3LhriqAiHJYw7rxvtlkvQc', 'images': [{'height': 640, 'url': 'https://i.scdn.co/image/ab67616d0000b273479856767f92aab97c956704', 'width': 640}, {'height': 300, 'url': 'https://i.scdn.co/image/ab67616d00001e02479856767f92aab97c956704', 'width': 300}, {'height': 64, 'url': 'https://i.scdn.co/image/ab67616d00004851479856767f92aab97c956704', 'width': 64}], 'name': 'Lose Somebody', 'release_date': '2020-05-15', 'release_date_precision': 'day', 'total_tracks': 1, 'type': 'album', 'uri': 'spotify:album:3LhriqAiHJYw7rxvtlkvQc'}, {'album_type': 'album', 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'}, 'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of', 'id': '0LyfQWJT6nXafLPZqxe9Of', 'name': 'Various Artists', 'type': 'artist', 'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}], 'available_markets': ['AD', 'AE', 'AR', 'AT', 'AU', 'BE', 'BG', 'BH', 'BO', 'BR', 'CA', 'CH', 'CL', 'CO', 'CR', 'CY', 'CZ', 'DE', 'DK', 'DO', 'DZ', 'EC', 'EE', 'EG', 'ES', 'FI', 'FR', 'GB', 'GR', 'GT', 'HK', 'HN', 'HU', 'ID', 'IE', 'IL', 'IN', 'IS', 'IT', 'JO', 'JP', 'KW', 'LB', 'LI', 'LT', 'LU', 'LV', 'MA', ...

# %%
# One way to make it easier to read
print(json.dumps(data, indent=4))
# Out:
# {
#     "albums": {
#         "href": "https://api.spotify.com/v1/browse/new-releases?offset=0&limit=20",
#         "items": [
#             {
#                 "album_type": "album",
#                 "artists": [
#                     {
#                         "external_urls": {
#                             "spotify": "https://open.spotify.com/artist/1RyvyyTE3xzB2ZywiAwp0i"
#                         },
#                         "href": "https://api.spotify.com/v1/artists/1RyvyyTE3xzB2ZywiAwp0i",
#                         "id": "1RyvyyTE3xzB2ZywiAwp0i",
#                         "name": "Future",
#                         "type": "artist",
#                         "uri": "spotify:artist:1RyvyyTE3xzB2ZywiAwp0i"
#                     }
#                 ],
#                 "available_markets": [
#                     "AD",
#                     "AE",
#                     "AR",
#                     "AT",
#                     "AU",
#                     "BE",
#                     "BG",
#                     "BH",
#                     "BO",
#                     "BR",
#                     "CA",
#                     "CH",
#                     "CL",
#                     "CO",
#                     "CR",
#                     "CY",
#                     "CZ",
#                     "DE",
#                     "DK",
#                     "DO",
#                     "DZ",
#                     "EC",
#                     "EE",
#                     "EG",
#                     "ES",
#                     "FI",
#                     "FR",
#                     "GB",
#                     "GR",
#                     "GT",
#                     "HK",
#                     "HN",
#                     "HU",
#                     "ID",
#                     "IE",
#                     "IL",
#                     "IN",
#                     "IS",
#                     "IT",
#                     "JO",
#                     "JP",
#                     "KW",
#                     "LB",
#                     "LI",
#                     "LT",
#                     "LU",
#                     "LV",
#                     "MA",
#                     "MC",
#                     "MT",
#                     "MX",
#                     "MY",
#                     "NI",
#                     "NL",
#                     "NO",
#                     "NZ",
#                     "OM",
#                     "PA",
#                     "PE",
#                     "PH",
#                     "PL",
#                     "PS",
#                     "PT",
#                     "PY",
#                     "QA",
#                     "RO",
#                     "SA",
#                     "SE",
#                     "SG",
#                     "SK",
#                     "SV",
#                     "TH",
#                     "TN",
#                     "TR",
#                     "TW",
#                     "US",
#                     "UY",
#                     "VN",
#                     "ZA"
#                 ],
#                 "external_urls": {
#                     "spotify": "https://open.spotify.com/album/4bNPOFOzxGhF5jhfIK6lit"
#                 },
#                 "href": "https://api.spotify.com/v1/albums/4bNPOFOzxGhF5jhfIK6lit",
#                 "id": "4bNPOFOzxGhF5jhfIK6lit",
#                 "images": [
#                     {
#                         "height": 640,
#                         "url": "https://i.scdn.co/image/ab67616d0000b273935d8d5369bc55e74a39303e",
#                         "width": 640
#                     },
#                     {
#                         "height": 300,
#                         "url": "https://i.scdn.co/image/ab67616d00001e02935d8d5369bc55e74a39303e",
#                         "width": 300
#                     },
#                     {
#                         "height": 64,
#                         "url": "https://i.scdn.co/image/ab67616d00004851935d8d5369bc55e74a39303e",
#                         "width": 64
#                     }
#                 ],
#                 "name": "High Off Life",
#                 "release_date": "2020-05-15",
#                 "release_date_precision": "day",
#                 "total_tracks": 21,
#                 "type": "album",
#                 "uri": "spotify:album:4bNPOFOzxGhF5jhfIK6lit"
#             },
#             {
#                 "album_type": "single",
#                 "artists": [
#                     {
#                         "external_urls": {
#                             "spotify": "https://open.spotify.com/artist/23fqKkggKUBHNkbKtXEls4"
#                         },
#                         "href": "https://api.spotify.com/v1/artists/23fqKkggKUBHNkbKtXEls4",
#                         "id": "23fqKkggKUBHNkbKtXEls4",
#                         "name": "Kygo",
#                         "type": "artist",
#                         "uri": "spotify:artist:23fqKkggKUBHNkbKtXEls4"
#                     },
#                     {
#                         "external_urls": {
#                             "spotify": "https://open.spotify.com/artist/5Pwc4xIPtQLFEnJriah9YJ"
#                         },
#                         "href": "https://api.spotify.com/v1/artists/5Pwc4xIPtQLFEnJriah9YJ",
#                         "id": "5Pwc4xIPtQLFEnJriah9YJ",
#                         "name": "OneRepublic",
#                         "type": "artist",
#                         "uri": "spotify:artist:5Pwc4xIPtQLFEnJriah9YJ"
#                     }
#                 ],
#                 "available_markets": [
#                     "AD",
#                     "AE",
#                     "AR",
#                     "AT",
#                     "AU",
#                     "BE",
#                     "BG",
#                     "BH",
#                     "BO",
#                     "BR",
#                     "CA",
#                     "CH",
#                     "CL",
#                     "CO",
#                     "CR",
#                     "CY",
#                     "CZ",
#                     "DE",
#                     "DK",
#                     "DO",
#                     "DZ",
#                     "EC",
#                     "EE",
#                     "EG",
#                     "ES",
#                     "FI",
#                     "FR",
#                     "GB",
#                     "GR",
#                     "GT",
#                     "HK",
#                     "HN",
#                     "HU",
#                     "ID",
#                     "IE",
#                     "IL",
#                     "IN",
#                     "IS",
#                     "IT",
#                     "JO",
#                     "JP",
#                     "KW",
#                     "LB",
#                     "LI",
#                     "LT",
#                     "LU",
#                     "LV",
#                     "MA",
#                     "MC",
#                     "MT",
#                     "MX",
#                     "MY",
#                     "NI",
#                     "NL",
#                     "NO",
#                     "NZ",
#                     "OM",
#                     "PA",
#                     "PE",
#                     "PH",
#                     "PL",
#                     "PS",
#                     "PT",
#                     "PY",
#                     "QA",
#                     "RO",
#                     "SA",
#                     "SE",
#                     "SG",
#                     "SK",
#                     "SV",
#                     "TH",
#                     "TN",
#                     "TR",
#                     "TW",
#                     "US",
#                     "UY",
#                     "VN",
#                     "ZA"
#                 ],
#                 "external_urls": {
#                     "spotify": "https://open.spotify.com/album/3LhriqAiHJYw7rxvtlkvQc"
#                 },
#                 "href": "https://api.spotify.com/v1/albums/3LhriqAiHJYw7rxvtlkvQc",
#                 "id": "3LhriqAiHJYw7rxvtlkvQc",
#                 "images": [
#                     {
#                         "height": 640,
#                         "url": "https://i.scdn.co/image/ab67616d0000b273479856767f92aab97c956704",
#                         "width": 640
#                     },
#                     {
#                         "height": 300,
#                         "url": "https://i.scdn.co/image/ab67616d00001e02479856767f92aab97c956704",
#                         "width": 300
#                     },
#                     {
#                         "height": 64,
#                         "url": "https://i.scdn.co/image/ab67616d00004851479856767f92aab97c956704",
#                         "width": 64
#                     }
#                 ],
#                 "name": "Lose Somebody",
#                 "release_date": "2020-05-15",
#                 "release_date_precision": "day",
#                 "total_tracks": 1,
#                 "type": "album",
#                 "uri": "spotify:album:3LhriqAiHJYw7rxvtlkvQc"
#             },
#             {
#                 "album_type": "album",
#                 "artists": [
#                     {
#                         "external_urls": {
#                             "spotify": "https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of"
#                         },
#                         "href": "https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of",
#                         "id": "0LyfQWJT6nXafLPZqxe9Of",
#                         "name": "Various Artists",
#                         "type": "artist",
#                         "uri": "spotify:artist:0LyfQWJT6nXafLPZqxe9Of"
#                     }
#                 ],
#                 "available_markets": [
#                     "AD",
#                     "AE",
#                     "AR",
#                     "AT",
#                     "AU",
#                     "BE",
#                     "BG",
#                     "BH",
#                     "BO",
#                     "BR",
#                     "CA",
#                     "CH",
#                     "CL",
#                     "CO",
#                     "CR",
#                     "CY",
#                     "CZ",
#                     "DE",
#                     "DK",
#                     "DO",
#                     "DZ",
#                     "EC",
#                     "EE",
#                     "EG",
#                     "ES",
#                     "FI",
#                     "FR",
#                     "GB",
#                     "GR",
#                     "GT",
#                     "HK",
#                     "HN",
#                     "HU",
#                     "ID",
#                     "IE",
#                     "IL",
#                     "IN",
#                     "IS",
#                     "IT",
#                     "JO",
#                     "JP",
#                     "KW",
#                     "LB",
#                     "LI",
#                     "LT",
#                     "LU",
#                     "LV",
#                     "MA",
#                     "MC",
#                     "MT",
#                     "MX",
#                     "MY",
#                     "NI",
#                     "NL",
#                     "NO",
#                     "NZ",
#                     "OM",
#                     "PA",
#                     "PE",
#                     "PH",
#                     "PL",
#                     "PS",
#                     "PT",
#                     "PY",
#                     "QA",
#                     "RO",
#                     "SA",
#                     "SE",
#                     "SG",
#                     "SK",
#                     "SV",
#                     "TH",
#                     "TN",
#                     "TR",
#                     "TW",
#                     "US",
#                     "UY",
#                     "VN",
#                     "ZA"
#                 ],
#                 "external_urls": {
#                     "spotify": "https://open.spotify.com/album/2Zg5xZo3WwIoAZys8OcUpG"
#                 },
#                 "href": "https://api.spotify.com/v1/albums/2Zg5xZo3WwIoAZys8OcUpG",
#                 "id": "2Zg5xZo3WwIoAZys8OcUpG",
#                 "images": [
#                     {
#                         "height": 640,
#                         "url": "https://i.scdn.co/image/ab67616d0000b2732e819e33b9703a8b3fc85a35",
#                         "width": 640
#                     },
#                     {
#                         "height": 300,
#                         "url": "https://i.scdn.co/image/ab67616d00001e022e819e33b9703a8b3fc85a35",
#                         "width": 300
#                     },
#                     {
#                         "height": 64,
#                         "url": "https://i.scdn.co/image/ab67616d000048512e819e33b9703a8b3fc85a35",
#                         "width": 64
#                     }
#                 ],
#                 "name": "SCOOB! The Album",
#                 "release_date": "2020-05-15",
#                 "release_date_precision": "day",
#                 "total_tracks": 12,
#                 "type": "album",
#                 "uri": "spotify:album:2Zg5xZo3WwIoAZys8OcUpG"
#             },
#             {
#                 "album_type": "single",
#                 "artists": [
#                     {
#                         "external_urls": {
#                             "spotify": "https://open.spotify.com/artist/6jJ0s89eD6GaHleKKya26X"
#                         },
#                         "href": "https://api.spotify.com/v1/artists/6jJ0s89eD6GaHleKKya26X",
#                         "id": "6jJ0s89eD6GaHleKKya26X",
#                         "name": "Katy Perry",
#                         "type": "artist",
#                         "uri": "spotify:artist:6jJ0s89eD6GaHleKKya26X"
#                     }
#                 ],
#                 "available_markets": [
#                     "AD",
#                     "AE",
#                     "AR",
#                     "AT",
#                     "AU",
#                     "BE",
#                     "BG",
#                     "BH",
#                     "BO",
#                     "BR",
#                     "CA",
#                     "CH",
#                     "CL",
#                     "CO",
#                     "CR",
#                     "CY",
#                     "CZ",
#                     "DE",
#                     "DK",
#                     "DO",
#                     "DZ",
#                     "EC",
#                     "EE",
#                     "EG",
#                     "ES",
#                     "FI",
#                     "FR",
#                     "GB",
#                     "GR",
#                     "GT",
#                     "HK",
#                     "HN",
#                     "HU",
#                     "ID",
#                     "IE",
#                     "IL",
#                     "IN",
#                     "IS",
#                     "IT",
#                     "JO",
#                     "JP",
#                     "KW",
#                     "LB",
#                     "LI",
#                     "LT",
#                     "LU",
#                     "LV",
#                     "MA",
#                     "MC",
#                     "MT",
#                     "MX",
#                     "MY",
#                     "NI",
#                     "NL",
#                     "NO",
#                     "NZ",
#                     "OM",
#                     "PA",
#                     "PE",
#                     "PH",
#                     "PL",
#                     "PS",
#                     "PT",
#                     "PY",
#                     "QA",
#                     "RO",
#                     "SA",
#                     "SE",
#                     "SG",
#                     "SK",
#                     "SV",
#                     "TH",
#                     "TN",
#                     "TR",
#                     "TW",
#                     "US",
#                     "UY",
#                     "VN",
#                     "ZA"
#                 ],
#                 "external_urls": {
#                     "spotify": "https://open.spotify.com/album/2m5J1DUH7hJpPSOromIqpN"
#                 },
#                 "href": "https://api.spotify.com/v1/albums/2m5J1DUH7hJpPSOromIqpN",
#                 "id": "2m5J1DUH7hJpPSOromIqpN",
#                 "images": [
#                     {
#                         "height": 640,
#                         "url": "https://i.scdn.co/image/ab67616d0000b2738df6751bad8ab6b5c928dba3",
#                         "width": 640
#                     },
#                     {
#                         "height": 300,
#                         "url": "https://i.scdn.co/image/ab67616d00001e028df6751bad8ab6b5c928dba3",
#                         "width": 300
#                     },
#                     {
#                         "height": 64,
#                         "url": "https://i.scdn.co/image/ab67616d000048518df6751bad8ab6b5c928dba3",
#                         "width": 64
#                     }
#                 ],
#                 "name": "Daisies",
#                 "release_date": "2020-05-15",
#                 "release_date_precision": "day",
#                 "total_tracks": 1,
#                 "type": "album",
#                 "uri": "spotify:album:2m5J1DUH7hJpPSOromIqpN"
#             },
#             {
#                 "album_type": "album",
#                 "artists": [
#                     {
#                         "external_urls": {
#                             "spotify": "https://open.spotify.com/artist/6AgTAQt8XS6jRWi4sX7w49"
#                         },
#                         "href": "https://api.spotify.com/v1/artists/6AgTAQt8XS6jRWi4sX7w49",
#                         "id": "6AgTAQt8XS6jRWi4sX7w49",
#                         "name": "Polo G",
#                         "type": "artist",
#                         "uri": "spotify:artist:6AgTAQt8XS6jRWi4sX7w49"
#                     }
#                 ],
#                 "available_markets": [
#                     "AD",
#                     "AE",
#                     "AR",
#                     "AT",
#                     "AU",
#                     "BE",
#                     "BG",
#                     "BH",
#                     "BO",
#                     "BR",
#                     "CA",
#                     "CH",
#                     "CL",
#                     "CO",
#                     "CR",
#                     "CY",
#                     "CZ",
#                     "DE",
#                     "DK",
#                     "DO",
#                     "DZ",
#                     "EC",
#                     "EE",
#                     "EG",
#                     "ES",
#                     "FI",
#                     "FR",
#                     "GB",
#                     "GR",
#                     "GT",
#                     "HK",
#                     "HN",
#                     "HU",
#                     "ID",
#                     "IE",
#                     "IL",
#                     "IN",
#                     "IS",
#                     "IT",
#                     "JO",
#                     "JP",
#                     "KW",
#                     "LB",
#                     "LI",
#                     "LT",
#                     "LU",
#                     "LV",
#                     "MA",
#                     "MC",
#                     "MT",
#                     "MX",
#                     "MY",
#                     "NI",
#                     "NL",
#                     "NO",
#                     "NZ",
#                     "OM",
#                     "PA",
#                     "PE",
#                     "PH",
#                     "PL",
#                     "PS",
#                     "PT",
#                     "PY",
#                     "QA",
#                     "RO",
#                     "SA",
#                     "SE",
#                     "SG",
#                     "SK",
#                     "SV",
#                     "TH",
#                     "TN",
#                     "TR",
#                     "TW",
#                     "US",
#                     "UY",
#                     "VN",
#                     "ZA"
#                 ],
#                 "external_urls": {
#                     "spotify": "https://open.spotify.com/album/39xhYyNNDatQtgKw2KdXMz"
#                 },
#                 "href": "https://api.spotify.com/v1/albums/39xhYyNNDatQtgKw2KdXMz",
#                 "id": "39xhYyNNDatQtgKw2KdXMz",
#                 "images": [
#                     {
#                         "height": 640,
#                         "url": "https://i.scdn.co/image/ab67616d0000b273339f780dfdbc38558ea0761d",
#                         "width": 640
#                     },
#                     {
#                         "height": 300,
#                         "url": "https://i.scdn.co/image/ab67616d00001e02339f780dfdbc38558ea0761d",
#                         "width": 300
#                     },
#                     {
#                         "height": 64,
#                         "url": "https://i.scdn.co/image/ab67616d00004851339f780dfdbc38558ea0761d",
#                         "width": 64
#                     }
#                 ],
#                 "name": "THE GOAT",
#                 "release_date": "2020-05-15",
#                 "release_date_precision": "day",
#                 "total_tracks": 16,
#                 "type": "album",
#                 "uri": "spotify:album:39xhYyNNDatQtgKw2KdXMz"
#             },
#             {
#                 "album_type": "single",
#                 "artists": [
#                     {
#                         "external_urls": {
#                             "spotify": "https://open.spotify.com/artist/7gOdHgIoIKoe4i9Tta6qdD"
#                         },
#                         "href": "https://api.spotify.com/v1/artists/7gOdHgIoIKoe4i9Tta6qdD",
#                         "id": "7gOdHgIoIKoe4i9Tta6qdD",
#                         "name": "Jonas Brothers",
#                         "type": "artist",
#                         "uri": "spotify:artist:7gOdHgIoIKoe4i9Tta6qdD"
#                     },
#                     {
#                         "external_urls": {
#                             "spotify": "https://open.spotify.com/artist/790FomKkXshlbRYZFtlgla"
#                         },
#                         "href": "https://api.spotify.com/v1/artists/790FomKkXshlbRYZFtlgla",
#                         "id": "790FomKkXshlbRYZFtlgla",
#                         "name": "KAROL G",
#                         "type": "artist",
#                         "uri": "spotify:artist:790FomKkXshlbRYZFtlgla"
#                     }
#                 ],
#                 "available_markets": [
#                     "AD",
#                     "AE",
#                     "AR",
#                     "AT",
#                     "AU",
#                     "BE",
#                     "BG",
#                     "BH",
#                     "BO",
#                     "BR",
#                     "CA",
#                     "CH",
#                     "CL",
#                     "CO",
#                     "CR",
#                     "CY",
#                     "CZ",
#                     "DE",
#                     "DK",
#                     "DO",
#                     "DZ",
#                     "EC",
#                     "EE",
#                     "EG",
#                     "ES",
#                     "FI",
#                     "FR",
#                     "GB",
#                     "GR",
#                     "GT",
#                     "HK",
#                     "HN",
#                     "HU",
#                     "ID",
#                     "IE",
#                     "IL",
#                     "IN",
#                     "IS",
#                     "IT",
#                     "JO",
#                     "JP",
#                     "KW",
#                     "LB",
#                     "LI",
#                     "LT",
#                     "LU",
#                     "LV",
#                     "MA",
#                     "MC",
#                     "MT",
#                     "MX",
#                     "MY",
#                     "NI",
#                     "NL",
#                     "NO",
#                     "NZ",
#                     "OM",
#                     "PA",
#                     "PE",
#                     "PH",
#                     "PL",
#                     "PS",
#                     "PT",
#                     "PY",
#                     "QA",
#                     "RO",
#                     "SA",
#                     "SE",
#                     "SG",
#                     "SK",
#                     "SV",
#                     "TH",
#                     "TN",
#                     "TR",
#                     "TW",
#                     "US",
#                     "UY",
#                     "VN",
#                     "ZA"
#                 ],
#                 "external_urls": {
#                     "spotify": "https://open.spotify.com/album/0i96PtPJV65ddxsfMfo45F"
#                 },
#                 "href": "https://api.spotify.com/v1/albums/0i96PtPJV65ddxsfMfo45F",
#                 "id": "0i96PtPJV65ddxsfMfo45F",
#                 "images": [
#                     {
#                         "height": 640,
#                         "url": "https://i.scdn.co/image/ab67616d0000b2733b3cd45dfa6f779c01d63fdb",
#                         "width": 640
#                     },
#                     {
#                         "height": 300,
#                         "url": "https://i.scdn.co/image/ab67616d00001e023b3cd45dfa6f779c01d63fdb",
#                         "width": 300
#                     },
#                     {
#                         "height": 64,
#                         "url": "https://i.scdn.co/image/ab67616d000048513b3cd45dfa6f779c01d63fdb",
#                         "width": 64
#                     }
#                 ],
#                 "name": "XV",
#                 "release_date": "2020-05-15",
#                 "release_date_precision": "day",
#                 "total_tracks": 2,
#                 "type": "album",
#                 "uri": "spotify:album:0i96PtPJV65ddxsfMfo45F"
#             },
#             {
#                 "album_type": "album",
#                 "artists": [
#                     {
#                         "external_urls": {
#                             "spotify": "https://open.spotify.com/artist/25uiPmTg16RbhZWAqwLBy5"
#                         },
#                         "href": "https://api.spotify.com/v1/artists/25uiPmTg16RbhZWAqwLBy5",
#                         "id": "25uiPmTg16RbhZWAqwLBy5",
#                         "name": "Charli XCX",
#                         "type": "artist",
#                         "uri": "spotify:artist:25uiPmTg16RbhZWAqwLBy5"
#                     }
#                 ],
#                 "available_markets": [
#                     "AD",
#                     "AE",
#                     "AR",
#                     "AT",
#                     "AU",
#                     "BE",
#                     "BG",
#                     "BH",
#                     "BO",
#                     "BR",
#                     "CA",
#                     "CH",
#                     "CL",
#                     "CO",
#                     "CR",
#                     "CY",
#                     "CZ",
#                     "DE",
#                     "DK",
#                     "DO",
#                     "DZ",
#                     "EC",
#                     "EE",
#                     "EG",
#                     "ES",
#                     "FI",
#                     "FR",
#                     "GB",
#                     "GR",
#                     "GT",
#                     "HK",
#                     "HN",
#                     "HU",
#                     "ID",
#                     "IE",
#                     "IL",
#                     "IN",
#                     "IS",
#                     "IT",
#                     "JO",
#                     "JP",
#                     "KW",
#                     "LB",
#                     "LI",
#                     "LT",
#                     "LU",
#                     "LV",
#                     "MA",
#                     "MC",
#                     "MT",
#                     "MX",
#                     "MY",
#                     "NI",
#                     "NL",
#                     "NO",
#                     "NZ",
#                     "OM",
#                     "PA",
#                     "PE",
#                     "PH",
#                     "PL",
#                     "PS",
#                     "PT",
#                     "PY",
#                     "QA",
#                     "RO",
#                     "SA",
#                     "SE",
#                     "SG",
#                     "SK",
#                     "SV",
#                     "TH",
#                     "TN",
#                     "TR",
#                     "TW",
#                     "US",
#                     "UY",
#                     "VN",
#                     "ZA"
#                 ],
#                 "external_urls": {
#                     "spotify": "https://open.spotify.com/album/3a9qH2VEsSiOZvMrjaS0Nu"
#                 },
#                 "href": "https://api.spotify.com/v1/albums/3a9qH2VEsSiOZvMrjaS0Nu",
#                 "id": "3a9qH2VEsSiOZvMrjaS0Nu",
#                 "images": [
#                     {
#                         "height": 640,
#                         "url": "https://i.scdn.co/image/ab67616d0000b273664e38c99d077cc52ab48914",
#                         "width": 640
#                     },
#                     {
#                         "height": 300,
#                         "url": "https://i.scdn.co/image/ab67616d00001e02664e38c99d077cc52ab48914",
#                         "width": 300
#                     },
#                     {
#                         "height": 64,
#                         "url": "https://i.scdn.co/image/ab67616d00004851664e38c99d077cc52ab48914",
#                         "width": 64
#                     }
#                 ],
#                 "name": "how i'm feeling now",
#                 "release_date": "2020-05-15",
#                 "release_date_precision": "day",
#                 "total_tracks": 11,
#                 "type": "album",
#                 "uri": "spotify:album:3a9qH2VEsSiOZvMrjaS0Nu"
#             },
#             {
#                 "album_type": "single",
#                 "artists": [
#                     {
#                         "external_urls": {
#                             "spotify": "https://open.spotify.com/artist/2jku7tDXc6XoB6MO2hFuqg"
#                         },
#                         "href": "https://api.spotify.com/v1/artists/2jku7tDXc6XoB6MO2hFuqg",
#                         "id": "2jku7tDXc6XoB6MO2hFuqg",
#                         "name": "Tory Lanez",
#                         "type": "artist",
#                         "uri": "spotify:artist:2jku7tDXc6XoB6MO2hFuqg"
#                     }
#                 ],
#                 "available_markets": [
#                     "AD",
#                     "AE",
#                     "AR",
#                     "AT",
#                     "AU",
#                     "BE",
#                     "BG",
#                     "BH",
#                     "BO",
#                     "BR",
#                     "CH",
#                     "CL",
#                     "CO",
#                     "CR",
#                     "CY",
#                     "CZ",
#                     "DE",
#                     "DK",
#                     "DO",
#                     "DZ",
#                     "EC",
#                     "EE",
#                     "EG",
#                     "ES",
#                     "FI",
#                     "FR",
#                     "GB",
#                     "GR",
#                     "GT",
#                     "HK",
#                     "HN",
#                     "HU",
#                     "ID",
#                     "IE",
#                     "IL",
#                     "IN",
#                     "IS",
#                     "IT",
#                     "JO",
#                     "JP",
#                     "KW",
#                     "LB",
#                     "LI",
#                     "LT",
#                     "LU",
#                     "LV",
#                     "MA",
#                     "MC",
#                     "MT",
#                     "MX",
#                     "MY",
#                     "NI",
#                     "NL",
#                     "NO",
#                     "NZ",
#                     "OM",
#                     "PA",
#                     "PE",
#                     "PH",
#                     "PL",
#                     "PS",
#                     "PT",
#                     "PY",
#                     "QA",
#                     "RO",
#                     "SA",
#                     "SE",
#                     "SG",
#                     "SK",
#                     "SV",
#                     "TH",
#                     "TN",
#                     "TR",
#                     "TW",
#                     "US",
#                     "UY",
#                     "VN",
#                     "ZA"
#                 ],
#                 "external_urls": {
#                     "spotify": "https://open.spotify.com/album/3lalGt6k7JM3tIji1Xbgmk"
#                 },
#                 "href": "https://api.spotify.com/v1/albums/3lalGt6k7JM3tIji1Xbgmk",
#                 "id": "3lalGt6k7JM3tIji1Xbgmk",
#                 "images": [
#                     {
#                         "height": 640,
#                         "url": "https://i.scdn.co/image/ab67616d0000b273c2ebaf0c84eb77f358d958bc",
#                         "width": 640
#                     },
#                     {
#                         "height": 300,
#                         "url": "https://i.scdn.co/image/ab67616d00001e02c2ebaf0c84eb77f358d958bc",
#                         "width": 300
#                     },
#                     {
#                         "height": 64,
#                         "url": "https://i.scdn.co/image/ab67616d00004851c2ebaf0c84eb77f358d958bc",
#                         "width": 64
#                     }
#                 ],
#                 "name": "Temperature Rising",
#                 "release_date": "2020-05-15",
#                 "release_date_precision": "day",
#                 "total_tracks": 1,
#                 "type": "album",
#                 "uri": "spotify:album:3lalGt6k7JM3tIji1Xbgmk"
#             },
#             {
#                 "album_type": "album",
#                 "artists": [
#                     {
#                         "external_urls": {
#                             "spotify": "https://open.spotify.com/artist/2ueoLVCXQ948OfhVvAy3Nn"
#                         },
#                         "href": "https://api.spotify.com/v1/artists/2ueoLVCXQ948OfhVvAy3Nn",
#                         "id": "2ueoLVCXQ948OfhVvAy3Nn",
#                         "name": "Perfume Genius",
#                         "type": "artist",
#                         "uri": "spotify:artist:2ueoLVCXQ948OfhVvAy3Nn"
#                     }
#                 ],
#                 "available_markets": [
#                     "AD",
#                     "AE",
#                     "AR",
#                     "AT",
#                     "AU",
#                     "BE",
#                     "BG",
#                     "BH",
#                     "BO",
#                     "BR",
#                     "CA",
#                     "CH",
#                     "CL",
#                     "CO",
#                     "CR",
#                     "CY",
#                     "CZ",
#                     "DE",
#                     "DK",
#                     "DO",
#                     "DZ",
#                     "EC",
#                     "EE",
#                     "EG",
#                     "ES",
#                     "FI",
#                     "FR",
#                     "GB",
#                     "GR",
#                     "GT",
#                     "HK",
#                     "HN",
#                     "HU",
#                     "ID",
#                     "IE",
#                     "IL",
#                     "IN",
#                     "IS",
#                     "IT",
#                     "JO",
#                     "JP",
#                     "KW",
#                     "LB",
#                     "LI",
#                     "LT",
#                     "LU",
#                     "LV",
#                     "MA",
#                     "MC",
#                     "MT",
#                     "MX",
#                     "MY",
#                     "NI",
#                     "NL",
#                     "NO",
#                     "NZ",
#                     "OM",
#                     "PA",
#                     "PE",
#                     "PH",
#                     "PL",
#                     "PS",
#                     "PT",
#                     "PY",
#                     "QA",
#                     "RO",
#                     "SA",
#                     "SE",
#                     "SG",
#                     "SK",
#                     "SV",
#                     "TH",
#                     "TN",
#                     "TR",
#                     "TW",
#                     "US",
#                     "UY",
#                     "VN",
#                     "ZA"
#                 ],
#                 "external_urls": {
#                     "spotify": "https://open.spotify.com/album/6daEdTBi1hyFQgmsnR7oRr"
#                 },
#                 "href": "https://api.spotify.com/v1/albums/6daEdTBi1hyFQgmsnR7oRr",
#                 "id": "6daEdTBi1hyFQgmsnR7oRr",
#                 "images": [
#                     {
#                         "height": 640,
#                         "url": "https://i.scdn.co/image/ab67616d0000b2739af34850f5125ef195d6101a",
#                         "width": 640
#                     },
#                     {
#                         "height": 300,
#                         "url": "https://i.scdn.co/image/ab67616d00001e029af34850f5125ef195d6101a",
#                         "width": 300
#                     },
#                     {
#                         "height": 64,
#                         "url": "https://i.scdn.co/image/ab67616d000048519af34850f5125ef195d6101a",
#                         "width": 64
#                     }
#                 ],
#                 "name": "Set My Heart On Fire Immediately",
#                 "release_date": "2020-05-15",
#                 "release_date_precision": "day",
#                 "total_tracks": 13,
#                 "type": "album",
#                 "uri": "spotify:album:6daEdTBi1hyFQgmsnR7oRr"
#             },
#             {
#                 "album_type": "album",
#                 "artists": [
#                     {
#                         "external_urls": {
#                             "spotify": "https://open.spotify.com/artist/7rkW85dBwwrJtlHRDkJDAC"
#                         },
#                         "href": "https://api.spotify.com/v1/artists/7rkW85dBwwrJtlHRDkJDAC",
#                         "id": "7rkW85dBwwrJtlHRDkJDAC",
#                         "name": "NAV",
#                         "type": "artist",
#                         "uri": "spotify:artist:7rkW85dBwwrJtlHRDkJDAC"
#                     }
#                 ],
#                 "available_markets": [
#                     "AD",
#                     "AE",
#                     "AR",
#                     "AT",
#                     "AU",
#                     "BE",
#                     "BG",
#                     "BH",
#                     "BO",
#                     "BR",
#                     "CA",
#                     "CH",
#                     "CL",
#                     "CO",
#                     "CR",
#                     "CY",
#                     "CZ",
#                     "DE",
#                     "DK",
#                     "DO",
#                     "DZ",
#                     "EC",
#                     "EE",
#                     "EG",
#                     "ES",
#                     "FI",
#                     "FR",
#                     "GB",
#                     "GR",
#                     "GT",
#                     "HK",
#                     "HN",
#                     "HU",
#                     "ID",
#                     "IE",
#                     "IL",
#                     "IN",
#                     "IS",
#                     "IT",
#                     "JO",
#                     "JP",
#                     "KW",
#                     "LB",
#                     "LI",
#                     "LT",
#                     "LU",
#                     "LV",
#                     "MA",
#                     "MC",
#                     "MT",
#                     "MX",
#                     "MY",
#                     "NI",
#                     "NL",
#                     "NO",
#                     "NZ",
#                     "OM",
#                     "PA",
#                     "PE",
#                     "PH",
#                     "PL",
#                     "PS",
#                     "PT",
#                     "PY",
#                     "QA",
#                     "RO",
#                     "SA",
#                     "SE",
#                     "SG",
#                     "SK",
#                     "SV",
#                     "TH",
#                     "TN",
#                     "TR",
#                     "TW",
#                     "US",
#                     "UY",
#                     "VN",
#                     "ZA"
#                 ],
#                 "external_urls": {
#                     "spotify": "https://open.spotify.com/album/2kx4l1OQNT2JXLld9HJDIh"
#                 },
#                 "href": "https://api.spotify.com/v1/albums/2kx4l1OQNT2JXLld9HJDIh",
#                 "id": "2kx4l1OQNT2JXLld9HJDIh",
#                 "images": [
#                     {
#                         "height": 640,
#                         "url": "https://i.scdn.co/image/ab67616d0000b273b9c89bb14d58ea3150bd435d",
#                         "width": 640
#                     },
#                     {
#                         "height": 300,
#                         "url": "https://i.scdn.co/image/ab67616d00001e02b9c89bb14d58ea3150bd435d",
#                         "width": 300
#                     },
#                     {
#                         "height": 64,
#                         "url": "https://i.scdn.co/image/ab67616d00004851b9c89bb14d58ea3150bd435d",
#                         "width": 64
#                     }
#                 ],
#                 "name": "Good Intentions (Brown Boy 2 Deluxe Version)",
#                 "release_date": "2020-05-11",
#                 "release_date_precision": "day",
#                 "total_tracks": 32,
#                 "type": "album",
#                 "uri": "spotify:album:2kx4l1OQNT2JXLld9HJDIh"
#             },
#             {
#                 "album_type": "single",
#                 "artists": [
#                     {
#                         "external_urls": {
#                             "spotify": "https://open.spotify.com/artist/6oMuImdp5ZcFhWP0ESe6mG"
#                         },
#                         "href": "https://api.spotify.com/v1/artists/6oMuImdp5ZcFhWP0ESe6mG",
#                         "id": "6oMuImdp5ZcFhWP0ESe6mG",
#                         "name": "Migos",
#                         "type": "artist",
#                         "uri": "spotify:artist:6oMuImdp5ZcFhWP0ESe6mG"
#                     }
#                 ],
#                 "available_markets": [
#                     "AD",
#                     "AE",
#                     "AR",
#                     "AT",
#                     "AU",
#                     "BE",
#                     "BG",
#                     "BH",
#                     "BO",
#                     "BR",
#                     "CA",
#                     "CH",
#                     "CL",
#                     "CO",
#                     "CR",
#                     "CY",
#                     "CZ",
#                     "DE",
#                     "DK",
#                     "DO",
#                     "DZ",
#                     "EC",
#                     "EE",
#                     "EG",
#                     "ES",
#                     "FI",
#                     "FR",
#                     "GB",
#                     "GR",
#                     "GT",
#                     "HK",
#                     "HN",
#                     "HU",
#                     "ID",
#                     "IE",
#                     "IL",
#                     "IN",
#                     "IS",
#                     "IT",
#                     "JO",
#                     "JP",
#                     "KW",
#                     "LB",
#                     "LI",
#                     "LT",
#                     "LU",
#                     "LV",
#                     "MA",
#                     "MC",
#                     "MT",
#                     "MX",
#                     "MY",
#                     "NI",
#                     "NL",
#                     "NO",
#                     "NZ",
#                     "OM",
#                     "PA",
#                     "PE",
#                     "PH",
#                     "PL",
#                     "PS",
#                     "PT",
#                     "PY",
#                     "QA",
#                     "RO",
#                     "SA",
#                     "SE",
#                     "SG",
#                     "SK",
#                     "SV",
#                     "TH",
#                     "TN",
#                     "TR",
#                     "TW",
#                     "US",
#                     "UY",
#                     "VN",
#                     "ZA"
#                 ],
#                 "external_urls": {
#                     "spotify": "https://open.spotify.com/album/3PASWLvNfvfMF68dDznEgK"
#                 },
#                 "href": "https://api.spotify.com/v1/albums/3PASWLvNfvfMF68dDznEgK",
#                 "id": "3PASWLvNfvfMF68dDznEgK",
#                 "images": [
#                     {
#                         "height": 640,
#                         "url": "https://i.scdn.co/image/ab67616d0000b2739325c863d9139cc2d507421b",
#                         "width": 640
#                     },
#                     {
#                         "height": 300,
#                         "url": "https://i.scdn.co/image/ab67616d00001e029325c863d9139cc2d507421b",
#                         "width": 300
#                     },
#                     {
#                         "height": 64,
#                         "url": "https://i.scdn.co/image/ab67616d000048519325c863d9139cc2d507421b",
#                         "width": 64
#                     }
#                 ],
#                 "name": "Racks 2 Skinny",
#                 "release_date": "2020-05-11",
#                 "release_date_precision": "day",
#                 "total_tracks": 1,
#                 "type": "album",
#                 "uri": "spotify:album:3PASWLvNfvfMF68dDznEgK"
#             },
#             {
#                 "album_type": "single",
#                 "artists": [
#                     {
#                         "external_urls": {
#                             "spotify": "https://open.spotify.com/artist/5Zq7R5qmi58ByYyBQTlNuk"
#                         },
#                         "href": "https://api.spotify.com/v1/artists/5Zq7R5qmi58ByYyBQTlNuk",
#                         "id": "5Zq7R5qmi58ByYyBQTlNuk",
#                         "name": "Lee Brice",
#                         "type": "artist",
#                         "uri": "spotify:artist:5Zq7R5qmi58ByYyBQTlNuk"
#                     }
#                 ],
#                 "available_markets": [
#                     "AD",
#                     "AE",
#                     "AR",
#                     "AT",
#                     "AU",
#                     "BE",
#                     "BG",
#                     "BH",
#                     "BO",
#                     "BR",
#                     "CA",
#                     "CH",
#                     "CL",
#                     "CO",
#                     "CR",
#                     "CY",
#                     "CZ",
#                     "DE",
#                     "DK",
#                     "DO",
#                     "DZ",
#                     "EC",
#                     "EE",
#                     "EG",
#                     "ES",
#                     "FI",
#                     "FR",
#                     "GB",
#                     "GR",
#                     "GT",
#                     "HK",
#                     "HN",
#                     "HU",
#                     "ID",
#                     "IE",
#                     "IL",
#                     "IN",
#                     "IS",
#                     "IT",
#                     "JO",
#                     "JP",
#                     "KW",
#                     "LB",
#                     "LI",
#                     "LT",
#                     "LU",
#                     "LV",
#                     "MA",
#                     "MC",
#                     "MT",
#                     "MX",
#                     "MY",
#                     "NI",
#                     "NL",
#                     "NO",
#                     "NZ",
#                     "OM",
#                     "PA",
#                     "PE",
#                     "PH",
#                     "PL",
#                     "PS",
#                     "PT",
#                     "PY",
#                     "QA",
#                     "RO",
#                     "SA",
#                     "SE",
#                     "SG",
#                     "SK",
#                     "SV",
#                     "TH",
#                     "TN",
#                     "TR",
#                     "TW",
#                     "US",
#                     "UY",
#                     "VN",
#                     "ZA"
#                 ],
#                 "external_urls": {
#                     "spotify": "https://open.spotify.com/album/5LK5cCx0XdniivfZ91vOSv"
#                 },
#                 "href": "https://api.spotify.com/v1/albums/5LK5cCx0XdniivfZ91vOSv",
# ...
#                     "PT",
#                     "PY",
#                     "QA",
#                     "RO",
#                     "SA",
#                     "SE",
#                     "SG",
#                     "SK",
#                     "SV",
#                     "TH",
#                     "TN",
#                     "TR",
#                     "TW",
#                     "US",
#                     "UY",
#                     "VN",
#                     "ZA"
#                 ],
#                 "external_urls": {
#                     "spotify": "https://open.spotify.com/album/5Gn3fFzlWL89j0hGumtXb5"
#                 },
#                 "href": "https://api.spotify.com/v1/albums/5Gn3fFzlWL89j0hGumtXb5",
#                 "id": "5Gn3fFzlWL89j0hGumtXb5",
#                 "images": [
#                     {
#                         "height": 640,
#                         "url": "https://i.scdn.co/image/ab67616d0000b2737f66b73bd6e86f4c8d2a7692",
#                         "width": 640
#                     },
#                     {
#                         "height": 300,
#                         "url": "https://i.scdn.co/image/ab67616d00001e027f66b73bd6e86f4c8d2a7692",
#                         "width": 300
#                     },
#                     {
#                         "height": 64,
#                         "url": "https://i.scdn.co/image/ab67616d000048517f66b73bd6e86f4c8d2a7692",
#                         "width": 64
#                     }
#                 ],
#                 "name": "THE END OF EVERYTHING",
#                 "release_date": "2020-05-15",
#                 "release_date_precision": "day",
#                 "total_tracks": 8,
#                 "type": "album",
#                 "uri": "spotify:album:5Gn3fFzlWL89j0hGumtXb5"
#             },
#             {
#                 "album_type": "single",
#                 "artists": [
#                     {
#                         "external_urls": {
#                             "spotify": "https://open.spotify.com/artist/6C1ohJrd5VydigQtaGy5Wa"
#                         },
#                         "href": "https://api.spotify.com/v1/artists/6C1ohJrd5VydigQtaGy5Wa",
#                         "id": "6C1ohJrd5VydigQtaGy5Wa",
#                         "name": "Joyner Lucas",
#                         "type": "artist",
#                         "uri": "spotify:artist:6C1ohJrd5VydigQtaGy5Wa"
#                     },
#                     {
#                         "external_urls": {
#                             "spotify": "https://open.spotify.com/artist/41qil2VaGbD194gaEcmmyx"
#                         },
#                         "href": "https://api.spotify.com/v1/artists/41qil2VaGbD194gaEcmmyx",
#                         "id": "41qil2VaGbD194gaEcmmyx",
#                         "name": "Will Smith",
#                         "type": "artist",
#                         "uri": "spotify:artist:41qil2VaGbD194gaEcmmyx"
#                     }
#                 ],
#                 "available_markets": [
#                     "AD",
#                     "AE",
#                     "AR",
#                     "AT",
#                     "AU",
#                     "BE",
#                     "BG",
#                     "BH",
#                     "BO",
#                     "BR",
#                     "CA",
#                     "CH",
#                     "CL",
#                     "CO",
#                     "CR",
#                     "CY",
#                     "CZ",
#                     "DE",
#                     "DK",
#                     "DO",
#                     "DZ",
#                     "EC",
#                     "EE",
#                     "EG",
#                     "ES",
#                     "FI",
#                     "FR",
#                     "GB",
#                     "GR",
#                     "GT",
#                     "HK",
#                     "HN",
#                     "HU",
#                     "ID",
#                     "IE",
#                     "IL",
#                     "IN",
#                     "IS",
#                     "IT",
#                     "JO",
#                     "JP",
#                     "KW",
#                     "LB",
#                     "LI",
#                     "LT",
#                     "LU",
#                     "LV",
#                     "MA",
#                     "MC",
#                     "MT",
#                     "MX",
#                     "MY",
#                     "NI",
#                     "NL",
#                     "NO",
#                     "NZ",
#                     "OM",
#                     "PA",
#                     "PE",
#                     "PH",
#                     "PL",
#                     "PS",
#                     "PT",
#                     "PY",
#                     "QA",
#                     "RO",
#                     "SA",
#                     "SE",
#                     "SG",
#                     "SK",
#                     "SV",
#                     "TH",
#                     "TN",
#                     "TR",
#                     "TW",
#                     "US",
#                     "UY",
#                     "VN",
#                     "ZA"
#                 ],
#                 "external_urls": {
#                     "spotify": "https://open.spotify.com/album/3tOe6XM8LmRA5vDAaMqp8e"
#                 },
#                 "href": "https://api.spotify.com/v1/albums/3tOe6XM8LmRA5vDAaMqp8e",
#                 "id": "3tOe6XM8LmRA5vDAaMqp8e",
#                 "images": [
#                     {
#                         "height": 640,
#                         "url": "https://i.scdn.co/image/ab67616d0000b2734ac196312c24faedb76a345e",
#                         "width": 640
#                     },
#                     {
#                         "height": 300,
#                         "url": "https://i.scdn.co/image/ab67616d00001e024ac196312c24faedb76a345e",
#                         "width": 300
#                     },
#                     {
#                         "height": 64,
#                         "url": "https://i.scdn.co/image/ab67616d000048514ac196312c24faedb76a345e",
#                         "width": 64
#                     }
#                 ],
#                 "name": "Will (Remix)",
#                 "release_date": "2020-05-15",
#                 "release_date_precision": "day",
#                 "total_tracks": 1,
#                 "type": "album",
#                 "uri": "spotify:album:3tOe6XM8LmRA5vDAaMqp8e"
#             },
#             {
#                 "album_type": "single",
#                 "artists": [
#                     {
#                         "external_urls": {
#                             "spotify": "https://open.spotify.com/artist/6Xgp2XMz1fhVYe7i6yNAax"
#                         },
#                         "href": "https://api.spotify.com/v1/artists/6Xgp2XMz1fhVYe7i6yNAax",
#                         "id": "6Xgp2XMz1fhVYe7i6yNAax",
#                         "name": "Trippie Redd",
#                         "type": "artist",
#                         "uri": "spotify:artist:6Xgp2XMz1fhVYe7i6yNAax"
#                     },
#                     {
#                         "external_urls": {
#                             "spotify": "https://open.spotify.com/artist/2HPaUgqeutzr3jx5a9WyDV"
#                         },
#                         "href": "https://api.spotify.com/v1/artists/2HPaUgqeutzr3jx5a9WyDV",
#                         "id": "2HPaUgqeutzr3jx5a9WyDV",
#                         "name": "PARTYNEXTDOOR",
#                         "type": "artist",
#                         "uri": "spotify:artist:2HPaUgqeutzr3jx5a9WyDV"
#                     }
#                 ],
#                 "available_markets": [
#                     "AD",
#                     "AE",
#                     "AR",
#                     "AT",
#                     "AU",
#                     "BE",
#                     "BG",
#                     "BH",
#                     "BO",
#                     "BR",
#                     "CA",
#                     "CH",
#                     "CL",
#                     "CO",
#                     "CR",
#                     "CY",
#                     "CZ",
#                     "DE",
#                     "DK",
#                     "DO",
#                     "DZ",
#                     "EC",
#                     "EE",
#                     "EG",
#                     "ES",
#                     "FI",
#                     "FR",
#                     "GB",
#                     "GR",
#                     "GT",
#                     "HK",
#                     "HN",
#                     "HU",
#                     "ID",
#                     "IE",
#                     "IL",
#                     "IN",
#                     "IS",
#                     "IT",
#                     "JO",
#                     "JP",
#                     "KW",
#                     "LB",
#                     "LI",
#                     "LT",
#                     "LU",
#                     "LV",
#                     "MA",
#                     "MC",
#                     "MT",
#                     "MX",
#                     "MY",
#                     "NI",
#                     "NL",
#                     "NO",
#                     "NZ",
#                     "OM",
#                     "PA",
#                     "PE",
#                     "PH",
#                     "PL",
#                     "PS",
#                     "PT",
#                     "PY",
#                     "QA",
#                     "RO",
#                     "SA",
#                     "SE",
#                     "SG",
#                     "SK",
#                     "SV",
#                     "TH",
#                     "TN",
#                     "TR",
#                     "TW",
#                     "US",
#                     "UY",
#                     "VN",
#                     "ZA"
#                 ],
#                 "external_urls": {
#                     "spotify": "https://open.spotify.com/album/7rcMHNqNbQxF5TaPMHFoKu"
#                 },
#                 "href": "https://api.spotify.com/v1/albums/7rcMHNqNbQxF5TaPMHFoKu",
#                 "id": "7rcMHNqNbQxF5TaPMHFoKu",
#                 "images": [
#                     {
#                         "height": 640,
#                         "url": "https://i.scdn.co/image/ab67616d0000b273de32a6662a7db272328f4761",
#                         "width": 640
#                     },
#                     {
#                         "height": 300,
#                         "url": "https://i.scdn.co/image/ab67616d00001e02de32a6662a7db272328f4761",
#                         "width": 300
#                     },
#                     {
#                         "height": 64,
#                         "url": "https://i.scdn.co/image/ab67616d00004851de32a6662a7db272328f4761",
#                         "width": 64
#                     }
#                 ],
#                 "name": "Excitement",
#                 "release_date": "2020-05-15",
#                 "release_date_precision": "day",
#                 "total_tracks": 1,
#                 "type": "album",
#                 "uri": "spotify:album:7rcMHNqNbQxF5TaPMHFoKu"
#             },
#             {
#                 "album_type": "single",
#                 "artists": [
#                     {
#                         "external_urls": {
#                             "spotify": "https://open.spotify.com/artist/3NPpFNZtSTHheNBaWC82rB"
#                         },
#                         "href": "https://api.spotify.com/v1/artists/3NPpFNZtSTHheNBaWC82rB",
#                         "id": "3NPpFNZtSTHheNBaWC82rB",
#                         "name": "X Ambassadors",
#                         "type": "artist",
#                         "uri": "spotify:artist:3NPpFNZtSTHheNBaWC82rB"
#                     },
#                     {
#                         "external_urls": {
#                             "spotify": "https://open.spotify.com/artist/0pCNk4D3E2xtszsm6hMsWr"
#                         },
#                         "href": "https://api.spotify.com/v1/artists/0pCNk4D3E2xtszsm6hMsWr",
#                         "id": "0pCNk4D3E2xtszsm6hMsWr",
#                         "name": "K.Flay",
#                         "type": "artist",
#                         "uri": "spotify:artist:0pCNk4D3E2xtszsm6hMsWr"
#                     },
#                     {
#                         "external_urls": {
#                             "spotify": "https://open.spotify.com/artist/4ZgQDCtRqZlhLswVS6MHN4"
#                         },
#                         "href": "https://api.spotify.com/v1/artists/4ZgQDCtRqZlhLswVS6MHN4",
#                         "id": "4ZgQDCtRqZlhLswVS6MHN4",
#                         "name": "grandson",
#                         "type": "artist",
#                         "uri": "spotify:artist:4ZgQDCtRqZlhLswVS6MHN4"
#                     }
#                 ],
#                 "available_markets": [
#                     "AD",
#                     "AE",
#                     "AR",
#                     "AT",
#                     "AU",
#                     "BE",
#                     "BG",
#                     "BH",
#                     "BO",
#                     "BR",
#                     "CA",
#                     "CH",
#                     "CL",
#                     "CO",
#                     "CR",
#                     "CY",
#                     "CZ",
#                     "DE",
#                     "DK",
#                     "DO",
#                     "DZ",
#                     "EC",
#                     "EE",
#                     "EG",
#                     "ES",
#                     "FI",
#                     "FR",
#                     "GB",
#                     "GR",
#                     "GT",
#                     "HK",
#                     "HN",
#                     "HU",
#                     "ID",
#                     "IE",
#                     "IL",
#                     "IN",
#                     "IS",
#                     "IT",
#                     "JO",
#                     "JP",
#                     "KW",
#                     "LB",
#                     "LI",
#                     "LT",
#                     "LU",
#                     "LV",
#                     "MA",
#                     "MC",
#                     "MT",
#                     "MX",
#                     "MY",
#                     "NI",
#                     "NL",
#                     "NO",
#                     "NZ",
#                     "OM",
#                     "PA",
#                     "PE",
#                     "PH",
#                     "PL",
#                     "PS",
#                     "PT",
#                     "PY",
#                     "QA",
#                     "RO",
#                     "SA",
#                     "SE",
#                     "SG",
#                     "SK",
#                     "SV",
#                     "TH",
#                     "TN",
#                     "TR",
#                     "TW",
#                     "US",
#                     "UY",
#                     "VN",
#                     "ZA"
#                 ],
#                 "external_urls": {
#                     "spotify": "https://open.spotify.com/album/2JQbWWpYG6kKppiD6z2FwL"
#                 },
#                 "href": "https://api.spotify.com/v1/albums/2JQbWWpYG6kKppiD6z2FwL",
#                 "id": "2JQbWWpYG6kKppiD6z2FwL",
#                 "images": [
#                     {
#                         "height": 640,
#                         "url": "https://i.scdn.co/image/ab67616d0000b273e420fab8e9ec9cf79c073a28",
#                         "width": 640
#                     },
#                     {
#                         "height": 300,
#                         "url": "https://i.scdn.co/image/ab67616d00001e02e420fab8e9ec9cf79c073a28",
#                         "width": 300
#                     },
#                     {
#                         "height": 64,
#                         "url": "https://i.scdn.co/image/ab67616d00004851e420fab8e9ec9cf79c073a28",
#                         "width": 64
#                     }
#                 ],
#                 "name": "Zen (with K.Flay & grandson)",
#                 "release_date": "2020-05-15",
#                 "release_date_precision": "day",
#                 "total_tracks": 1,
#                 "type": "album",
#                 "uri": "spotify:album:2JQbWWpYG6kKppiD6z2FwL"
#             }
#         ],
#         "limit": 20,
#         "next": "https://api.spotify.com/v1/browse/new-releases?offset=20&limit=20",
#         "offset": 0,
#         "previous": null,
#         "total": 100
#     }
# }

# %%
# Using the default Jupyter Notebook's display() helps
display(data) # Uncomment this to do the same as just displaying the last line
# Out:
# {'albums': {'href': 'https://api.spotify.com/v1/browse/new-releases?offset=0&limit=20',
#   'items': [{'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1RyvyyTE3xzB2ZywiAwp0i'},
#       'href': 'https://api.spotify.com/v1/artists/1RyvyyTE3xzB2ZywiAwp0i',
#       'id': '1RyvyyTE3xzB2ZywiAwp0i',
#       'name': 'Future',
#       'type': 'artist',
#       'uri': 'spotify:artist:1RyvyyTE3xzB2ZywiAwp0i'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/4bNPOFOzxGhF5jhfIK6lit'},
#     'href': 'https://api.spotify.com/v1/albums/4bNPOFOzxGhF5jhfIK6lit',
#     'id': '4bNPOFOzxGhF5jhfIK6lit',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273935d8d5369bc55e74a39303e',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02935d8d5369bc55e74a39303e',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851935d8d5369bc55e74a39303e',
#       'width': 64}],
#     'name': 'High Off Life',
#     'release_date': '2020-05-15',
#     'release_date_precision': 'day',
#     'total_tracks': 21,
#     'type': 'album',
#     'uri': 'spotify:album:4bNPOFOzxGhF5jhfIK6lit'},
#    {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/23fqKkggKUBHNkbKtXEls4'},
#       'href': 'https://api.spotify.com/v1/artists/23fqKkggKUBHNkbKtXEls4',
#       'id': '23fqKkggKUBHNkbKtXEls4',
#       'name': 'Kygo',
#       'type': 'artist',
#       'uri': 'spotify:artist:23fqKkggKUBHNkbKtXEls4'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/5Pwc4xIPtQLFEnJriah9YJ'},
#       'href': 'https://api.spotify.com/v1/artists/5Pwc4xIPtQLFEnJriah9YJ',
#       'id': '5Pwc4xIPtQLFEnJriah9YJ',
#       'name': 'OneRepublic',
#       'type': 'artist',
#       'uri': 'spotify:artist:5Pwc4xIPtQLFEnJriah9YJ'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/3LhriqAiHJYw7rxvtlkvQc'},
#     'href': 'https://api.spotify.com/v1/albums/3LhriqAiHJYw7rxvtlkvQc',
#     'id': '3LhriqAiHJYw7rxvtlkvQc',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273479856767f92aab97c956704',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02479856767f92aab97c956704',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851479856767f92aab97c956704',
#       'width': 64}],
#     'name': 'Lose Somebody',
#     'release_date': '2020-05-15',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:3LhriqAiHJYw7rxvtlkvQc'},
#    {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#       'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#       'id': '0LyfQWJT6nXafLPZqxe9Of',
#       'name': 'Various Artists',
#       'type': 'artist',
#       'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/2Zg5xZo3WwIoAZys8OcUpG'},
#     'href': 'https://api.spotify.com/v1/albums/2Zg5xZo3WwIoAZys8OcUpG',
#     'id': '2Zg5xZo3WwIoAZys8OcUpG',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2732e819e33b9703a8b3fc85a35',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e022e819e33b9703a8b3fc85a35',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048512e819e33b9703a8b3fc85a35',
#       'width': 64}],
#     'name': 'SCOOB! The Album',
#     'release_date': '2020-05-15',
#     'release_date_precision': 'day',
#     'total_tracks': 12,
#     'type': 'album',
#     'uri': 'spotify:album:2Zg5xZo3WwIoAZys8OcUpG'},
#    {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6jJ0s89eD6GaHleKKya26X'},
#       'href': 'https://api.spotify.com/v1/artists/6jJ0s89eD6GaHleKKya26X',
#       'id': '6jJ0s89eD6GaHleKKya26X',
#       'name': 'Katy Perry',
#       'type': 'artist',
#       'uri': 'spotify:artist:6jJ0s89eD6GaHleKKya26X'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/2m5J1DUH7hJpPSOromIqpN'},
#     'href': 'https://api.spotify.com/v1/albums/2m5J1DUH7hJpPSOromIqpN',
#     'id': '2m5J1DUH7hJpPSOromIqpN',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2738df6751bad8ab6b5c928dba3',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e028df6751bad8ab6b5c928dba3',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048518df6751bad8ab6b5c928dba3',
#       'width': 64}],
#     'name': 'Daisies',
#     'release_date': '2020-05-15',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:2m5J1DUH7hJpPSOromIqpN'},
#    {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6AgTAQt8XS6jRWi4sX7w49'},
#       'href': 'https://api.spotify.com/v1/artists/6AgTAQt8XS6jRWi4sX7w49',
#       'id': '6AgTAQt8XS6jRWi4sX7w49',
#       'name': 'Polo G',
#       'type': 'artist',
#       'uri': 'spotify:artist:6AgTAQt8XS6jRWi4sX7w49'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/39xhYyNNDatQtgKw2KdXMz'},
#     'href': 'https://api.spotify.com/v1/albums/39xhYyNNDatQtgKw2KdXMz',
#     'id': '39xhYyNNDatQtgKw2KdXMz',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273339f780dfdbc38558ea0761d',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02339f780dfdbc38558ea0761d',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851339f780dfdbc38558ea0761d',
#       'width': 64}],
#     'name': 'THE GOAT',
#     'release_date': '2020-05-15',
#     'release_date_precision': 'day',
#     'total_tracks': 16,
#     'type': 'album',
#     'uri': 'spotify:album:39xhYyNNDatQtgKw2KdXMz'},
#    {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7gOdHgIoIKoe4i9Tta6qdD'},
#       'href': 'https://api.spotify.com/v1/artists/7gOdHgIoIKoe4i9Tta6qdD',
#       'id': '7gOdHgIoIKoe4i9Tta6qdD',
#       'name': 'Jonas Brothers',
#       'type': 'artist',
#       'uri': 'spotify:artist:7gOdHgIoIKoe4i9Tta6qdD'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/790FomKkXshlbRYZFtlgla'},
#       'href': 'https://api.spotify.com/v1/artists/790FomKkXshlbRYZFtlgla',
#       'id': '790FomKkXshlbRYZFtlgla',
#       'name': 'KAROL G',
#       'type': 'artist',
#       'uri': 'spotify:artist:790FomKkXshlbRYZFtlgla'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/0i96PtPJV65ddxsfMfo45F'},
#     'href': 'https://api.spotify.com/v1/albums/0i96PtPJV65ddxsfMfo45F',
#     'id': '0i96PtPJV65ddxsfMfo45F',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2733b3cd45dfa6f779c01d63fdb',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e023b3cd45dfa6f779c01d63fdb',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048513b3cd45dfa6f779c01d63fdb',
#       'width': 64}],
#     'name': 'XV',
#     'release_date': '2020-05-15',
#     'release_date_precision': 'day',
#     'total_tracks': 2,
#     'type': 'album',
#     'uri': 'spotify:album:0i96PtPJV65ddxsfMfo45F'},
#    {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/25uiPmTg16RbhZWAqwLBy5'},
#       'href': 'https://api.spotify.com/v1/artists/25uiPmTg16RbhZWAqwLBy5',
#       'id': '25uiPmTg16RbhZWAqwLBy5',
#       'name': 'Charli XCX',
#       'type': 'artist',
#       'uri': 'spotify:artist:25uiPmTg16RbhZWAqwLBy5'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/3a9qH2VEsSiOZvMrjaS0Nu'},
#     'href': 'https://api.spotify.com/v1/albums/3a9qH2VEsSiOZvMrjaS0Nu',
#     'id': '3a9qH2VEsSiOZvMrjaS0Nu',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273664e38c99d077cc52ab48914',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02664e38c99d077cc52ab48914',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851664e38c99d077cc52ab48914',
#       'width': 64}],
#     'name': "how i'm feeling now",
#     'release_date': '2020-05-15',
#     'release_date_precision': 'day',
#     'total_tracks': 11,
#     'type': 'album',
#     'uri': 'spotify:album:3a9qH2VEsSiOZvMrjaS0Nu'},
#    {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2jku7tDXc6XoB6MO2hFuqg'},
#       'href': 'https://api.spotify.com/v1/artists/2jku7tDXc6XoB6MO2hFuqg',
#       'id': '2jku7tDXc6XoB6MO2hFuqg',
#       'name': 'Tory Lanez',
#       'type': 'artist',
#       'uri': 'spotify:artist:2jku7tDXc6XoB6MO2hFuqg'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/3lalGt6k7JM3tIji1Xbgmk'},
#     'href': 'https://api.spotify.com/v1/albums/3lalGt6k7JM3tIji1Xbgmk',
#     'id': '3lalGt6k7JM3tIji1Xbgmk',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273c2ebaf0c84eb77f358d958bc',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02c2ebaf0c84eb77f358d958bc',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851c2ebaf0c84eb77f358d958bc',
#       'width': 64}],
#     'name': 'Temperature Rising',
#     'release_date': '2020-05-15',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:3lalGt6k7JM3tIji1Xbgmk'},
#    {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2ueoLVCXQ948OfhVvAy3Nn'},
#       'href': 'https://api.spotify.com/v1/artists/2ueoLVCXQ948OfhVvAy3Nn',
#       'id': '2ueoLVCXQ948OfhVvAy3Nn',
#       'name': 'Perfume Genius',
#       'type': 'artist',
#       'uri': 'spotify:artist:2ueoLVCXQ948OfhVvAy3Nn'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/6daEdTBi1hyFQgmsnR7oRr'},
#     'href': 'https://api.spotify.com/v1/albums/6daEdTBi1hyFQgmsnR7oRr',
#     'id': '6daEdTBi1hyFQgmsnR7oRr',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2739af34850f5125ef195d6101a',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e029af34850f5125ef195d6101a',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048519af34850f5125ef195d6101a',
#       'width': 64}],
#     'name': 'Set My Heart On Fire Immediately',
#     'release_date': '2020-05-15',
#     'release_date_precision': 'day',
#     'total_tracks': 13,
#     'type': 'album',
#     'uri': 'spotify:album:6daEdTBi1hyFQgmsnR7oRr'},
#    {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7rkW85dBwwrJtlHRDkJDAC'},
#       'href': 'https://api.spotify.com/v1/artists/7rkW85dBwwrJtlHRDkJDAC',
#       'id': '7rkW85dBwwrJtlHRDkJDAC',
#       'name': 'NAV',
#       'type': 'artist',
#       'uri': 'spotify:artist:7rkW85dBwwrJtlHRDkJDAC'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/2kx4l1OQNT2JXLld9HJDIh'},
#     'href': 'https://api.spotify.com/v1/albums/2kx4l1OQNT2JXLld9HJDIh',
#     'id': '2kx4l1OQNT2JXLld9HJDIh',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273b9c89bb14d58ea3150bd435d',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02b9c89bb14d58ea3150bd435d',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851b9c89bb14d58ea3150bd435d',
#       'width': 64}],
#     'name': 'Good Intentions (Brown Boy 2 Deluxe Version)',
#     'release_date': '2020-05-11',
#     'release_date_precision': 'day',
#     'total_tracks': 32,
#     'type': 'album',
#     'uri': 'spotify:album:2kx4l1OQNT2JXLld9HJDIh'},
#    {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6oMuImdp5ZcFhWP0ESe6mG'},
#       'href': 'https://api.spotify.com/v1/artists/6oMuImdp5ZcFhWP0ESe6mG',
#       'id': '6oMuImdp5ZcFhWP0ESe6mG',
#       'name': 'Migos',
#       'type': 'artist',
#       'uri': 'spotify:artist:6oMuImdp5ZcFhWP0ESe6mG'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/3PASWLvNfvfMF68dDznEgK'},
#     'href': 'https://api.spotify.com/v1/albums/3PASWLvNfvfMF68dDznEgK',
#     'id': '3PASWLvNfvfMF68dDznEgK',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2739325c863d9139cc2d507421b',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e029325c863d9139cc2d507421b',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048519325c863d9139cc2d507421b',
#       'width': 64}],
#     'name': 'Racks 2 Skinny',
#     'release_date': '2020-05-11',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:3PASWLvNfvfMF68dDznEgK'},
#    {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5Zq7R5qmi58ByYyBQTlNuk'},
#       'href': 'https://api.spotify.com/v1/artists/5Zq7R5qmi58ByYyBQTlNuk',
#       'id': '5Zq7R5qmi58ByYyBQTlNuk',
#       'name': 'Lee Brice',
#       'type': 'artist',
#       'uri': 'spotify:artist:5Zq7R5qmi58ByYyBQTlNuk'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/5LK5cCx0XdniivfZ91vOSv'},
#     'href': 'https://api.spotify.com/v1/albums/5LK5cCx0XdniivfZ91vOSv',
#     'id': '5LK5cCx0XdniivfZ91vOSv',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b27306ae99421702f8a9d881e268',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e0206ae99421702f8a9d881e268',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d0000485106ae99421702f8a9d881e268',
#       'width': 64}],
#     'name': 'One Of Them Girls',
#     'release_date': '2020-05-15',
#     'release_date_precision': 'day',
#     'total_tracks': 2,
#     'type': 'album',
#     'uri': 'spotify:album:5LK5cCx0XdniivfZ91vOSv'},
#    {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2o5jDhtHVPhrJdv3cEQ99Z'},
#       'href': 'https://api.spotify.com/v1/artists/2o5jDhtHVPhrJdv3cEQ99Z',
#       'id': '2o5jDhtHVPhrJdv3cEQ99Z',
#       'name': 'Tiësto',
#       'type': 'artist',
#       'uri': 'spotify:artist:2o5jDhtHVPhrJdv3cEQ99Z'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/6CIslPQSknp875cigkhKJC'},
#     'href': 'https://api.spotify.com/v1/albums/6CIslPQSknp875cigkhKJC',
#     'id': '6CIslPQSknp875cigkhKJC',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2739759d6dfa2c19091814fccb3',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e029759d6dfa2c19091814fccb3',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048519759d6dfa2c19091814fccb3',
#       'width': 64}],
#     'name': 'The London Sessions',
#     'release_date': '2020-05-15',
#     'release_date_precision': 'day',
#     'total_tracks': 13,
#     'type': 'album',
#     'uri': 'spotify:album:6CIslPQSknp875cigkhKJC'},
#    {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6pBNfggcZZDCmb0p92OnGn'},
#       'href': 'https://api.spotify.com/v1/artists/6pBNfggcZZDCmb0p92OnGn',
#       'id': '6pBNfggcZZDCmb0p92OnGn',
#       'name': 'Chase Rice',
#       'type': 'artist',
#       'uri': 'spotify:artist:6pBNfggcZZDCmb0p92OnGn'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/5XvXf3mdhShyLZhoJYR74q'},
#     'href': 'https://api.spotify.com/v1/albums/5XvXf3mdhShyLZhoJYR74q',
#     'id': '5XvXf3mdhShyLZhoJYR74q',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2735f6b892b478747a769252650',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e025f6b892b478747a769252650',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048515f6b892b478747a769252650',
#       'width': 64}],
#     'name': 'The Album, Pt. II',
#     'release_date': '2020-05-15',
#     'release_date_precision': 'day',
#     'total_tracks': 4,
#     'type': 'album',
#     'uri': 'spotify:album:5XvXf3mdhShyLZhoJYR74q'},
#    {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1caBfBEapzw8z2Qz9q0OaQ'},
#       'href': 'https://api.spotify.com/v1/artists/1caBfBEapzw8z2Qz9q0OaQ',
#       'id': '1caBfBEapzw8z2Qz9q0OaQ',
#       'name': 'Asking Alexandria',
#       'type': 'artist',
#       'uri': 'spotify:artist:1caBfBEapzw8z2Qz9q0OaQ'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/5VKKXDvYuJmRc2UQHCwNQK'},
#     'href': 'https://api.spotify.com/v1/albums/5VKKXDvYuJmRc2UQHCwNQK',
#     'id': '5VKKXDvYuJmRc2UQHCwNQK',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273d30ebbcdf987ab5273abdd8d',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02d30ebbcdf987ab5273abdd8d',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851d30ebbcdf987ab5273abdd8d',
#       'width': 64}],
#     'name': 'Like A House On Fire',
#     'release_date': '2020-05-15',
#     'release_date_precision': 'day',
#     'total_tracks': 15,
#     'type': 'album',
#     'uri': 'spotify:album:5VKKXDvYuJmRc2UQHCwNQK'},
#    {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7d3WFRME3vBY2cgoP38RDo'},
#       'href': 'https://api.spotify.com/v1/artists/7d3WFRME3vBY2cgoP38RDo',
#       'id': '7d3WFRME3vBY2cgoP38RDo',
#       'name': 'Lil Skies',
#       'type': 'artist',
#       'uri': 'spotify:artist:7d3WFRME3vBY2cgoP38RDo'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/3cVy1WTjSAVpzUc7MVCTLu'},
#     'href': 'https://api.spotify.com/v1/albums/3cVy1WTjSAVpzUc7MVCTLu',
#     'id': '3cVy1WTjSAVpzUc7MVCTLu',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273f7571dc32332081426ab3818',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02f7571dc32332081426ab3818',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851f7571dc32332081426ab3818',
#       'width': 64}],
#     'name': 'Riot',
#     'release_date': '2020-05-13',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:3cVy1WTjSAVpzUc7MVCTLu'},
#    {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/55fhWPvDiMpLnE4ZzNXZyW'},
#       'href': 'https://api.spotify.com/v1/artists/55fhWPvDiMpLnE4ZzNXZyW',
#       'id': '55fhWPvDiMpLnE4ZzNXZyW',
#       'name': 'Noah Cyrus',
#       'type': 'artist',
#       'uri': 'spotify:artist:55fhWPvDiMpLnE4ZzNXZyW'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/5Gn3fFzlWL89j0hGumtXb5'},
#     'href': 'https://api.spotify.com/v1/albums/5Gn3fFzlWL89j0hGumtXb5',
#     'id': '5Gn3fFzlWL89j0hGumtXb5',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2737f66b73bd6e86f4c8d2a7692',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e027f66b73bd6e86f4c8d2a7692',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048517f66b73bd6e86f4c8d2a7692',
#       'width': 64}],
#     'name': 'THE END OF EVERYTHING',
#     'release_date': '2020-05-15',
#     'release_date_precision': 'day',
#     'total_tracks': 8,
#     'type': 'album',
#     'uri': 'spotify:album:5Gn3fFzlWL89j0hGumtXb5'},
#    {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6C1ohJrd5VydigQtaGy5Wa'},
#       'href': 'https://api.spotify.com/v1/artists/6C1ohJrd5VydigQtaGy5Wa',
#       'id': '6C1ohJrd5VydigQtaGy5Wa',
#       'name': 'Joyner Lucas',
#       'type': 'artist',
#       'uri': 'spotify:artist:6C1ohJrd5VydigQtaGy5Wa'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/41qil2VaGbD194gaEcmmyx'},
#       'href': 'https://api.spotify.com/v1/artists/41qil2VaGbD194gaEcmmyx',
#       'id': '41qil2VaGbD194gaEcmmyx',
#       'name': 'Will Smith',
#       'type': 'artist',
#       'uri': 'spotify:artist:41qil2VaGbD194gaEcmmyx'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/3tOe6XM8LmRA5vDAaMqp8e'},
#     'href': 'https://api.spotify.com/v1/albums/3tOe6XM8LmRA5vDAaMqp8e',
#     'id': '3tOe6XM8LmRA5vDAaMqp8e',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2734ac196312c24faedb76a345e',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e024ac196312c24faedb76a345e',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048514ac196312c24faedb76a345e',
#       'width': 64}],
#     'name': 'Will (Remix)',
#     'release_date': '2020-05-15',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:3tOe6XM8LmRA5vDAaMqp8e'},
#    {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6Xgp2XMz1fhVYe7i6yNAax'},
#       'href': 'https://api.spotify.com/v1/artists/6Xgp2XMz1fhVYe7i6yNAax',
#       'id': '6Xgp2XMz1fhVYe7i6yNAax',
#       'name': 'Trippie Redd',
#       'type': 'artist',
#       'uri': 'spotify:artist:6Xgp2XMz1fhVYe7i6yNAax'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/2HPaUgqeutzr3jx5a9WyDV'},
#       'href': 'https://api.spotify.com/v1/artists/2HPaUgqeutzr3jx5a9WyDV',
#       'id': '2HPaUgqeutzr3jx5a9WyDV',
#       'name': 'PARTYNEXTDOOR',
#       'type': 'artist',
#       'uri': 'spotify:artist:2HPaUgqeutzr3jx5a9WyDV'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/7rcMHNqNbQxF5TaPMHFoKu'},
#     'href': 'https://api.spotify.com/v1/albums/7rcMHNqNbQxF5TaPMHFoKu',
#     'id': '7rcMHNqNbQxF5TaPMHFoKu',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273de32a6662a7db272328f4761',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02de32a6662a7db272328f4761',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851de32a6662a7db272328f4761',
#       'width': 64}],
#     'name': 'Excitement',
#     'release_date': '2020-05-15',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:7rcMHNqNbQxF5TaPMHFoKu'},
#    {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3NPpFNZtSTHheNBaWC82rB'},
#       'href': 'https://api.spotify.com/v1/artists/3NPpFNZtSTHheNBaWC82rB',
#       'id': '3NPpFNZtSTHheNBaWC82rB',
#       'name': 'X Ambassadors',
#       'type': 'artist',
#       'uri': 'spotify:artist:3NPpFNZtSTHheNBaWC82rB'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/0pCNk4D3E2xtszsm6hMsWr'},
#       'href': 'https://api.spotify.com/v1/artists/0pCNk4D3E2xtszsm6hMsWr',
#       'id': '0pCNk4D3E2xtszsm6hMsWr',
#       'name': 'K.Flay',
#       'type': 'artist',
#       'uri': 'spotify:artist:0pCNk4D3E2xtszsm6hMsWr'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/4ZgQDCtRqZlhLswVS6MHN4'},
#       'href': 'https://api.spotify.com/v1/artists/4ZgQDCtRqZlhLswVS6MHN4',
#       'id': '4ZgQDCtRqZlhLswVS6MHN4',
#       'name': 'grandson',
#       'type': 'artist',
#       'uri': 'spotify:artist:4ZgQDCtRqZlhLswVS6MHN4'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/2JQbWWpYG6kKppiD6z2FwL'},
#     'href': 'https://api.spotify.com/v1/albums/2JQbWWpYG6kKppiD6z2FwL',
#     'id': '2JQbWWpYG6kKppiD6z2FwL',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273e420fab8e9ec9cf79c073a28',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02e420fab8e9ec9cf79c073a28',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851e420fab8e9ec9cf79c073a28',
#       'width': 64}],
#     'name': 'Zen (with K.Flay & grandson)',
#     'release_date': '2020-05-15',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:2JQbWWpYG6kKppiD6z2FwL'}],
#   'limit': 20,
#   'next': 'https://api.spotify.com/v1/browse/new-releases?offset=20&limit=20',
#   'offset': 0,
#   'previous': None,
#   'total': 100}}

# %% [markdown]
# To start exploring, let's check the type of our new `data` object and start mapping out the hierarchy.

# %%
type(data)
# Out:
# dict

# %%
data.keys()
# Out:
# dict_keys(['albums'])

# %% [markdown]
# In this case, there is only a single key, 'albums', so we'll continue on down the pathway exploring and mapping out the hierarchy. Once again, let's start by checking the type of this nested data structure.

# %%
type(data['albums'])
# Out:
# dict

# %%
data['albums'].keys()
# Out:
# dict_keys(['href', 'items', 'limit', 'next', 'offset', 'previous', 'total'])

# %% [markdown]
# At this point, things are starting to look something like this:
#
# ![](images/json_diagram1.jpg)
#
# If we were to continue checking individual data types, we'd have a lot to go through. To simplify this, let's use a `for` loop:

# %%
for key, value in data['albums'].items():
    print(key, type(value))
# Out:
# href <class 'str'>
# items <class 'list'>
# limit <class 'int'>
# next <class 'str'>
# offset <class 'int'>
# previous <class 'NoneType'>
# total <class 'int'>

# %% [markdown]
# Adding this to our diagram, we now have something like this:
#
# ![](images/json_diagram2.jpg)
#
# Let's look at the `items` list - this contains the album information.

# %%
type(data['albums']['items'])
# Out:
# list

# %%
data['albums']#['items'][0]#['artists'][0]
# Out:
# {'href': 'https://api.spotify.com/v1/browse/new-releases?offset=0&limit=20',
#  'items': [{'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1RyvyyTE3xzB2ZywiAwp0i'},
#      'href': 'https://api.spotify.com/v1/artists/1RyvyyTE3xzB2ZywiAwp0i',
#      'id': '1RyvyyTE3xzB2ZywiAwp0i',
#      'name': 'Future',
#      'type': 'artist',
#      'uri': 'spotify:artist:1RyvyyTE3xzB2ZywiAwp0i'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/4bNPOFOzxGhF5jhfIK6lit'},
#    'href': 'https://api.spotify.com/v1/albums/4bNPOFOzxGhF5jhfIK6lit',
#    'id': '4bNPOFOzxGhF5jhfIK6lit',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273935d8d5369bc55e74a39303e',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02935d8d5369bc55e74a39303e',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d00004851935d8d5369bc55e74a39303e',
#      'width': 64}],
#    'name': 'High Off Life',
#    'release_date': '2020-05-15',
#    'release_date_precision': 'day',
#    'total_tracks': 21,
#    'type': 'album',
#    'uri': 'spotify:album:4bNPOFOzxGhF5jhfIK6lit'},
#   {'album_type': 'single',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/23fqKkggKUBHNkbKtXEls4'},
#      'href': 'https://api.spotify.com/v1/artists/23fqKkggKUBHNkbKtXEls4',
#      'id': '23fqKkggKUBHNkbKtXEls4',
#      'name': 'Kygo',
#      'type': 'artist',
#      'uri': 'spotify:artist:23fqKkggKUBHNkbKtXEls4'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/5Pwc4xIPtQLFEnJriah9YJ'},
#      'href': 'https://api.spotify.com/v1/artists/5Pwc4xIPtQLFEnJriah9YJ',
#      'id': '5Pwc4xIPtQLFEnJriah9YJ',
#      'name': 'OneRepublic',
#      'type': 'artist',
#      'uri': 'spotify:artist:5Pwc4xIPtQLFEnJriah9YJ'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/3LhriqAiHJYw7rxvtlkvQc'},
#    'href': 'https://api.spotify.com/v1/albums/3LhriqAiHJYw7rxvtlkvQc',
#    'id': '3LhriqAiHJYw7rxvtlkvQc',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273479856767f92aab97c956704',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02479856767f92aab97c956704',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d00004851479856767f92aab97c956704',
#      'width': 64}],
#    'name': 'Lose Somebody',
#    'release_date': '2020-05-15',
#    'release_date_precision': 'day',
#    'total_tracks': 1,
#    'type': 'album',
#    'uri': 'spotify:album:3LhriqAiHJYw7rxvtlkvQc'},
#   {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#      'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#      'id': '0LyfQWJT6nXafLPZqxe9Of',
#      'name': 'Various Artists',
#      'type': 'artist',
#      'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/2Zg5xZo3WwIoAZys8OcUpG'},
#    'href': 'https://api.spotify.com/v1/albums/2Zg5xZo3WwIoAZys8OcUpG',
#    'id': '2Zg5xZo3WwIoAZys8OcUpG',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b2732e819e33b9703a8b3fc85a35',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e022e819e33b9703a8b3fc85a35',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d000048512e819e33b9703a8b3fc85a35',
#      'width': 64}],
#    'name': 'SCOOB! The Album',
#    'release_date': '2020-05-15',
#    'release_date_precision': 'day',
#    'total_tracks': 12,
#    'type': 'album',
#    'uri': 'spotify:album:2Zg5xZo3WwIoAZys8OcUpG'},
#   {'album_type': 'single',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6jJ0s89eD6GaHleKKya26X'},
#      'href': 'https://api.spotify.com/v1/artists/6jJ0s89eD6GaHleKKya26X',
#      'id': '6jJ0s89eD6GaHleKKya26X',
#      'name': 'Katy Perry',
#      'type': 'artist',
#      'uri': 'spotify:artist:6jJ0s89eD6GaHleKKya26X'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/2m5J1DUH7hJpPSOromIqpN'},
#    'href': 'https://api.spotify.com/v1/albums/2m5J1DUH7hJpPSOromIqpN',
#    'id': '2m5J1DUH7hJpPSOromIqpN',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b2738df6751bad8ab6b5c928dba3',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e028df6751bad8ab6b5c928dba3',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d000048518df6751bad8ab6b5c928dba3',
#      'width': 64}],
#    'name': 'Daisies',
#    'release_date': '2020-05-15',
#    'release_date_precision': 'day',
#    'total_tracks': 1,
#    'type': 'album',
#    'uri': 'spotify:album:2m5J1DUH7hJpPSOromIqpN'},
#   {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6AgTAQt8XS6jRWi4sX7w49'},
#      'href': 'https://api.spotify.com/v1/artists/6AgTAQt8XS6jRWi4sX7w49',
#      'id': '6AgTAQt8XS6jRWi4sX7w49',
#      'name': 'Polo G',
#      'type': 'artist',
#      'uri': 'spotify:artist:6AgTAQt8XS6jRWi4sX7w49'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/39xhYyNNDatQtgKw2KdXMz'},
#    'href': 'https://api.spotify.com/v1/albums/39xhYyNNDatQtgKw2KdXMz',
#    'id': '39xhYyNNDatQtgKw2KdXMz',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273339f780dfdbc38558ea0761d',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02339f780dfdbc38558ea0761d',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d00004851339f780dfdbc38558ea0761d',
#      'width': 64}],
#    'name': 'THE GOAT',
#    'release_date': '2020-05-15',
#    'release_date_precision': 'day',
#    'total_tracks': 16,
#    'type': 'album',
#    'uri': 'spotify:album:39xhYyNNDatQtgKw2KdXMz'},
#   {'album_type': 'single',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7gOdHgIoIKoe4i9Tta6qdD'},
#      'href': 'https://api.spotify.com/v1/artists/7gOdHgIoIKoe4i9Tta6qdD',
#      'id': '7gOdHgIoIKoe4i9Tta6qdD',
#      'name': 'Jonas Brothers',
#      'type': 'artist',
#      'uri': 'spotify:artist:7gOdHgIoIKoe4i9Tta6qdD'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/790FomKkXshlbRYZFtlgla'},
#      'href': 'https://api.spotify.com/v1/artists/790FomKkXshlbRYZFtlgla',
#      'id': '790FomKkXshlbRYZFtlgla',
#      'name': 'KAROL G',
#      'type': 'artist',
#      'uri': 'spotify:artist:790FomKkXshlbRYZFtlgla'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/0i96PtPJV65ddxsfMfo45F'},
#    'href': 'https://api.spotify.com/v1/albums/0i96PtPJV65ddxsfMfo45F',
#    'id': '0i96PtPJV65ddxsfMfo45F',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b2733b3cd45dfa6f779c01d63fdb',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e023b3cd45dfa6f779c01d63fdb',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d000048513b3cd45dfa6f779c01d63fdb',
#      'width': 64}],
#    'name': 'XV',
#    'release_date': '2020-05-15',
#    'release_date_precision': 'day',
#    'total_tracks': 2,
#    'type': 'album',
#    'uri': 'spotify:album:0i96PtPJV65ddxsfMfo45F'},
#   {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/25uiPmTg16RbhZWAqwLBy5'},
#      'href': 'https://api.spotify.com/v1/artists/25uiPmTg16RbhZWAqwLBy5',
#      'id': '25uiPmTg16RbhZWAqwLBy5',
#      'name': 'Charli XCX',
#      'type': 'artist',
#      'uri': 'spotify:artist:25uiPmTg16RbhZWAqwLBy5'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/3a9qH2VEsSiOZvMrjaS0Nu'},
#    'href': 'https://api.spotify.com/v1/albums/3a9qH2VEsSiOZvMrjaS0Nu',
#    'id': '3a9qH2VEsSiOZvMrjaS0Nu',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273664e38c99d077cc52ab48914',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02664e38c99d077cc52ab48914',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d00004851664e38c99d077cc52ab48914',
#      'width': 64}],
#    'name': "how i'm feeling now",
#    'release_date': '2020-05-15',
#    'release_date_precision': 'day',
#    'total_tracks': 11,
#    'type': 'album',
#    'uri': 'spotify:album:3a9qH2VEsSiOZvMrjaS0Nu'},
#   {'album_type': 'single',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2jku7tDXc6XoB6MO2hFuqg'},
#      'href': 'https://api.spotify.com/v1/artists/2jku7tDXc6XoB6MO2hFuqg',
#      'id': '2jku7tDXc6XoB6MO2hFuqg',
#      'name': 'Tory Lanez',
#      'type': 'artist',
#      'uri': 'spotify:artist:2jku7tDXc6XoB6MO2hFuqg'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/3lalGt6k7JM3tIji1Xbgmk'},
#    'href': 'https://api.spotify.com/v1/albums/3lalGt6k7JM3tIji1Xbgmk',
#    'id': '3lalGt6k7JM3tIji1Xbgmk',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273c2ebaf0c84eb77f358d958bc',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02c2ebaf0c84eb77f358d958bc',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d00004851c2ebaf0c84eb77f358d958bc',
#      'width': 64}],
#    'name': 'Temperature Rising',
#    'release_date': '2020-05-15',
#    'release_date_precision': 'day',
#    'total_tracks': 1,
#    'type': 'album',
#    'uri': 'spotify:album:3lalGt6k7JM3tIji1Xbgmk'},
#   {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2ueoLVCXQ948OfhVvAy3Nn'},
#      'href': 'https://api.spotify.com/v1/artists/2ueoLVCXQ948OfhVvAy3Nn',
#      'id': '2ueoLVCXQ948OfhVvAy3Nn',
#      'name': 'Perfume Genius',
#      'type': 'artist',
#      'uri': 'spotify:artist:2ueoLVCXQ948OfhVvAy3Nn'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/6daEdTBi1hyFQgmsnR7oRr'},
#    'href': 'https://api.spotify.com/v1/albums/6daEdTBi1hyFQgmsnR7oRr',
#    'id': '6daEdTBi1hyFQgmsnR7oRr',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b2739af34850f5125ef195d6101a',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e029af34850f5125ef195d6101a',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d000048519af34850f5125ef195d6101a',
#      'width': 64}],
#    'name': 'Set My Heart On Fire Immediately',
#    'release_date': '2020-05-15',
#    'release_date_precision': 'day',
#    'total_tracks': 13,
#    'type': 'album',
#    'uri': 'spotify:album:6daEdTBi1hyFQgmsnR7oRr'},
#   {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7rkW85dBwwrJtlHRDkJDAC'},
#      'href': 'https://api.spotify.com/v1/artists/7rkW85dBwwrJtlHRDkJDAC',
#      'id': '7rkW85dBwwrJtlHRDkJDAC',
#      'name': 'NAV',
#      'type': 'artist',
#      'uri': 'spotify:artist:7rkW85dBwwrJtlHRDkJDAC'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/2kx4l1OQNT2JXLld9HJDIh'},
#    'href': 'https://api.spotify.com/v1/albums/2kx4l1OQNT2JXLld9HJDIh',
#    'id': '2kx4l1OQNT2JXLld9HJDIh',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273b9c89bb14d58ea3150bd435d',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02b9c89bb14d58ea3150bd435d',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d00004851b9c89bb14d58ea3150bd435d',
#      'width': 64}],
#    'name': 'Good Intentions (Brown Boy 2 Deluxe Version)',
#    'release_date': '2020-05-11',
#    'release_date_precision': 'day',
#    'total_tracks': 32,
#    'type': 'album',
#    'uri': 'spotify:album:2kx4l1OQNT2JXLld9HJDIh'},
#   {'album_type': 'single',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6oMuImdp5ZcFhWP0ESe6mG'},
#      'href': 'https://api.spotify.com/v1/artists/6oMuImdp5ZcFhWP0ESe6mG',
#      'id': '6oMuImdp5ZcFhWP0ESe6mG',
#      'name': 'Migos',
#      'type': 'artist',
#      'uri': 'spotify:artist:6oMuImdp5ZcFhWP0ESe6mG'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/3PASWLvNfvfMF68dDznEgK'},
#    'href': 'https://api.spotify.com/v1/albums/3PASWLvNfvfMF68dDznEgK',
#    'id': '3PASWLvNfvfMF68dDznEgK',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b2739325c863d9139cc2d507421b',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e029325c863d9139cc2d507421b',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d000048519325c863d9139cc2d507421b',
#      'width': 64}],
#    'name': 'Racks 2 Skinny',
#    'release_date': '2020-05-11',
#    'release_date_precision': 'day',
#    'total_tracks': 1,
#    'type': 'album',
#    'uri': 'spotify:album:3PASWLvNfvfMF68dDznEgK'},
#   {'album_type': 'single',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5Zq7R5qmi58ByYyBQTlNuk'},
#      'href': 'https://api.spotify.com/v1/artists/5Zq7R5qmi58ByYyBQTlNuk',
#      'id': '5Zq7R5qmi58ByYyBQTlNuk',
#      'name': 'Lee Brice',
#      'type': 'artist',
#      'uri': 'spotify:artist:5Zq7R5qmi58ByYyBQTlNuk'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/5LK5cCx0XdniivfZ91vOSv'},
#    'href': 'https://api.spotify.com/v1/albums/5LK5cCx0XdniivfZ91vOSv',
#    'id': '5LK5cCx0XdniivfZ91vOSv',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b27306ae99421702f8a9d881e268',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e0206ae99421702f8a9d881e268',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d0000485106ae99421702f8a9d881e268',
#      'width': 64}],
#    'name': 'One Of Them Girls',
#    'release_date': '2020-05-15',
#    'release_date_precision': 'day',
#    'total_tracks': 2,
#    'type': 'album',
#    'uri': 'spotify:album:5LK5cCx0XdniivfZ91vOSv'},
#   {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2o5jDhtHVPhrJdv3cEQ99Z'},
#      'href': 'https://api.spotify.com/v1/artists/2o5jDhtHVPhrJdv3cEQ99Z',
#      'id': '2o5jDhtHVPhrJdv3cEQ99Z',
#      'name': 'Tiësto',
#      'type': 'artist',
#      'uri': 'spotify:artist:2o5jDhtHVPhrJdv3cEQ99Z'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/6CIslPQSknp875cigkhKJC'},
#    'href': 'https://api.spotify.com/v1/albums/6CIslPQSknp875cigkhKJC',
#    'id': '6CIslPQSknp875cigkhKJC',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b2739759d6dfa2c19091814fccb3',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e029759d6dfa2c19091814fccb3',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d000048519759d6dfa2c19091814fccb3',
#      'width': 64}],
#    'name': 'The London Sessions',
#    'release_date': '2020-05-15',
#    'release_date_precision': 'day',
#    'total_tracks': 13,
#    'type': 'album',
#    'uri': 'spotify:album:6CIslPQSknp875cigkhKJC'},
#   {'album_type': 'single',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6pBNfggcZZDCmb0p92OnGn'},
#      'href': 'https://api.spotify.com/v1/artists/6pBNfggcZZDCmb0p92OnGn',
#      'id': '6pBNfggcZZDCmb0p92OnGn',
#      'name': 'Chase Rice',
#      'type': 'artist',
#      'uri': 'spotify:artist:6pBNfggcZZDCmb0p92OnGn'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/5XvXf3mdhShyLZhoJYR74q'},
#    'href': 'https://api.spotify.com/v1/albums/5XvXf3mdhShyLZhoJYR74q',
#    'id': '5XvXf3mdhShyLZhoJYR74q',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b2735f6b892b478747a769252650',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e025f6b892b478747a769252650',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d000048515f6b892b478747a769252650',
#      'width': 64}],
#    'name': 'The Album, Pt. II',
#    'release_date': '2020-05-15',
#    'release_date_precision': 'day',
#    'total_tracks': 4,
#    'type': 'album',
#    'uri': 'spotify:album:5XvXf3mdhShyLZhoJYR74q'},
#   {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1caBfBEapzw8z2Qz9q0OaQ'},
#      'href': 'https://api.spotify.com/v1/artists/1caBfBEapzw8z2Qz9q0OaQ',
#      'id': '1caBfBEapzw8z2Qz9q0OaQ',
#      'name': 'Asking Alexandria',
#      'type': 'artist',
#      'uri': 'spotify:artist:1caBfBEapzw8z2Qz9q0OaQ'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/5VKKXDvYuJmRc2UQHCwNQK'},
#    'href': 'https://api.spotify.com/v1/albums/5VKKXDvYuJmRc2UQHCwNQK',
#    'id': '5VKKXDvYuJmRc2UQHCwNQK',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273d30ebbcdf987ab5273abdd8d',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02d30ebbcdf987ab5273abdd8d',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d00004851d30ebbcdf987ab5273abdd8d',
#      'width': 64}],
#    'name': 'Like A House On Fire',
#    'release_date': '2020-05-15',
#    'release_date_precision': 'day',
#    'total_tracks': 15,
#    'type': 'album',
#    'uri': 'spotify:album:5VKKXDvYuJmRc2UQHCwNQK'},
#   {'album_type': 'single',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7d3WFRME3vBY2cgoP38RDo'},
#      'href': 'https://api.spotify.com/v1/artists/7d3WFRME3vBY2cgoP38RDo',
#      'id': '7d3WFRME3vBY2cgoP38RDo',
#      'name': 'Lil Skies',
#      'type': 'artist',
#      'uri': 'spotify:artist:7d3WFRME3vBY2cgoP38RDo'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/3cVy1WTjSAVpzUc7MVCTLu'},
#    'href': 'https://api.spotify.com/v1/albums/3cVy1WTjSAVpzUc7MVCTLu',
#    'id': '3cVy1WTjSAVpzUc7MVCTLu',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273f7571dc32332081426ab3818',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02f7571dc32332081426ab3818',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d00004851f7571dc32332081426ab3818',
#      'width': 64}],
#    'name': 'Riot',
#    'release_date': '2020-05-13',
#    'release_date_precision': 'day',
#    'total_tracks': 1,
#    'type': 'album',
#    'uri': 'spotify:album:3cVy1WTjSAVpzUc7MVCTLu'},
#   {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/55fhWPvDiMpLnE4ZzNXZyW'},
#      'href': 'https://api.spotify.com/v1/artists/55fhWPvDiMpLnE4ZzNXZyW',
#      'id': '55fhWPvDiMpLnE4ZzNXZyW',
#      'name': 'Noah Cyrus',
#      'type': 'artist',
#      'uri': 'spotify:artist:55fhWPvDiMpLnE4ZzNXZyW'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/5Gn3fFzlWL89j0hGumtXb5'},
#    'href': 'https://api.spotify.com/v1/albums/5Gn3fFzlWL89j0hGumtXb5',
#    'id': '5Gn3fFzlWL89j0hGumtXb5',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b2737f66b73bd6e86f4c8d2a7692',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e027f66b73bd6e86f4c8d2a7692',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d000048517f66b73bd6e86f4c8d2a7692',
#      'width': 64}],
#    'name': 'THE END OF EVERYTHING',
#    'release_date': '2020-05-15',
#    'release_date_precision': 'day',
#    'total_tracks': 8,
#    'type': 'album',
#    'uri': 'spotify:album:5Gn3fFzlWL89j0hGumtXb5'},
#   {'album_type': 'single',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6C1ohJrd5VydigQtaGy5Wa'},
#      'href': 'https://api.spotify.com/v1/artists/6C1ohJrd5VydigQtaGy5Wa',
#      'id': '6C1ohJrd5VydigQtaGy5Wa',
#      'name': 'Joyner Lucas',
#      'type': 'artist',
#      'uri': 'spotify:artist:6C1ohJrd5VydigQtaGy5Wa'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/41qil2VaGbD194gaEcmmyx'},
#      'href': 'https://api.spotify.com/v1/artists/41qil2VaGbD194gaEcmmyx',
#      'id': '41qil2VaGbD194gaEcmmyx',
#      'name': 'Will Smith',
#      'type': 'artist',
#      'uri': 'spotify:artist:41qil2VaGbD194gaEcmmyx'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/3tOe6XM8LmRA5vDAaMqp8e'},
#    'href': 'https://api.spotify.com/v1/albums/3tOe6XM8LmRA5vDAaMqp8e',
#    'id': '3tOe6XM8LmRA5vDAaMqp8e',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b2734ac196312c24faedb76a345e',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e024ac196312c24faedb76a345e',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d000048514ac196312c24faedb76a345e',
#      'width': 64}],
#    'name': 'Will (Remix)',
#    'release_date': '2020-05-15',
#    'release_date_precision': 'day',
#    'total_tracks': 1,
#    'type': 'album',
#    'uri': 'spotify:album:3tOe6XM8LmRA5vDAaMqp8e'},
#   {'album_type': 'single',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6Xgp2XMz1fhVYe7i6yNAax'},
#      'href': 'https://api.spotify.com/v1/artists/6Xgp2XMz1fhVYe7i6yNAax',
#      'id': '6Xgp2XMz1fhVYe7i6yNAax',
#      'name': 'Trippie Redd',
#      'type': 'artist',
#      'uri': 'spotify:artist:6Xgp2XMz1fhVYe7i6yNAax'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/2HPaUgqeutzr3jx5a9WyDV'},
#      'href': 'https://api.spotify.com/v1/artists/2HPaUgqeutzr3jx5a9WyDV',
#      'id': '2HPaUgqeutzr3jx5a9WyDV',
#      'name': 'PARTYNEXTDOOR',
#      'type': 'artist',
#      'uri': 'spotify:artist:2HPaUgqeutzr3jx5a9WyDV'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/7rcMHNqNbQxF5TaPMHFoKu'},
#    'href': 'https://api.spotify.com/v1/albums/7rcMHNqNbQxF5TaPMHFoKu',
#    'id': '7rcMHNqNbQxF5TaPMHFoKu',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273de32a6662a7db272328f4761',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02de32a6662a7db272328f4761',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d00004851de32a6662a7db272328f4761',
#      'width': 64}],
#    'name': 'Excitement',
#    'release_date': '2020-05-15',
#    'release_date_precision': 'day',
#    'total_tracks': 1,
#    'type': 'album',
#    'uri': 'spotify:album:7rcMHNqNbQxF5TaPMHFoKu'},
#   {'album_type': 'single',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3NPpFNZtSTHheNBaWC82rB'},
#      'href': 'https://api.spotify.com/v1/artists/3NPpFNZtSTHheNBaWC82rB',
#      'id': '3NPpFNZtSTHheNBaWC82rB',
#      'name': 'X Ambassadors',
#      'type': 'artist',
#      'uri': 'spotify:artist:3NPpFNZtSTHheNBaWC82rB'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/0pCNk4D3E2xtszsm6hMsWr'},
#      'href': 'https://api.spotify.com/v1/artists/0pCNk4D3E2xtszsm6hMsWr',
#      'id': '0pCNk4D3E2xtszsm6hMsWr',
#      'name': 'K.Flay',
#      'type': 'artist',
#      'uri': 'spotify:artist:0pCNk4D3E2xtszsm6hMsWr'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/4ZgQDCtRqZlhLswVS6MHN4'},
#      'href': 'https://api.spotify.com/v1/artists/4ZgQDCtRqZlhLswVS6MHN4',
#      'id': '4ZgQDCtRqZlhLswVS6MHN4',
#      'name': 'grandson',
#      'type': 'artist',
#      'uri': 'spotify:artist:4ZgQDCtRqZlhLswVS6MHN4'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/2JQbWWpYG6kKppiD6z2FwL'},
#    'href': 'https://api.spotify.com/v1/albums/2JQbWWpYG6kKppiD6z2FwL',
#    'id': '2JQbWWpYG6kKppiD6z2FwL',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273e420fab8e9ec9cf79c073a28',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02e420fab8e9ec9cf79c073a28',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d00004851e420fab8e9ec9cf79c073a28',
#      'width': 64}],
#    'name': 'Zen (with K.Flay & grandson)',
#    'release_date': '2020-05-15',
#    'release_date_precision': 'day',
#    'total_tracks': 1,
#    'type': 'album',
#    'uri': 'spotify:album:2JQbWWpYG6kKppiD6z2FwL'}],
#  'limit': 20,
#  'next': 'https://api.spotify.com/v1/browse/new-releases?offset=20&limit=20',
#  'offset': 0,
#  'previous': None,
#  'total': 100}

# %% [markdown]
# We access values as we would for nested lists or dictionaries in Python.

# %%
data['albums']['items'][0].keys()
# Out:
# dict_keys(['album_type', 'artists', 'available_markets', 'external_urls', 'href', 'id', 'images', 'name', 'release_date', 'release_date_precision', 'total_tracks', 'type', 'uri'])

# %%
data['albums']['items'][0]['artists'][0]['name']
# Out:
# 'Future'

# %%
data['albums']['items'][1]['artists'][0]['name']
# Out:
# 'Kygo'

# %% [markdown]
# # Loading in Plant Data

# %% [markdown]
# Now that we have a handle on how to deal with data in JSON form, let's load in a new dataset and construct an analysis!
# This dataset was gathered with the [Trefle API](https://docs.trefle.io/). It contains information about 1000 plants in JSON form.

# %%
with open('data/plants.json', 'r') as f:
    plants = json.load(f)

# %%
type(plants)
# Out:
# list

# %%
len(plants)
# Out:
# 1000

# %% [markdown]
# ## What Information Do We Have?

# %% [markdown]
# Let's take a look at the first plant in our list to see what information is available.

# %%
plants[0]
# Out:
# {'id': 678281,
#  'common_name': 'Evergreen oak',
#  'slug': 'quercus-rotundifolia',
#  'scientific_name': 'Quercus rotundifolia',
#  'year': 1785,
#  'bibliography': 'Encycl. 1: 723 (1785)',
#  'author': 'Lam.',
#  'status': 'accepted',
#  'rank': 'species',
#  'family_common_name': 'Beech family',
#  'genus_id': 5778,
#  'image_url': 'https://bs.plantnet.org/image/o/1a03948baf0300da25558c2448f086d39b41ca30',
#  'synonyms': ['Quercus lyauteyi',
#   'Quercus rotundifolia f. crassicupulata',
#   'Quercus ballota',
#   'Quercus ilex f. brevicupulata',
#   'Quercus calycina',
#   'Quercus rotundifolia f. dolichocalyx',
#   'Quercus rotundifolia f. pilosella',
#   'Quercus rotundifolia f. macrocarpa',
#   'Quercus rotundifolia f. calycina',
#   'Quercus ilex f. macrocarpa',
#   'Quercus ilex subsp. ballota',
#   'Quercus rotundifolia var. pilosella',
#   'Quercus rotundifolia var. brevicupulata',
#   'Quercus rotundifolia subsp. maghrebiana',
#   'Quercus rotundifolia f. brevicupulata',
#   'Quercus rotundifolia var. macrocarpa'],
#  'genus': 'Quercus',
#  'family': 'Fagaceae',
#  'links': {'self': '/api/v1/species/quercus-rotundifolia',
#   'plant': '/api/v1/plants/quercus-rotundifolia',
#   'genus': '/api/v1/genus/quercus'}}

# %% [markdown]
# You can find more information about these fields [here](https://docs.trefle.io/docs/advanced/plants-fields).

# %% [markdown]
# ## Plant Families

# %% [markdown]
# Let's start by seeing what botanical families are represented in our data. We'll build a dictionary that counts the plants by family. We'll use the common names for this purpose.

# %%
plant_dict = defaultdict(int)
for plant in plants:
    plant_dict[plant['family_common_name']] += 1

# %%
plant_dict
# Out:
# defaultdict(int,
#             {'Beech family': 10,
#              'Nettle family': 2,
#              'Grass family': 81,
#              'Plantain family': 25,
#              'Buttercup family': 21,
#              'Pea family': 63,
#              'Olive family': 5,
#              'Rose family': 49,
#              'Birch family': 7,
#              'Rush family': 19,
#              'Buckwheat family': 17,
#              'Soapberry family': 7,
#              'Pine family': 10,
#              'Mint family': 45,
#              'Madder family': 9,
#              None: 113,
#              'Pink family': 31,
#              'Carrot family': 29,
#              'Geranium family': 10,
#              'Aster family': 80,
#              'Horsetail family': 7,
#              'Heath family': 17,
#              'Loosestrife family': 2,
#              'Bracken Fern family': 1,
#              'Mustard family': 29,
#              'Evening Primrose family': 10,
#              'Willow family': 3,
#              'Polypody family': 7,
#              'Dogwood family': 3,
#              'Honeysuckle family': 9,
#              'Morning-glory family': 3,
#              'Iris family': 1,
#              'Spleenwort family': 8,
#              'Amaranth family': 6,
#              'Sedge family': 41,
#              'Buckthorn family': 3,
#              'Holly family': 1,
#              'Potato family': 7,
#              'Bellflower family': 9,
#              'Wood-Sorrel family': 3,
#              'Borage family': 13,
#              'Bittersweet family': 2,
#              'Primrose family': 12,
#              'Poppy family': 7,
#              'Spurge family': 10,
#              'Cat-tail family': 4,
#              'Arum family': 8,
#              'Water-plantain family': 1,
#              'Hemp family': 1,
#              'Sumac family': 2,
#              'Touch-me-not family': 3,
#              'Broom-rape family': 10,
#              'Elm family': 2,
#              'Flax family': 2,
#              'Stonecrop family': 8,
#              'Brachythecium moss family': 3,
#              'Rock-rose family': 5,
#              'Mallow family': 5,
#              'Buckbean family': 1,
#              'Sundew family': 2,
#              'Milkwort family': 2,
#              'Cypress family': 2,
#              'Myrtle family': 2,
#              'Verbena family': 3,
#              'Ginseng family': 1,
#              'Currant family': 4,
#              'Sandalwood family': 1,
#              'Pondweed family': 7,
#              'Water-lily family': 2,
#              'Gentian family': 6,
#              'Yam family': 1,
#              'Walnut family': 1,
#              'Boxwood family': 1,
#              'Dogbane family': 3,
#              'Mignonette family': 2,
#              'Bladderwort family': 2,
#              'Melastome family': 1,
#              'Saxifrage family': 5,
#              'Purslane family': 1,
#              'Grape family': 2,
#              'Pokeweed family': 1,
#              'Mezereum family': 3,
#              'Bayberry family': 1,
#              'Club-moss family': 4,
#              'Hornwort family': 1,
#              'Leadwort family': 1,
#              'Arrow-grass family': 2,
#              'Cucumber family': 1,
#              'Water Milfoil family': 3,
#              'Tape-grass family': 10,
#              'Manatee-grass family': 4,
#              'Eel-grass family': 1,
#              'Flowering Rush family': 1,
#              'Lily family': 2,
#              'Spike-moss family': 1,
#              'Barberry family': 1,
#              "Adder's-tongue family": 2,
#              'Oleaster family': 1,
#              'Palm family': 2,
#              'Acanthus family': 1,
#              'Calamus family': 1,
#              'Birthwort family': 1,
#              'Pittosporum family': 2})

# %%
plant_dict['Beech family']
# Out:
# 10

# %% [markdown]
# Are there any missing values?

# %%
plant_dict[None]
# Out:
# 113

# %% [markdown]
# Let's remove these by using a dictionary comprehension:

# %%
fams_clean = {fam: num for fam, num in plant_dict.items() if fam != None}

# %%
fams_clean.get("Beech family")
# Out:
# 10

# %% [markdown]
# Let's also remove the families whose counts are less than ten:

# %%
fams_clean = {fam: num for fam, num in fams_clean.items() if num >= 10}
fams_clean
# Out:
# {'Beech family': 10,
#  'Grass family': 81,
#  'Plantain family': 25,
#  'Buttercup family': 21,
#  'Pea family': 63,
#  'Rose family': 49,
#  'Rush family': 19,
#  'Buckwheat family': 17,
#  'Pine family': 10,
#  'Mint family': 45,
#  'Pink family': 31,
#  'Carrot family': 29,
#  'Geranium family': 10,
#  'Aster family': 80,
#  'Heath family': 17,
#  'Mustard family': 29,
#  'Evening Primrose family': 10,
#  'Sedge family': 41,
#  'Borage family': 13,
#  'Primrose family': 12,
#  'Spurge family': 10,
#  'Broom-rape family': 10,
#  'Tape-grass family': 10}

# %% [markdown]
# Now we can make a bar chart of the numbers:

# %%
plt.style.use('seaborn')
# Out:
# /var/folders/zh/d6prt00115d70pxr6ctyc_180000gp/T/ipykernel_6191/240305066.py:1: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn')

# %%
fig, ax = plt.subplots(figsize=(20, 12))

ax.bar(x=list(fams_clean.keys()), height=list(fams_clean.values()))
ax.set_title('Families by Number', fontsize=30)
plt.xticks(rotation=80, fontsize=20)
plt.yticks(fontsize=20);

# %% [markdown]
# ## Synonyms

# %% [markdown]
# Suppose we wanted to know how many synonymous names were listed for each plant. We could grab this number with a list comprehension:

# %%
plants[0]
# Out:
# {'id': 678281,
#  'common_name': 'Evergreen oak',
#  'slug': 'quercus-rotundifolia',
#  'scientific_name': 'Quercus rotundifolia',
#  'year': 1785,
#  'bibliography': 'Encycl. 1: 723 (1785)',
#  'author': 'Lam.',
#  'status': 'accepted',
#  'rank': 'species',
#  'family_common_name': 'Beech family',
#  'genus_id': 5778,
#  'image_url': 'https://bs.plantnet.org/image/o/1a03948baf0300da25558c2448f086d39b41ca30',
#  'synonyms': ['Quercus lyauteyi',
#   'Quercus rotundifolia f. crassicupulata',
#   'Quercus ballota',
#   'Quercus ilex f. brevicupulata',
#   'Quercus calycina',
#   'Quercus rotundifolia f. dolichocalyx',
#   'Quercus rotundifolia f. pilosella',
#   'Quercus rotundifolia f. macrocarpa',
#   'Quercus rotundifolia f. calycina',
#   'Quercus ilex f. macrocarpa',
#   'Quercus ilex subsp. ballota',
#   'Quercus rotundifolia var. pilosella',
#   'Quercus rotundifolia var. brevicupulata',
#   'Quercus rotundifolia subsp. maghrebiana',
#   'Quercus rotundifolia f. brevicupulata',
#   'Quercus rotundifolia var. macrocarpa'],
#  'genus': 'Quercus',
#  'family': 'Fagaceae',
#  'links': {'self': '/api/v1/species/quercus-rotundifolia',
#   'plant': '/api/v1/plants/quercus-rotundifolia',
#   'genus': '/api/v1/genus/quercus'}}

# %%
num_syn = [len(plant['synonyms']) for plant in plants]

# %%
fig, ax = plt.subplots(figsize=(8, 6))

ax.scatter(range(1000), num_syn, alpha=0.8)
ax.set_title('Numbers of Synonyms');

# %% [markdown]
# ## Exercise

# %% [markdown]
# One plant has nearly 350 synonynms! What plant is this?

# %% [markdown]
# <details>
#     <summary>
#         Answer 1
#     </summary>
#
# ```python
# [plant for plant in plants if len(plant['synonyms']) > 300][0]['common_name']
# ```
# </details>

# %% [markdown]
# <details>
#     <summary>
#         Answer 2
#     </summary>
#
# ```python
# for plant in plants:
#     if len(plant['synonyms']) >300:
#         print (plant['common_name'])
# ```
# </details>

# %% [markdown]
# ## Bibliography

# %%
biblios = [plant['bibliography'] for plant in plants]

# %%
biblios[0]
# Out:
# 'Encycl. 1: 723 (1785)'

# %% [markdown]
# Let's check the bibliographies for any explicit mention of Linnaeus, the godfather of biological taxonomy. First we'll remove the plants with no bibliography:

# %%
hasbiblio = [plant for plant in plants if plant['bibliography'] != None]

# %%
len(hasbiblio)
# Out:
# 994

# %%
linnaeans = [plant['bibliography'] for plant in hasbiblio if 'Linnaeus'in plant['bibliography']]
linnaeans
# Out:
# ['Linnaeus, C. (1753). Species plantarum, exhibentes plantas rite cognitas ad genera relatas cum differentiis specificis, nominibus trivialibus, synonymis selectis, locis natalibus, secundum systema sexuale digestas. Stockholm.']

# %% [markdown]
# # Matching Author and Bibliography

# %% [markdown]
# In fact, _Species Plantarum_ (1753) was written by Linnaeus, and "Sp. Pl." In these bibliographies is a reference to that master work. Let's check to see who the author is for these records whose bibliographies start with "Sp. Pl.":

# %%
sps = []
for plant in hasbiblio:
    if plant['bibliography'].startswith('Sp. Pl.'):
            sps.append(plant)

# %%
sp_authors = [sp['author'] for sp in sps]
sp_authors
# Out:
# ['L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  '(L.) L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  '(J.Presl & C.Presl) Parl.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'Willd.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  None,
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  '(L.) L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'A.Haines (Linnaeus)',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.',
#  'L.']

# %%
uniq_auth = list(set(sp_authors))
uniq_auth
# Out:
# ['A.Haines (Linnaeus)',
#  'Willd.',
#  'L.',
#  None,
#  '(L.) L.',
#  '(J.Presl & C.Presl) Parl.']

# %%
counts = []
for author in uniq_auth:
    counts.append(sp_authors.count(author))

# %%
dict(zip(uniq_auth, counts))
# Out:
# {'A.Haines (Linnaeus)': 1,
#  'Willd.': 1,
#  'L.': 439,
#  None: 1,
#  '(L.) L.': 2,
#  '(J.Presl & C.Presl) Parl.': 1}

# %% [markdown]
# ## Exercise

# %% [markdown]
# Change the author to 'L.' (for 'Linnaeus') for all of these records in the plants list.

# %%
new_plants = []
for key,plant in enumerate(plants):
    if plant['author'] != "L.":
        plant['author'] = "L."
        new_plants.append(plant)
new_plants
# Out:
# [{'id': 124198,
#   'common_name': 'Oneseed hawthorn',
#   'slug': 'crataegus-monogyna',
#   'scientific_name': 'Crataegus monogyna',
#   'year': 1775,
#   'bibliography': 'Fl. Austriac. 3: 50 (1775)',
#   'author': 'L.',
#   'status': 'accepted',
#   'rank': 'species',
#   'family_common_name': 'Rose family',
#   'genus_id': 678,
#   'image_url': 'https://bs.plantnet.org/image/o/26b1520c799177ee1b7c4a27f9f46c4ace617dd2',
#   'synonyms': ['Crataegus insegnae',
#    'Mespilus insegnae',
#    'Mespilus crataegus',
#    'Mespilus elegans',
#    'Mespilus heterophylla',
#    'Crataegus triloba',
#    'Crataegus monogyna var. dissecta',
#    'Oxyacantha elegans',
#    'Mespilus brevispina',
#    'Crataegus brevispina',
#    'Crataegus monogyna var. lasiocarpa',
#    'Crataegus azarella',
#    'Crataegus monogyna var. microphylla',
#    'Crataegus dissecta',
#    'Crataegus monogyna var. nordica',
#    'Crataegus apiifolia',
#    'Mespilus maura',
#    'Mespilus constantinopolitana',
#    'Crataegus maura',
#    'Crataegus heterophylla',
#    'Oxyacantha azarella',
#    'Crataegus aegeica',
#    'Crataegus monogyna subsp. nordica',
#    'Mespilus triloba',
#    'Oxyacantha apiifolia',
#    'Oxyacantha monogyna',
#    'Mespilus monogyna',
#    'Crataegus lasiocarpa',
#    'Crataegus stevenii'],
#   'genus': 'Crataegus',
#   'family': 'Rosaceae',
#   'links': {'self': '/api/v1/species/crataegus-monogyna',
#    'plant': '/api/v1/plants/crataegus-monogyna',
#    'genus': '/api/v1/genus/crataegus'}},
#  {'id': 137183,
#   'common_name': 'Queen of the meadow',
#   'slug': 'filipendula-ulmaria',
#   'scientific_name': 'Filipendula ulmaria',
#   'year': 1879,
#   'bibliography': 'Trudy Imp. S.-Peterburgsk. Bot. Sada 6: 251 (1879)',
#   'author': 'L.',
#   'status': 'accepted',
#   'rank': 'species',
#   'family_common_name': 'Rose family',
#   'genus_id': 3008,
#   'image_url': 'https://bs.plantnet.org/image/o/f5f2a3d241dcd22e237cdebdbf770477721516f0',
#   'synonyms': ['Spiraea ulmaria',
#    'Filipendula denudata',
#    'Filipendula ulmaria var. denudata',
#    'Filipendula ulmaria subsp. megalocarpa',
#    'Filipendula ulmaria subsp. denudata',
#    'Spiraea denudata',
#    'Spiraea filipendula var. tomentosa',
#    'Spiraea ulmaria var. denudata',
#    'Ulmaria glauca',
#    'Ulmaria quinqueloba',
#    'Ulmaria pentapetala',
#    'Ulmaria ulmaria',
#    'Ulmaria vulgaris',
#    'Ulmaria denudata',
#    'Filipendula megalocarpa',
#    'Spiraea contorta',
#    'Filipendula ulmaria var. tomentosa',
#    'Filipendula ulmaria var. glaberrima'],
#   'genus': 'Filipendula',
#   'family': 'Rosaceae',
#   'links': {'self': '/api/v1/species/filipendula-ulmaria',
#    'plant': '/api/v1/plants/filipendula-ulmaria',
#    'genus': '/api/v1/genus/filipendula'}},
#  {'id': 166081,
#   'common_name': 'Common reed',
#   'slug': 'phragmites-australis',
#   'scientific_name': 'Phragmites australis',
#   'year': 1841,
#   'bibliography': 'Nomencl. Bot., ed. 2, 2: 324 (1841)',
#   'author': 'L.',
#   'status': 'accepted',
#   'rank': 'species',
#   'family_common_name': 'Grass family',
#   'genus_id': 3364,
#   'image_url': 'https://bs.plantnet.org/image/o/1155e1614588374ce93aedb701ae8483e2cae45f',
#   'synonyms': ['Phragmites communis',
#    'Arundo australis',
#    'Arundo pseudophragmites',
#    'Donax australis',
#    'Phragmites australis subsp. americanus',
#    'Phragmites communis subsp. berlandieri',
#    'Phragmites australis var. flavescens',
#    'Remirea diffusa',
#    'Phragmites chilensis',
#    'Arundo filiformis',
#    'Cynodon phragmites',
#    'Arundo vulgaris',
#    'Phragmites breviglumis',
#    'Phragmites jahandiezii',
#    'Phragmites humilis',
#    'Czernya arundinacea',
#    'Phragmites hirsutus',
#    'Phragmites nagus',
#    'Cenchrus frutescens',
#    'Phragmites flavescens',
#    'Oxyanthe phragmites',
#    'Arundo barbata',
#    'Trichoon phragmites',
#    'Phragmites pungens',
#    'Phragmites communis f. salsa',
#    'Phragmites australis var. salsa',
#    'Phragmites stenophyllus',
#    'Phragmites australis var. turkestanicus',
#    'Phragmites australis var. striatopictus',
#    'Phragmites willkommianus',
#    'Phragmites fissifolius',
#    'Phragmites communis var. variegatus',
#    'Phragmites martinicensis',
#    'Phragmites explanatus',
#    'Phragmites congestus',
#    'Xenochloa arundinacea',
#    'Phragmites dioicus',
#    'Phragmites pumilus',
#    'Arundo nigricans',
#    'Phragmites australis subsp. maritimus',
#    'Arundo occidentalis',
#    'Phragmites australis subsp. humilis',
#    'Reimaria diffusa',
#    'Arundo vulnerans',
#    'Phragmites capensis',
#    'Arundo phragmites',
#    'Phragmites caudatus',
#    'Phragmites hispanicus',
#    'Phragmites occidentalis',
#    'Phragmites graecus',
#    'Phragmites nigricans',
#    'Phragmites flexuosus',
#    'Phragmites nakaianus',
#    'Calamagrostis nigricans',
#    'Phragmites australis f. pilifer',
#    'Phragmites australis var. marsillianus',
#    'Phragmites australis f. subuniflora',
#    'Phragmites australis var. stenophyllus',
#    'Phragmites vulgaris',
#    'Phragmites xenochloa',
#    'Phragmites frutescens',
#    'Phragmites maximus var. variegatus',
#    'Arundo graeca',
#    'Phragmites emodi',
#    'Phragmites maritimus',
#    'Arundo rivularis',
#    'Phragmites filiformis',
#    'Phragmites loscosii',
#    'Phragmites longivalvis',
#    'Phragmites distichus',
#    'Phragmites bhattacharyyae',
#    'Phragmites jeholensis',
#    'Arundo palustris',
#    'Phragmites australis var. humilis',
#    'Arundo pungens',
#    'Arundo aggerum',
#    'Phragmites australis subsp. berlandieri',
#    'Phragmites barbatus'],
#   'genus': 'Phragmites',
#   'family': 'Poaceae',
#   'links': {'self': '/api/v1/species/phragmites-australis',
#    'plant': '/api/v1/plants/phragmites-australis',
#    'genus': '/api/v1/genus/phragmites'}},
#  {'id': 118634,
#   'common_name': 'Common mouse-ear chickweed',
#   'slug': 'cerastium-fontanum',
#   'scientific_name': 'Cerastium fontanum',
#   'year': 1816,
#   'bibliography': 'Enum. Stirp. Transsilv. 1: 425 (1816)',
#   'author': 'L.',
#   'status': 'accepted',
#   'rank': 'species',
#   'family_common_name': 'Pink family',
#   'genus_id': 1602,
#   'image_url': 'https://bs.plantnet.org/image/o/38a8a07c9c0cd6083b2a8dca1be4ac7f0e49b709',
#   'synonyms': ['Cerastium vulgatum var. filiforme',
#    'Cerastium triviale var. alpinum',
#    'Cerastium vulgatum var. viscidum',
#    'Cerastium vulgatum var. anomalum',
#    'Cerastium caespitosum subsp. alpinum',
#    'Cerastium vulgatum subsp. alpinum',
#    'Cerastium vulgatum var. alpestre',
#    'Cerastium longirostre'],
#   'genus': 'Cerastium',
#   'family': 'Caryophyllaceae',
#   'links': {'self': '/api/v1/species/cerastium-fontanum',
#    'plant': '/api/v1/plants/cerastium-fontanum',
#    'genus': '/api/v1/genus/cerastium'}},
#  {'id': 1235524,
#   'common_name': 'European alder',
#   'slug': 'alnus-glutinosa',
#   'scientific_name': 'Alnus glutinosa',
#   'year': 1790,
#   'bibliography': 'Fruct. Sem. Pl. 2: 54 (1790)',
#   'author': 'L.',
#   'status': 'accepted',
#   'rank': 'species',
#   'family_common_name': 'Birch family',
#   'genus_id': 273,
#   'image_url': 'https://bs.plantnet.org/image/o/2730cc06110e471d878bf14af815f83905866a64',
#   'synonyms': ['Alnus vulgaris',
#    'Betula alnus var. glutinosa',
#    'Alnus rotundifolia',
#    'Alnus cerifera',
#    'Alnus incisa',
#    'Alnus morisiana',
#    'Alnus suaveolens',
#    'Alnus nigra',
#    'Alnus quercifolia',
#    'Betula emarginata',
#    'Alnus dubia',
#    'Alnus februaria',
#    'Alnus oxyacanthifolia',
#    'Alnus nitens',
#    'Alnus prunifolia',
#    'Alnus sorbifolia'],
#   'genus': 'Alnus',
#   'family': 'Betulaceae',
#   'links': {'self': '/api/v1/species/alnus-glutinosa',
#    'plant': '/api/v1/plants/alnus-glutinosa',
#    'genus': '/api/v1/genus/alnus'}},
#  {'id': 111375,
#   'common_name': 'European white birch',
#   'slug': 'betula-pendula',
#   'scientific_name': 'Betula pendula',
#   'year': 1788,
#   'bibliography': 'Tent. Fl. Germ. 1: 405 (1788)',
#   'author': 'L.',
#   'status': 'accepted',
#   'rank': 'species',
#   'family_common_name': 'Birch family',
#   'genus_id': 970,
#   'image_url': 'https://bs.plantnet.org/image/o/8b54826c7cc96e83f953ea09872ee3026c8d598e',
#   'synonyms': ['Betula verrucosa',
#    'Betula platyphylloides',
#    'Betula pseudopendula',
#    'Betula talassica',
#    'Betula ellipticifolia',
#    'Betula brachylepis',
#    'Betula insularis',
#    'Betula kotulae',
#    'Betula transbaicalensis',
#    'Betula alba var. laciniata',
#    'Betula pendula var. cuneata',
#    'Betula parvibracteata',
#    'Betula ferganensis',
#    'Betula pendula f. cuneata',
#    'Betula cajanderi f. fruticans',
#    'Betula fontqueri',
#    'Betula microlepis var. moldavica',
#    'Betula odorata var. sudetica',
#    'Betula palmata var. lobulata',
#    'Betula szaferi',
#    'Betula verrucosa f. bircalensis',
#    'Betula pendula var. lapponica',
#    'Betula alba var. dalecarlica',
#    'Betula coriacea',
#    'Betula pendula f. crispa',
#    'Betula pendula var. laciniata',
#    'Betula hybrida',
#    'Betula palmata',
#    'Betula gummifera',
#    'Betula platyphylloides var. microphylla',
#    'Betula pendula var. etnensis',
#    'Betula fontqueri subsp. parvibracteata',
#    'Betula cycoviensis',
#    'Betula laciniata var. crispa',
#    'Betula pendula var. microlepis',
#    'Betula pendula f. dalecarlica',
#    'Betula microlepis',
#    'Betula montana',
#    'Betula vladimirii',
#    'Betula kossogolica',
#    'Betula tiulinae',
#    'Betula obscura',
#    'Betula alba var. macrocarpa',
#    'Betula ludmilae',
#    'Betula pendula var. fontqueri',
#    'Betula palmata var. bircalensis',
#    'Betula pendula var. parvibracteata',
#    'Betula laciniata',
#    'Betula tristis',
#    'Betula carpatica var. sudetica',
#    'Betula alba var. lobulata',
#    'Betula lobulata',
#    'Betula mongolica',
#    'Betula etnensis',
#    'Betula palmata var. crispa',
#    'Betula virgultosa',
#    'Betula pendula f. bircalensis',
#    'Betula pendula subsp. fontqueri',
#    'Betula pendula var. meridionalis',
#    'Betula pendula var. carelica',
#    'Betula pendula f. palmeri',
#    'Betula hippolyti',
#    'Betula oycoviensis',
#    'Betula oycowiensis',
#    'Betula uschkanensis'],
#   'genus': 'Betula',
#   'family': 'Betulaceae',
#   'links': {'self': '/api/v1/species/betula-pendula',
#    'plant': '/api/v1/plants/betula-pendula',
#    'genus': '/api/v1/genus/betula'}},
#  {'id': 127884,
#   'common_name': 'Mountain wavy hairgrass',
#   'slug': 'avenella-flexuosa',
#   'scientific_name': 'Avenella flexuosa',
#   'year': 1838,
#   'bibliography': 'Fl. Excurs. Hafn.: 32 (1838)',
#   'author': 'L.',
#   'status': 'accepted',
#   'rank': 'species',
#   'family_common_name': 'Grass family',
#   'genus_id': 2377,
#   'image_url': 'https://d2seqvvyy3b8p2.cloudfront.net/36096e9d4ceb8271fde266276ce454f1.jpg',
#   'synonyms': ['Lerchenfeldia flexuosa',
#    'Deschampsia flexuosa',
#    'Aira flexuosa',
#    'Arundo flexuosa',
#    'Avena flexuosa',
#    'Podionapus flexuosus',
#    'Salmasia flexuosa',
#    'Deschampsia flexuosa var. pallida',
#    'Deschampsia flexuosa f. viridiflora',
#    'Deschampsia tenella',
#    'Eriachne montana',
#    'Deschampsia alba',
#    'Aira versicolor',
#    'Aira flexuosa var. montana',
#    'Aira vestita',
#    'Aira arenaria',
#    'Deschampsia nitida',
#    'Aira flexuosa f. pallida',
#    'Aira nitida',
#    'Deschampsia flexuosa f. viridistriata',
#    'Aira legei',
#    'Deschampsia fuegina',
#    'Deschampsia vestita',
#    'Aira euflexuosa',
#    'Lerchenfeldia vestita',
#    'Aira splendida',
#    'Aira caryophyllaea',
#    'Deschampsia macloviana',
#    'Deschampsia flexuosa f. alpina',
#    'Deschampsia martini',
#    'Aira montana',
#    'Panicum rubigerum',
#    'Aira kawakamii',
#    'Deschampsia kawakamii',
#    'Deschampsia philippii',
#    'Deschampsia flexuosa f. parviflora',
#    'Lerchenfeldia montana',
#    'Deschampsia flexuosa f. violacea',
#    'Aira flexilis',
#    'Deschampsia flexuosa f. argentea',
#    'Aira flammosa',
#    'Deschampsia flexuosa var. flexuosa',
#    'Deschampsia flexuosa var. montana',
#    'Avenella flexuosa subsp. montana',
#    'Deschampsia flexuosa subsp. montana',
#    'Lerchenfeldia flexuosa subsp. montana'],
#   'genus': 'Avenella',
#   'family': 'Poaceae',
#   'links': {'self': '/api/v1/species/avenella-flexuosa',
#    'plant': '/api/v1/plants/avenella-flexuosa',
#    'genus': '/api/v1/genus/avenella'}},
#  {'id': 127829,
#   'common_name': 'Tufted hairgrass',
#   'slug': 'deschampsia-cespitosa',
#   'scientific_name': 'Deschampsia cespitosa',
#   'year': 1812,
#   'bibliography': 'Ess. Agrostogr.: 91 (1812)',
#   'author': 'L.',
#   'status': 'accepted',
#   'rank': 'species',
#   'family_common_name': 'Grass family',
#   'genus_id': 1267,
#   'image_url': 'https://bs.plantnet.org/image/o/8193be51b20eb8bd28a29d67dd96e9287ddbcbec',
#   'synonyms': ['Aira cespitosa',
#    'Calamagrostis arundo',
#    'Avena cespitosa',
#    'Agrostis cespitosa',
#    'Aira major',
#    'Podionapus cespitosus',
#    'Campella cespitosa',
#    'Deschampsia andina',
#    'Deschampsia caespitosa var. longiflora',
#    'Deschampsia caespitosa',
#    'Deschampsia caespitosa var. abbei',
#    'Deschampsia caespitosa var. intercotidalis',
#    'Deschampsia cespitosa var. arctica',
#    'Deschampsia cespitosa var. bottnica',
#    'Deschampsia cespitosa var. glauca',
#    'Deschampsia cespitosa var. littoralis',
#    'Deschampsia cespitosa subsp. alpina',
#    'Deschampsia caespitosa subsp. genuina',
#    'Deschampsia caespitosa subsp. orientalis',
#    'Deschampsia caespitosa subsp. beringensis',
#    'Deschampsia caespitosa subsp. glauca',
#    'Deschampsia cespitosa subsp. paramushirensis',
#    'Aira triflora',
#    'Deschampsia sukatschewii',
#    'Deschampsia alpina',
#    'Deschampsia bottnica',
#    'Deschampsia cespitosa var. longiflora',
#    'Deschampsia paramushirensis',
#    'Deschampsia beringensis',
#    'Deschampsia cespitosa var. mackenzieana',
#    'Deschampsia cespitosa var. maritima',
#    'Deschampsia mackenzieana',
#    'Deschampsia cespitosa var. abbei',
#    'Deschampsia obensis',
#    'Deschampsia cespitosa var. intercotidalis',
#    'Deschampsia pumila',
#    'Aira caespitosa',
#    'Deschampsia glauca',
#    'Deschampsia cespitosa subsp. austrobohemica',
#    'Deschampsia cespitosa var. alpicola',
#    'Deschampsia cespitosa var. submutica',
#    'Aira cespitosa var. ambigua',
#    'Deschampsia hispanica subsp. gredensis',
#    'Deschampsia cespitosa var. variegata',
#    'Vahlodea flexuosa',
#    'Aira alpina',
#    'Deschampsia cespitosa subsp. ivanovae',
#    'Aira alpicola',
#    'Deschampsia alpicola',
#    'Deschampsia vodopjanoviae',
#    'Deschampsia cespitosa f. alpicola',
#    'Aira pulchra',
#    'Deschampsia cespitosa subsp. scardica',
#    'Deschampsia cespitosa var. pulchra',
#    'Aira breviaristata',
#    'Aira cespitosa var. littoralis',
#    'Deschampsia littoralis var. ivanovae',
#    'Deschampsia cespitosa f. tenera',
#    'Deschampsia gaudinii',
#    'Aira litoralis',
#    'Aira paludosa',
#    'Deschampsia hispanica',
#    'Agrostis gredensis',
#    'Aira vivipara',
#    'Deschampsia austrobohemica',
#    'Deschampsia cespitosa var. pungens',
#    'Deschampsia breviaristata',
#    'Deschampsia brevifolia var. major',
#    'Deschampsia cespitosa subsp. rhenana',
#    'Deschampsia cespitosa var. atlantis',
#    'Deschampsia cespitosa subsp. gredensis',
#    'Deschampsia turczaninowii',
#    'Deschampsia sukatschewii subsp. borealis',
#    'Deschampsia pulchra',
#    'Deschampsia biebersteiniana',
#    'Aira micans',
#    'Deschampsia ambigua',
#    'Deschampsia multiflora',
#    'Aira cespitosa var. submutica',
#    'Aira australis',
#    'Deschampsia crassifolia',
#    'Aira glomerata',
#    'Deschampsia cespitosa subsp. anadyrensis',
#    'Deschampsia cespitosa subsp. pyrenaica',
#    'Deschampsia littoralis',
#    'Deschampsia gredensis',
#    'Deschampsia hispanica var. burebana',
#    'Deschampsia latifolia',
#    'Aira altissima',
#    'Deschampsia cespitosa subsp. obensis',
#    'Aira brevifolia',
#    'Deschampsia brachyphylla',
#    'Deschampsia cespitosa subsp. bottnica',
#    'Deschampsia penicillata',
#    'Deschampsia chinensis',
#    'Deschampsia komarovii',
#    'Aira cespitosa var. montana',
#    'Deschampsia media var. iberica',
#    'Triodia splendida',
#    'Aira laevigata',
#    'Deschampsia cespitosa var. strictior',
#    'Aira hybrida',
#    'Deschampsia tzvelevii',
#    'Aira andraei',
#    'Deschampsia cespitosa var. komarovii',
#    'Poa evagans',
#    'Aira chrysophaena',
#    'Aira turczaninowii',
#    'Deschampsia wahlenbergiana',
#    'Deschampsia cespitosa f. compacta',
#    'Deschampsia cespitosa var. crassifolia',
#    'Deschampsia tzvelevii var. vivipara',
#    'Aira bottnica',
#    'Deschampsia borealis',
#    'Aira neutralis',
#    'Aira ambigua',
#    'Deschampsia anadyrensis',
#    'Deschampsia doniana',
#    'Deschampsia sukatschewii subsp. orientalis',
#    'Deschampsia cespitosa var. exaristata',
#    'Aira grandis',
#    'Deschampsia cespitosa subsp. sukatschewii',
#    'Deschampsia cespitosa var. hispanica',
#    'Deschampsia sukatschewii subsp. minor',
#    'Deschampsia convoluta',
#    'Deschampsia hispanica var. iberica',
#    'Aira festucoides',
#    'Deschampsia hispanica subsp. gallaecica',
#    'Deschampsia laevigata',
#    'Deschampsia aleutica',
#    'Aira hartmaniana',
#    'Deschampsia altaica',
#    'Deschampsia beringensis var. atkensis',
#    'Deschampsia confinis',
#    'Deschampsia andraei',
#    'Aira sukatschewii',
#    'Deschampsia beringensis var. kurilensis',
#    'Aira biebersteinii',
#    'Aira aristulata',
#    'Deschampsia ivanovae',
#    'Deschampsia orientalis',
#    'Deschampsia alpigena',
#    'Deschampsia rhenana',
#    'Deschampsia cespitosa subsp. gaudinii',
#    'Aira × neumaniana',
#    'Aira littoralis',
#    'Deschampsia media subsp. hispanica',
#    'Deschampsia cespitosa var. minor',
#    'Deschampsia hispanica f. neilensis',
#    'Deschampsia pungens',
#    'Deschampsia cespitosa f. reptans',
#    'Deschampsia hybridogena',
#    'Aira stolonifera',
#    'Deschampsia neumaniana',
#    'Aira cespitosa var. alpina',
#    'Deschampsia cespitosa subsp. turczaninowii',
#    'Deschampsia littoralis var. beringensis',
#    'Aira pungens',
#    'Deschampsia refracta subsp. gredensis',
#    'Aira latifolia',
#    'Deschampsia montana',
#    'Aira glauca',
#    'Erioblastus flexuosus',
#    'Deschampsia cespitosa f. variegata',
#    'Deschampsia kaschinae',
#    'Deschampsia versicolor',
#    'Deschampsia kurilensis',
#    'Deschampsia cespitosa subsp. hispanica',
#    'Deschampsia submutica',
#    'Deschampsia caespitosa var. littoralis',
#    'Deschampsia caespitosa var. maritima',
#    'Deschampsia caespitosa var. alpicola',
#    'Deschampsia caespitosa var. arctica',
#    'Deschampsia caespitosa var. mackenzieana',
#    'Deschampsia caespitosa subsp. paramushirensis',
#    'Deschampsia cespitosa subsp. genuina',
#    'Deschampsia cespitosa subsp. orientalis',
#    'Deschampsia cespitosa subsp. beringensis'],
#   'genus': 'Deschampsia',
#   'family': 'Poaceae',
#   'links': {'self': '/api/v1/species/deschampsia-cespitosa',
#    'plant': '/api/v1/plants/deschampsia-cespitosa',
#    'genus': '/api/v1/genus/deschampsia'}},
#  {'id': 157316,
#   'common_name': 'Purple moorgrass',
#   'slug': 'molinia-caerulea',
#   'scientific_name': 'Molinia caerulea',
#   'year': 1794,
#   'bibliography': 'Methodus 183.  1794',
#   'author': 'L.',
#   'status': 'accepted',
#   'rank': 'species',
#   'family_common_name': 'Grass family',
#   'genus_id': 3220,
#   'image_url': 'https://bs.plantnet.org/image/o/b5a10b8476cda289a13eeb246ae9fcd0270faac7',
#   'synonyms': ['Aira caerulea',
#    'Arundo agrostis',
#    'Melica divaricata',
#    'Molinia rivulorum',
#    'Molinia caerulea var. africana',
#    'Melica caerulea',
#    'Molinia bertinii',
#    'Festuca caerulea',
#    'Molinia simonii',
#    'Enodium sylvaticum',
#    'Molinia horanszkyi',
#    'Molinia hungarica',
#    'Enodium caeruleum',
#    'Melica variabilis',
#    'Melica alpina',
#    'Molinia caerulea subsp. hispanica',
#    'Melica atrovirens',
#    'Melica sylvatica',
#    'Molinia simonii var. major',
#    'Molinia depauperata',
#    'Amblytes caerulea',
#    'Molinia sylvatica',
#    'Molinia varia',
#    'Melica arundinacea',
#    'Molinia variabilis',
#    'Aira atrovirens',
#    'Molinia euxina',
#    'Hydrochloa caerulea',
#    'Cynodon caeruleus',
#    'Molinia caerulea f. variegata',
#    'Molinia caerulea subsp. arundinacea',
#    'Molinia caerulea subsp. litoralis',
#    'Molinia altissima',
#    'Molinia ujhelyii',
#    'Molinia arundinacea var. robusta',
#    'Molinia arundinacea',
#    'Molinia litoralis',
#    'Molinia pocsii',
#    'Molinia arundinacea subsp. freyi'],
#   'genus': 'Molinia',
#   'family': 'Poaceae',
#   'links': {'self': '/api/v1/species/molinia-caerulea',
#    'plant': '/api/v1/plants/molinia-caerulea',
#    'genus': '/api/v1/genus/molinia'}},
#  {'id': 170556,
#   'common_name': 'Erect cinquefoil',
#   'slug': 'potentilla-erecta',
#   'scientific_name': 'Potentilla erecta',
#   'year': 1797,
#   'bibliography': 'Nomencl. Bot., ed. 3: 152 (1797)',
#   'author': 'L.',
#   'status': 'accepted',
#   'rank': 'species',
#   'family_common_name': 'Rose family',
#   'genus_id': 618,
#   'image_url': 'https://bs.plantnet.org/image/o/5487d9cebda9ab860383eef1cdf11aad0fcf3db7',
#   'synonyms': ['Potentilla sylvestris',
#    'Tormentilla alpina',
#    'Potentilla sciaphila',
#    'Tormentilla montana',
#    'Tormentilla sessilifolia',
#    'Tormentilla nodosa',
#    'Tormentilla adstringens',
#    'Tormentilla erecta',
#    'Fragaria tormentilla',
#    'Tormentilla divergens',
#    'Tormentilla orophila',
#    'Tormentilla ericetorum',
#    'Tormentilla parviflora',
#    'Potentilla tormentilla',
#    'Tormentilla officinalis',
#    'Tormentilla dissecta',
#    'Potentilla laeta',
#    'Potentilla officinalis',
#    'Potentilla divergens',
#    'Tormentilla tuberosa',
#    'Potentilla dacica',
#    'Potentilla favratii',
#    'Potentilla tetrapetala',
#    'Potentilla erecta subsp. strictissima'],
#   'genus': 'Potentilla',
#   'family': 'Rosaceae',
#   'links': {'self': '/api/v1/species/potentilla-erecta',
#    'plant': '/api/v1/plants/potentilla-erecta',
#    'genus': '/api/v1/genus/potentilla'}},
#  {'id': 120923,
#   'common_name': 'Bull thistle',
#   'slug': 'cirsium-vulgare',
#   'scientific_name': 'Cirsium vulgare',
#   'year': 2006,
#   'bibliography': 'Fl. Napol. 5: 209',
#   'author': 'L.',
#   'status': 'accepted',
#   'rank': 'species',
#   'family_common_name': 'Aster family',
#   'genus_id': 1787,
#   'image_url': 'https://bs.plantnet.org/image/o/8d152c039c42720f282359e792954734ebfa6d89',
#   'synonyms': ['Carduus vulgaris',
#    'Epitrachys vulgaris',
#    'Sonchus vulgare',
#    'Cirsium vulgare var. vulgare',
#    'Cirsium lanceolatum var. hypoleucum DC.',
#    'Cirsium lanceolatum var. hypoleucum'],
#   'genus': 'Cirsium',
#   'family': 'Asteraceae',
#   'links': {'self': '/api/v1/species/cirsium-vulgare',
#    'plant': '/api/v1/plants/cirsium-vulgare',
#    'genus': '/api/v1/genus/cirsium'}},
#  {'id': 166753,
#   'common_name': 'Norway spruce',
#   'slug': 'picea-abies',
#   'scientific_name': 'Picea abies',
#   'year': 1881,
#   'bibliography': 'Deut. Fl.: 325 (1881)',
#   'author': 'L.',
#   'status': 'accepted',
#   'rank': 'species',
#   'family_common_name': 'Pine family',
#   'genus_id': 5345,
#   'image_url': 'https://bs.plantnet.org/image/o/839086b536fc2782b9c1cc0f9687b97f3a18ef43',
#   'synonyms': ['Pinus pyramidalis',
#    'Picea excelsa f. parsonsii',
#    'Picea maxwellii',
#    'Picea gregoryana',
#    'Picea excelsa',
#    'Picea abies var. alpestris',
#    'Abies excelsa var. inverta',
#    'Abies medioxima',
#    'Picea excelsa f. oligoclada',
#    'Picea abies f. parsonsii',
#    'Pinus picea var. mucronata',
#    'Picea excelsa subvar. cupressina',
#    'Abies conica',
#    'Abies coerulescens',
#    'Picea subarctica',
#    'Picea abies f. mucronata',
#    'Picea abies f. columnaris',
#    'Abies excelsa var. mucronata',
#    'Pinus excelsa',
#    'Picea excelsa f. argentea',
#    'Abies alpestris',
#    'Picea viminalis',
#    'Pinus carpatica',
#    'Abies excelsa var. columnaris',
#    'Abies eremita',
#    'Abies elegans',
#    'Abies gregoryana',
#    'Abies montana',
#    'Picea cranstonii',
#    'Abies lemoniana',
#    'Abies communis',
#    'Abies minuta',
#    'Picea excelsa var. columnaris',
#    'Abies minima',
#    'Abies communis var. pendula',
#    'Picea rubra',
#    'Picea abies f. veitchii',
#    'Abies excelsa var. attenuata',
#    'Abies excelsa',
#    'Picea excelsa var. erythrocarpa',
#    'Picea excelsa f. veitchii',
#    'Abies subarctica',
#    'Picea excelsa subvar. columnaris',
#    'Abies excelsa var. argentea',
#    'Abies gigantea',
#    'Abies excelsa var. aurea',
#    'Picea excelsa var. mucronata',
#    'Abies excelsa var. eremita',
#    'Abies finedonensis',
#    'Picea elegantissima',
#    'Picea excelsa f. virgulata',
#    'Picea excelsa f. inversa',
#    'Picea finedonensis',
#    'Picea montana',
#    'Abies cranstonii',
#    'Picea abies f. integrisquamis',
#    'Abies viminalis',
#    'Abies cinerea',
#    'Picea vulgaris',
#    'Picea integrisquamis',
#    'Abies erythrocarpa',
#    'Picea velebitica',
#    'Picea excelsa var. integrisquamis',
#    'Picea excelsa var. pendula',
#    'Picea alpestris',
#    'Abies parvula',
#    'Pinus viminalis',
#    'Picea remontii',
#    'Picea abies f. cupressina',
#    'Picea excelsa f. erythrocarpa',
#    'Abies clambrasiliana',
#    'Picea vulgaris var. erythrocarpa',
#    'Picea abies f. argentea',
#    'Picea abies f. erythrocarpa',
#    'Pinus abies f. erythrocarpa',
#    'Abies excelsa var. brevifolia'],
#   'genus': 'Picea',
#   'family': 'Pinaceae',
#   'links': {'self': '/api/v1/species/picea-abies',
#    'plant': '/api/v1/plants/picea-abies',
#    'genus': '/api/v1/genus/picea'}},
#  {'id': 132057,
#   'common_name': 'Quackgrass',
#   'slug': 'elymus-repens',
#   'scientific_name': 'Elymus repens',
#   'year': 1947,
#   'bibliography': 'Madroño 9: 127 (1947)',
#   'author': 'L.',
#   'status': 'accepted',
#   'rank': 'species',
#   'family_common_name': 'Grass family',
#   'genus_id': 2703,
#   'image_url': 'https://d2seqvvyy3b8p2.cloudfront.net/80f1ec52846152e047da188e56b970c4.jpg',
#   'synonyms': ['Agropyron repens',
#    'Elytrigia repens',
#    'Triticum repens',
#    'Triticum infestum',
#    'Frumentum repens',
#    'Zeia repens',
#    'Braconotia officinarum',
#    'Elymus trachycaulus subsp. donianus',
#    'Braconotia elymoides',
#    'Agropyron caninum',
#    'Agropyron vaillantianum',
#    'Elymus caninus',
#    'Agropyron repens var. subulatum',
#    'Elytrigia vaillantiana',
#    'Triticum vaillantianum',
#    'Agropyron repens f. capillare',
#    'Agropyron leersianum',
#    'Agropyron subulatiforme f. viride',
#    'Agropyron repens var. pilosum',
#    'Agropyron subulatum',
#    'Triticum arundinaceum',
#    'Triticum sepium',
#    'Triticum rupestre',
#    'Triticum glaucum',
#    'Triticum intermedium',
#    'Agropyron bromiforme',
#    'Elymus repens var. subulatus',
#    'Agropyron repens f. vaillantianum',
#    'Elymus dumetorum',
#    'Elytrigia repens var. subulatum',
#    'Agropyron repens f. subpubescens',
#    'Elytrigia pseudocaesia',
#    'Triticum reptans',
#    'Agropyron caesium',
#    'Agropyron repens f. stoloniferum',
#    'Elytrigia dominii',
#    'Agropyron pseudocaesium',
#    'Elymus repens subsp. caesius',
#    'Elytrigia repens f. aristata',
#    'Triticum repens var. aristatum',
#    'Agropyron repens f. heberhachis',
#    'Agropyron elatum',
#    'Triticum repens var. minus',
#    'Agropyron sachalinense',
#    'Agropyron repens f. aristatum',
#    'Agropyron repens f. multiflorum',
#    'Elymus caesius',
#    'Bromus glaber',
#    'Triticum caesium',
#    'Michelaria villosa',
#    'Elymus repens var. aristatus',
#    'Elytrigia repens var. glauca',
#    'Agropyron repens f. pilosum',
#    'Agropyron repens f. podperae',
#    'Elymus repens subsp. pseudocaesius',
#    'Elytrigia levadica',
#    'Agropyron multiflorum',
#    'Agropyron repens f. geniculatum',
#    'Agropyron caninum f. caesium',
#    'Triticum firmum',
#    'Agropyron repens var. aristatum',
#    'Agropyron dumetorum',
#    'Agropyron loliiforme',
#    'Agropyron nicaeense',
#    'Agropyron rifeum',
#    'Agropyron collinum',
#    'Triticum subaristatum',
#    'Agropyron repens f. stenophyllum',
#    'Agropyron arundinaceum',
#    'Elytrigia ikonnikovii',
#    'Elytrigia repens var. aristata',
#    'Elytrigia repens var. bispiculata',
#    'Triticum repens var. nanum',
#    'Agropyron caldesii',
#    'Triticum repens var. glaucum',
#    'Agropyron firmum',
#    'Elymus vaillantianus',
#    'Agropyron repens var. arvense',
#    'Triticum arvense',
#    'Agropyron koeleri',
#    'Triticum leersianum',
#    'Agropyron repens f. setiferum',
#    'Elytrigia repens subsp. pseudocaesia',
#    'Agropyron repens var. pubescens',
#    'Elymus neogaeus',
#    'Agropyron repens f. pectinatum',
#    'Elytrigia repens subsp. caesia',
#    'Triticum ramosum',
#    'Elytrigia repens subsp. koeleri',
#    'Triticum multiflorum',
#    'Elytrigia repens var. vaillantiana',
#    'Triticum imbricatum',
#    'Triticum biflorum',
#    'Triticum dumetorum',
#    'Zeia canina',
#    'Agropyron pauciflorum',
#    'Zeia biflora',
#    'Triticum donianum',
#    'Elytrigia canina',
#    'Agropyron caninum f. subglaucum',
#    'Elymus helveticus',
#    'Agropyron caninum f. submuticum',
#    'Elymus caninus var. donianus',
#    'Elymus caninus subsp. biflorus',
#    'Roegneria canina',
#    'Agropyron rupestre',
#    'Brachypodium biflorum',
#    'Triticum alpinum',
#    'Triticum alpestre',
#    'Agropyron sepium',
#    'Goulardia biflora',
#    'Goulardia canina',
#    'Elymus donianus',
#    'Agropyron pseudocaninum',
#    'Triticum pseudocaninum',
#    'Festuca nutans',
#    'Roegneria tuskaulensis',
#    'Triticum caninum',
#    'Agropyron biflorum',
#    'Agropyron abchazicum',
#    'Agropyron caninum var. behmii',
#    'Roegneria behmii',
#    'Agropyron alpinum',
#    'Roegneria doniana',
#    'Elymus longispicatus',
#    'Elymus caninus var. behmii',
#    'Elymus caninus var. muticus',
#    'Agropyron donianum',
#    'Elymus caninus subsp. donianus'],
#   'genus': 'Elymus',
#   'family': 'Poaceae',
#   'links': {'self': '/api/v1/species/elymus-repens',
#    'plant': '/api/v1/plants/elymus-repens',
#    'genus': '/api/v1/genus/elymus'}},
#  {'id': 149582,
#   'common_name': 'Oxeye daisy',
#   'slug': 'leucanthemum-vulgare',
#   'scientific_name': 'Leucanthemum vulgare',
#   'year': 1779,
#   'bibliography': 'Fl. Franç. 2: 137 (1779)',
#   'author': 'L.',
#   'status': 'accepted',
#   'rank': 'species',
#   'family_common_name': 'Aster family',
#   'genus_id': 1747,
#   'image_url': 'https://bs.plantnet.org/image/o/cc03c870f80172d0faf20d14ff8291d050afd13f',
#   'synonyms': ['Leucanthemum praecox var. rhodopaeum',
#    'Leucanthemum vulgare subsp. heterophyllum',
#    'Pyrethrum leucanthemum',
#    'Leucanthemum tubuliflorum',
#    'Chrysanthemum lanceolatum',
#    'Leucanthemum vulgare subsp. alpicola',
#    'Chrysanthemum leucanthemum var. leucanthemum',
#    'Tanacetum serotinum',
#    'Leucanthemum vulgare var. pinnatifidum',
#    'Leucanthemum leucanthemum',
#    'Chrysanthemum leucanthemum var. pinnatifidum',
#    'Chrysanthemum leucanthemum',
#    'Leucanthemum praecox',
#    'Tanacetum affine',
#    'Chamaemelum leucanthemum',
#    'Tanacetum leucanthemum',
#    'Matricaria leucanthemum',
#    'Chrysanthemum alpicola',
#    'Chrysanthemum dentatum',
#    'Leucanthemum vulgare subsp. multicaule',
#    'Leucanthemum praecox var. autumnale',
#    'Bellis major',
#    'Chrysanthemum sylvestre',
#    'Tanacetum auriculatum',
#    'Leucanthemum praecox var. alpicola',
#    'Tanacetum coronulatum',
#    'Chrysanthemum pratense',
#    'Tanacetum alpinum'],
#   'genus': 'Leucanthemum',
#   'family': 'Asteraceae',
#   'links': {'self': '/api/v1/species/leucanthemum-vulgare',
#    'plant': '/api/v1/plants/leucanthemum-vulgare',
#    'genus': '/api/v1/genus/leucanthemum'}},
#  {'id': 172188,
#   'common_name': 'Western brackenfern',
#   'slug': 'pteridium-aquilinum',
#   'scientific_name': 'Pteridium aquilinum',
#   'year': 1879,
#   'bibliography': 'O. Kersten, Reis. Ost-Afr. 3(3):11.  1879',
#   'author': 'L.',
#   'status': 'accepted',
#   'rank': 'species',
#   'family_common_name': 'Bracken Fern family',
#   'genus_id': 5715,
#   'image_url': 'https://bs.plantnet.org/image/o/eaa1e69cec1d11160144f54a337e66dbf5ab8a45',
#   'synonyms': ['Pteridium aquilinum var. lanuginosum',
#    'Pteris firma',
#    'Pteris heredia',
#    'Pteridium tauricum',
#    'Pteridium heredia',
#    'Allosorus tauricus',
#    'Paesia aquilina',
#    'Pteris aquilina',
#    'Pteris foemina',
#    'Cincinalis aquilina',
#    'Filix aquilina',
#    'Pteridium pinetorum subsp. osmundaceum',
#    'Ornithopteris aquilina',
#    'Pteridium aquilinum subsp. typicum',
#    'Cincinalis gleditschii',
#    'Pteridium aquilinum subsp. heredia',
#    'Pteridium aquilinum f. pubescens',
#    'Allosorus aquilinus',
#    'Filix-foemina vulgaris',
#    'Pteris aquilina var. transcaucasica',
#    'Allosorus acutifolius',
#    'Pteridium aquilinum subsp. atlanticum',
#    'Pteridium aquilinum subsp. fulvum',
#    'Pteridium aquilinum subsp. tauricum',
#    'Allosorus villosus',
#    'Pteridium pinetorum subsp. sibiricum',
#    'Pteridium ceheginense',
#    'Pteris brevipes',
#    'Pteris nudicaulis',
#    'Polypodium austriacum',
#    'Pteris borealis',
#    'Pteridium aquilinum subsp. brevipes',
#    'Asplenium aquilinum',
#    'Filix-foemina aquilina',
#    'Pteridium aquilinum subsp. osmundaceum',
#    'Onychium capense',
#    'Cincinalis lanuginosa',
#    'Pteridium aquilinum var. osmundaceum',
#    'Eupteris aquilina',
#    'Pteridium pinetorum subsp. sajanense'],
#   'genus': 'Pteridium',
#   'family': 'Dennstaedtiaceae',
#   'links': {'self': '/api/v1/species/pteridium-aquilinum',
#    'plant': '/api/v1/plants/pteridium-aquilinum',
#    'genus': '/api/v1/genus/pteridium'}},
#  {'id': 130506,
#   'common_name': 'Male fern',
#   'slug': 'dryopteris-filix-mas',
#   'scientific_name': 'Dryopteris filix-mas',
#   'year': 1834,
#   'bibliography': 'Gen. Fil.: pl. 9 (1834)',
#   'author': 'L.',
#   'status': 'accepted',
#   'rank': 'species',
#   'family_common_name': 'Polypody family',
#   'genus_id': 572,
#   'image_url': 'https://bs.plantnet.org/image/o/3b39ae0843fb6bacb96cee2d7342bb84144311d5',
#   'synonyms': ['Polypodium filix-mas',
#    'Polystichum filix-mas',
#    'Aspidium filix-mas',
#    'Filix filix-mas',
#    'Tectaria filix-mas',
#    'Nephrodium filix-mas',
#    'Aspidium nemorale',
#    'Thelypteris filix-mas',
#    'Lastrea filix-mas'],
#   'genus': 'Dryopteris',
#   'family': 'Polypodiaceae',
#   'links': {'self': '/api/v1/species/dryopteris-filix-mas',
#    'plant': '/api/v1/plants/dryopteris-filix-mas',
#    'genus': '/api/v1/genus/dryopteris'}},
#  {'id': 167021,
#   'common_name': 'Aleppo pine',
#   'slug': 'pinus-halepensis',
#   'scientific_name': 'Pinus halepensis',
#   'year': 1768,
#   'bibliography': 'Gard. Dict. ed. 8: n.º 8 (1768)',
#   'author': 'L.',
#   'status': 'accepted',
#   'rank': 'species',
#   'family_common_name': 'Pine family',
#   'genus_id': 5,
#   'image_url': 'https://bs.plantnet.org/image/o/adc0540c6d0465d62ec203f878eef234f5df7609',
#   'synonyms': ['Pinus genuensis',
#    'Pinus halepensis var. ceciliae',
#    'Pinus pseudohalepensis',
#    'Pinus paroliniana',
#    'Pinus arabica',
#    'Pinus hispanica',
#    'Pinus hierosolimitana',
#    'Pinus parolinii',
#    'Pinus abasica',
#    'Pinus ceciliae',
#    'Pinus halepensis subsp. ceciliae',
#    'Pinus loiseleuriana',
#    'Pinus carica',
#    'Pinus saportae',
#    'Pinus halepensis var. pendula',
#    'Pinus colchica',
#    'Pinus penicillus'],
#   'genus': 'Pinus',
#   'family': 'Pinaceae',
#   'links': {'self': '/api/v1/species/pinus-halepensis',
#    'plant': '/api/v1/plants/pinus-halepensis',
#    'genus': '/api/v1/genus/pinus'}},
#  {'id': 107095,
#   'common_name': 'Silverweed cinquefoil',
#   'slug': 'argentina-anserina',
#   'scientific_name': 'Argentina anserina',
#   'year': 1898,
#   'bibliography': 'Monogr. N. Amer. Potent. 2: 159 (1898)',
#   'author': 'L.',
#   'status': 'accepted',
#   'rank': 'species',
#   'family_common_name': 'Rose family',
#   'genus_id': 617,
#   'image_url': 'https://bs.plantnet.org/image/o/c2965e0cbf932de8282e2458f9e72812230600ba',
#   'synonyms': ['Potentilla anserina',
#    'Potentilla anserina var. sericea',
#    'Argentina argentea',
#    'Argentina anserina var. concolor',
#    'Potentilla anserina var. viridis',
#    'Fragaria anserina',
#    'Potentilla anserina var. vulgaris',
#    'Argentina babcockiana',
#    'Potentilla anserina f. sericea',
#    'Tormentilla anserina',
#    'Argentina vulgaris',
#    'Potentilla argentina',
#    'Dactylophyllum anserina',
#    'Dasiphora anserina',
#    'Potentilla anserina var. concolor',
#    'Potentilla anserina subsp. anserina',
#    'Potentilla anserina var. yukonensis',
#    'Potentilla egedii subsp. yukonensis',
#    'Potentilla anserina subsp. yukonensis',
#    'Potentilla yukonensis',
#    'Argentina subarctica'],
#   'genus': 'Argentina',
#   'family': 'Rosaceae',
#   'links': {'self': '/api/v1/species/argentina-anserina',
#    'plant': '/api/v1/plants/argentina-anserina',
#    'genus': '/api/v1/genus/argentina'}},
#  {'id': 114923,
#   'common_name': 'Hedge false bindweed',
#   'slug': 'calystegia-sepium',
#   'scientific_name': 'Calystegia sepium',
#   'year': 1810,
#   'bibliography': 'Prodr. Fl. Nov. Holland.: 483 (1810)',
#   'author': 'L.',
#   'status': 'accepted',
#   'rank': 'species',
#   'family_common_name': 'Morning-glory family',
#   'genus_id': 1384,
#   'image_url': 'https://bs.plantnet.org/image/o/9d6e2c7bd6640934a03a7b983d44944e325d8062',
#   'synonyms': ['Convolvulus sepium',
#    'Convolvulus sepincola',
#    'Convolvulus acutifolius',
#    'Convolvulus maximiliani',
#    'Convolvulus laetus',
#    'Calystegia sepium var. maritima',
#    'Calystegia maximiliana',
#    'Convolvulus major',
#    'Convolvulus crassipes',
#    'Calystegia obtusa',
#    'Calystegia sepium subsp. baltica'],
#   'genus': 'Calystegia',
#   'family': 'Convolvulaceae',
#   'links': {'self': '/api/v1/species/calystegia-sepium',
#    'plant': '/api/v1/plants/calystegia-sepium',
#    'genus': '/api/v1/genus/calystegia'}},
#  {'id': 171280,
#   'common_name': 'Sweet cherry',
#   'slug': 'prunus-avium',
#   'scientific_name': 'Prunus avium',
#   'year': 1755,
#   'bibliography': 'Fl. Suec., ed. 2: 165 (1755)',
#   'author': 'L.',
#   'status': 'accepted',
#   'rank': 'species',
#   'family_common_name': 'Rose family',
#   'genus_id': 5629,
#   'image_url': 'https://bs.plantnet.org/image/o/cfa5920450191946aa0b400f08a8763e108a4641',
#   'synonyms': ['Cerasus avium',
#    'Prunus nigricans',
#    'Prunus cerasus var. juliana',
#    'Prunus cerasus var. dulcis',
#    'Cerasus avicularis',
#    'Cerasus avium var. albida',
#    'Cerasus pallida',
#    'Druparia avium',
#    'Cerasus varia',
#    'Prunus avium subsp. juliana',
#    'Prunus duracina',
#    'Prunus varia',
#    'Prunus cerasus var. bigarella',
#    'Prunus cerasus var. duracina',
#    'Cerasus anglica',
#    'Cerasus avium var. duracina',
#    'Prunus cerasus var. avium',
#    'Cerasus nigricans',
#    'Cerasus nigra',
#    'Cerasus dulcis',
#    'Cerasus avium var. juliana',
#    'Prunus cerasus'],
#   'genus': 'Prunus',
#   'family': 'Rosaceae',
#   'links': {'self': '/api/v1/species/prunus-avium',
#    'plant': '/api/v1/plants/prunus-avium',
#    'genus': '/api/v1/genus/prunus'}},
#  {'id': 1205139,
#   'common_name': 'Asplenium ladyfern',
#   'slug': 'athyrium-filix',
#   'scientific_name': 'Athyrium filix',
#   'year': None,
#   'bibliography': None,
#   'author': 'L.',
#   'status': 'accepted',
#   'rank': 'species',
#   'family_common_name': 'Spleenwort family',
#   'genus_id': 797,
#   'image_url': 'https://bs.plantnet.org/image/o/081e49b548661f596e399a5744a04b03a6581912',
#   'synonyms': [],
#   'genus': 'Athyrium',
#   'family': 'Aspleniaceae',
#   'links': {'self': '/api/v1/species/athyrium-filix',
#    'plant': '/api/v1/plants/athyrium-filix',
#    'genus': '/api/v1/genus/athyrium'}},
#  {'id': 1235562,
#   'common_name': 'White birch',
#   'slug': 'betula-pubescens',
#   'scientific_name': 'Betula pubescens',
#   'year': 1791,
#   'bibliography': 'Beitr. Naturk. 6: 98 (1791)',
#   'author': 'L.',
#   'status': 'accepted',
#   'rank': 'species',
#   'family_common_name': 'Birch family',
#   'genus_id': 970,
#   'image_url': 'https://bs.plantnet.org/image/o/8531ad6f5a55aba51e96361251eeb0ea2db80494',
#   'synonyms': ['Betula alba var. pubescens',
#    'Betula baicalia',
#    'Betula andreji',
#    'Betula jacutica',
#    'Betula concinna',
#    'Betula callosa',
#    'Betula sajanensis',
#    'Betula glutinosa',
#    'Betula alba subsp. pubescens',
#    'Betula odorata',
#    'Betula alba',
#    'Betula krylovii',
#    'Betula subarctica',
#    'Betula acuminata',
#    'Betula pubescens var. appressa',
#    'Betula glabra',
#    'Betula pontica',
#    'Betula pubescens f. hibernifolia',
#    'Betula borysthenica',
#    'Betula lenta',
#    'Betula ovata',
#    'Betula carpatica',
#    'Betula broccembergensis',
#    'Betula subarctica var. pojarkovae',
#    'Betula alba subsp. glutinosa',
#    'Betula pubescens f. rubra',
#    'Betula tricholepidea',
#    'Betula tomentosa',
#    'Betula macrostachya',
#    'Betula nigricans',
#    'Betula urticifolia',
#    'Betula pubescens f. columnaris',
#    'Betula ambigua',
#    'Betula virgata',
#    'Betula aurea',
#    'Betula asplenifolia',
#    'Betula sokolowii',
#    'Betula subodorata',
#    'Betula torfacea',
#    'Betula megaloptera',
#    'Betula alba var. glabrata',
#    'Betula canadensis',
#    'Betula × aurata var. rhombifolia',
#    'Betula major',
#    'Betula glauca',
#    'Betula dalecarlica',
#    'Betula rotundata',
#    'Betula microdontia',
#    'Betula rhombifolia',
#    'Betula stenocarpa',
#    'Betula platyodontia',
#    'Betula murithii',
#    'Betula hackelii',
#    'Betula coriifolia'],
#   'genus': 'Betula',
#   'family': 'Betulaceae',
#   'links': {'self': '/api/v1/species/betula-pubescens',
#    'plant': '/api/v1/plants/betula-pubescens',
#    'genus': '/api/v1/genus/betula'}},
#  {'id': 116345,
#   'common_name': 'Heath sedge',
#   'slug': 'carex-flacca',
#   'scientific_name': 'Carex flacca',
#   'year': 1771,
#   'bibliography': 'Spic. Fl. Lips., App.: 178 (1771)',
#   'author': 'L.',
#   'status': 'accepted',
#   'rank': 'species',
#   'family_common_name': 'Sedge family',
#   'genus_id': 1462,
#   'image_url': 'https://bs.plantnet.org/image/o/a07d1ccd6dd5e614707bc07585d198fed4a690e6',
#   'synonyms': ['Carex micheliana',
#    'Carex flacca f. tenuicula',
#    'Carex × petrae-furvae',
#    'Carex pubicarpa',
#    'Carex flacca f. castriferrei',
#    'Carex aspera',
#    'Carex thuringiaca',
#    'Trasus glaucus',
#    'Carex flacca subsp. praetutiana',
#    'Carex dinarica',
#    'Carex praetutiana',
#    'Carex nigrolutea',
#    'Carex trachycarpos',
#    'Carex genuensis',
#    'Carex claviformis',
#    'Carex stictocarpa',
#    'Carex pagesii',
#    'Carex ambleocarpa'],
#   'genus': 'Carex',
#   'family': 'Cyperaceae',
#   'links': {'self': '/api/v1/species/carex-flacca',
#    'plant': '/api/v1/plants/carex-flacca',
#    'genus': '/api/v1/genus/carex'}},
#  {'id': 137657,
#   'common_name': 'Glossy buckthorn',
#   'slug': 'frangula-alnus',
#   'scientific_name': 'Frangula alnus',
#   'year': 1768,
#   'bibliography': 'Gard. dict. ed. 8: <I>Frangula</I> no. 1.  1768',
#   'author': 'L.',
#   'status': 'accepted',
#   'rank': 'species',
#   'family_common_name': 'Buckthorn family',
#   'genus_id': 3055,
#   'image_url': 'https://bs.plantnet.org/image/o/09568bda13ff18487860da26ec87d7048fe53437',
#   'synonyms': ['Rhamnus frangula',
#    'Rhamnus autumnalis',
#    'Frangula sanguinea',
#    'Frangula nigra',
#    'Frangula vulgaris var. parvifolia',
#    'Rhamnus undulata',
#    'Rhamnus alnoides',
#    'Frangula vulgaris var. subrotunda',
#    'Rhamnus frangula var. subrotunda',
#    'Rhamnus nemoralis',
#    'Frangula atlantica',
#    'Frangula alnus subsp. saxatilis',
#    'Rhamnus sanguino',
#    'Rhamnus sanguinea',
#    'Frangula frangula',
#    'Frangula alnus var. elliptica',
#    'Frangula alnus var. prostrata',
#    'Frangula alnus subsp. sphagnicola',
#    'Frangula alnus var. angustifolia',
#    'Rhamnus frangula var. angustifolia',
#    'Rhamnus frangula subsp. columnaris'],
#   'genus': 'Frangula',
#   'family': 'Rhamnaceae',
#   'links': {'self': '/api/v1/species/frangula-alnus',
#    'plant': '/api/v1/plants/frangula-alnus',
#    'genus': '/api/v1/genus/frangula'}},
#  {'id': 1038693,
#   'common_name': 'Wood anemone',
#   'slug': 'anemonoides-nemorosa',
#   'scientific_name': 'Anemonoides nemorosa',
#   'year': 1973,
#   'bibliography': 'Folia Geobot. Phytotax. 8: 166 (1973)',
#   'author': 'L.',
#   'status': 'accepted',
#   'rank': 'species',
#   'family_common_name': 'Buttercup family',
#   'genus_id': 438,
#   'image_url': 'https://bs.plantnet.org/image/o/5e99297ccd0f697d33b853ec5e3013eb97a018da',
#   'synonyms': ['Anemone nemorosa',
#    'Anemonanthea nemorosa',
#    'Anemone nemorosa f. vulgaris',
#    'Pulsatilla nemorosa',
#    'Anemone nemorosa-alba',
#    'Anemanthus nemorosus',
#    'Anemone pentaphylla',
#    'Anemonidium nemorosum'],
#   'genus': 'Anemonoides',
#   'family': 'Ranunculaceae',
#   'links': {'self': '/api/v1/species/anemonoides-nemorosa',
#    'plant': '/api/v1/plants/anemonoides-nemorosa',
#    'genus': '/api/v1/genus/anemonoides'}},
#  {'id': 153104,
#   'common_name': 'Meadow campion',
#   'slug': 'silene-flos-cuculi',
#   'scientific_name': 'Silene flos-cuculi',
#   'year': 1982,
#   'bibliography': 'Willdenowia 12: 189 (1982)',
#   'author': 'L.',
#   'status': 'accepted',
#   'rank': 'species',
#   'family_common_name': 'Pink family',
#   'genus_id': 4327,
#   'image_url': 'https://bs.plantnet.org/image/o/54cde4c61064d894d2d9210cdb6d0337d291f0ba',
#   'synonyms': ['Lychnis flos-cuculi',
#    'Coronaria flos-cuculi',
#    'Agrostemma lusitanicum',
#    'Lychnis plumaria',
#    'Lychnis quadridentata',
#    'Agrostemma flos-cuculi',
#    'Floscuculi pratense',
#    'Lychnis laciniata',
#    'Lychnis laciniflora',
#    'Lychnis lusitanica',
#    'Lychnis cyrillii',
#    'Lychnis coccugosantha',
#    'Coccyganthe flos-cuculi',
#    'Silene cuculi',
#    'Coccyganthe pratensis'],
#   'genus': 'Silene',
#   'family': 'Caryophyllaceae',
#   'links': {'self': '/api/v1/species/silene-flos-cuculi',
#    'plant': '/api/v1/plants/silene-flos-cuculi',
#    'genus': '/api/v1/genus/silene'}},
#  {'id': 139784,
#   'common_name': 'Water mannagrass',
#   'slug': 'glyceria-fluitans',
#   'scientific_name': 'Glyceria fluitans',
#   'year': 1810,
#   'bibliography': 'Prodr. Fl. Nov. Holland.: 179 (1810)',
#   'author': 'L.',
#   'status': 'accepted',
#   'rank': 'species',
#   'family_common_name': 'Grass family',
#   'genus_id': 3218,
#   'image_url': 'https://bs.plantnet.org/image/o/ebed9cbd10da17f5b0843defe635b14942c2d2ff',
#   'synonyms': ['Festuca fluitans',
#    'Panicularia fluitans',
#    'Glyceria acuminata',
#    'Melica fluitans',
#    'Molinia fluitans',
#    'Molinia plicata',
#    'Poa fluitans',
#    'Glyceria integra',
#    'Glyceria fluitans var. islandica',
#    'Festucaria heisteri',
#    'Panicularia brachyphylla',
#    'Poa barrelieri',
#    'Glyceria denticulata'],
#   'genus': 'Glyceria',
#   'family': 'Poaceae',
#   'links': {'self': '/api/v1/species/glyceria-fluitans',
#    'plant': '/api/v1/plants/glyceria-fluitans',
#    'genus': '/api/v1/genus/glyceria'}},
#  {'id': 153004,
#   'common_name': 'Field woodrush',
#   'slug': 'luzula-campestris',
#   'scientific_name': 'Luzula campestris',
#   'year': 1805,
#   'bibliography': 'J. B. P. A. M. de Lamarck & A. P. de Candolle, Fl. franç. ed. 3, 3:161.  1805',
#   'author': 'L.',
#   'status': 'accepted',
#   'rank': 'species',
#   'family_common_name': 'Rush family',
#   'genus_id': 4321,
#   'image_url': 'https://bs.plantnet.org/image/o/ab30b7b483e521bcb26a1c2a66d2843593dbe66d',
#   'synonyms': ['Luzula vulgaris',
#    'Juncoides campestris var. vulgaris',
#    'Gymnodes campestris',
#    'Luzula subpilosa',
#    'Juncoides campestris',
#    'Juncus campestris',
#    'Luzula campestris var. vulgaris',
#    'Luciola campestris',
#    'Cyperella campestris',
#    'Juncoides campestre',
#    'Luzula campestris subsp. nevadensis',
#    'Luzula chabertii'],
#   'genus': 'Luzula',
#   'family': 'Juncaceae',
#   'links': {'self': '/api/v1/species/luzula-campestris',
#    'plant': '/api/v1/plants/luzula-campestris',
#    'genus': '/api/v1/genus/luzula'}},
#  {'id': 240413,
#   'common_name': 'Mouseear hawkweed',
#   'slug': 'pilosella-officinarum',
#   'scientific_name': 'Pilosella officinarum',
#   'year': 1754,
#   'bibliography': 'Königl. Akad. Wiss. Paris Anat. Abh. 5: 703 (1754)',
#   'author': 'L.',
#   'status': 'accepted',
#   'rank': 'species',
#   'family_common_name': 'Aster family',
#   'genus_id': 4838,
#   'image_url': 'https://bs.plantnet.org/image/o/44e695a74c98dbaff809fe95fd4bdb3a3874aa12',
#   'synonyms': ['Hieracium pilosella',
#    'Pilosella officinarum subsp. micradenia',
#    'Pilosella officinarum subsp. tricholepia',
#    'Hieracium kemulariae',
#    'Hieracium pilosella subsp. tricholepium',
#    'Hieracium melanops',
#    'Hieracium pilosella var. sedunense',
#    'Hieracium pilosella subsp. inalpestre',
#    'Hieracium pilosella subsp. microcephalum',
#    'Hieracium pilosella subsp. subcaulescens',
#    'Hieracium pilosella subsp. ermineum',
#    'Hieracium pilosella subsp. pachyanthum',
#    'Hieracium pilosella subsp. micradenium',
#    'Hieracium pilosella subsp. albomicans',
#    'Hieracium tricholepium',
#    'Hieracium pilosella subsp. angustissimum',
#    'Hieracium pilosella subsp. rigidistolonum',
#    'Hieracium pilosella subsp. coloratulum',
#    'Pilosella officinarum subsp. trichosoma',
#    'Hieracium pilosella subsp. calabrum',
#    'Hieracium pilosella subsp. parvulum',
#    'Hieracium pilosella var. serpens',
# ...
#   'author': 'L.',
#   'status': 'accepted',
#   'rank': 'species',
#   'family_common_name': 'Plantain family',
#   'genus_id': 3419,
#   'image_url': 'https://bs.plantnet.org/image/o/9d5978a3913b44db235286bd4d0e229129368af6',
#   'synonyms': ['Veronica didyma',
#    'Pocilla polita',
#    'Veronica thellungiana',
#    'Veronica nitidula',
#    'Veronica colocensis',
#    'Cardia didyma'],
#   'genus': 'Veronica',
#   'family': 'Plantaginaceae',
#   'links': {'self': '/api/v1/species/veronica-polita',
#    'plant': '/api/v1/plants/veronica-polita',
#    'genus': '/api/v1/genus/veronica'}},
#  {'id': 227821,
#   'common_name': None,
#   'slug': 'lepidocaryum-tenue',
#   'scientific_name': 'Lepidocaryum tenue',
#   'year': 1824,
#   'bibliography': 'Hist. Nat. Palm. 2: 51 (1824)',
#   'author': 'L.',
#   'status': 'accepted',
#   'rank': 'species',
#   'family_common_name': 'Palm family',
#   'genus_id': 8209,
#   'image_url': 'https://storage.googleapis.com/powop-assets/palmweb/palm_tc_110826_5_fullsize.jpg',
#   'synonyms': ['Mauritia tenuis',
#    'Mauritia quadripartita',
#    'Lepidocaryum tessmannii',
#    'Lepidocaryum allenii'],
#   'genus': 'Lepidocaryum',
#   'family': 'Arecaceae',
#   'links': {'self': '/api/v1/species/lepidocaryum-tenue',
#    'plant': '/api/v1/plants/lepidocaryum-tenue',
#    'genus': '/api/v1/genus/lepidocaryum'}},
#  {'id': 116285,
#   'common_name': 'Grassland sedge',
#   'slug': 'carex-divulsa',
#   'scientific_name': 'Carex divulsa',
#   'year': 1787,
#   'bibliography': 'W.Withering, Bot. Arr. Brit. Pl. ed. 2, 2: 1035 (1787)',
#   'author': 'L.',
#   'status': 'accepted',
#   'rank': 'species',
#   'family_common_name': 'Sedge family',
#   'genus_id': 1462,
#   'image_url': 'https://bs.plantnet.org/image/o/2186220602ac885271db0267a7e1a7ee91dba410',
#   'synonyms': ['Carex nemorosa',
#    'Vignea divulsa',
#    'Carex persica',
#    'Vignea guestphalica',
#    'Caricina divulsa',
#    'Carex divulsa f. angustifolia',
#    'Vignea virens',
#    'Carex muricata var. virens',
#    'Carex subramosa',
#    'Carex virens var. divulsa',
#    'Carex polyphylla &',
#    'Vignea persica',
#    'Carex polyphylla'],
#   'genus': 'Carex',
#   'family': 'Cyperaceae',
#   'links': {'self': '/api/v1/species/carex-divulsa',
#    'plant': '/api/v1/plants/carex-divulsa',
#    'genus': '/api/v1/genus/carex'}},
#  {'id': 182127,
#   'common_name': 'Blessed milkthistle',
#   'slug': 'silybum-marianum',
#   'scientific_name': 'Silybum marianum',
#   'year': 1791,
#   'bibliography': 'Fruct. Sem. Pl. 2: 378 (1791)',
#   'author': 'L.',
#   'status': 'accepted',
#   'rank': 'species',
#   'family_common_name': 'Aster family',
#   'genus_id': 6223,
#   'image_url': 'https://bs.plantnet.org/image/o/ea4788679cf0d800ae182407d8881ed7acedb021',
#   'synonyms': ['Carduus marianus',
#    'Mariana mariana',
#    'Centaurea dalmatica',
#    'Carthamus maculatum',
#    'Carduus mariae',
#    'Silybum maculatum',
#    'Mariana lactea',
#    'Silybum mariae',
#    'Mariacantha maculosa',
#    'Silybum marianum var. albiflorum',
#    'Carduus lactifolius',
#    'Carduus versicolor',
#    'Silybum leucanthum',
#    'Carthamus maculatus',
#    'Silybum intermedium',
#    'Silybum pygmaeum',
#    'Acosta dalmatica',
#    'Cirsium maculatum'],
#   'genus': 'Silybum',
#   'family': 'Asteraceae',
#   'links': {'self': '/api/v1/species/silybum-marianum',
#    'plant': '/api/v1/plants/silybum-marianum',
#    'genus': '/api/v1/genus/silybum'}},
#  {'id': 570344,
#   'common_name': 'Australian blackthorn',
#   'slug': 'bursaria-spinosa',
#   'scientific_name': 'Bursaria spinosa',
#   'year': 1797,
#   'bibliography': 'Icon. 4: 30 (1797)',
#   'author': 'L.',
#   'status': 'accepted',
#   'rank': 'species',
#   'family_common_name': 'Pittosporum family',
#   'genus_id': 12466,
#   'image_url': 'https://bs.plantnet.org/image/o/4dbdd05a7beacb72f10638b67f6bcdca13233e75',
#   'synonyms': ['Bursaria spinosa var. macrophylla',
#    'Cyrilla spinosa',
#    'Bursaria spinosa var. pantonii',
#    'Bursaria spinosa var. microphylla',
#    'Itea spinosa',
#    'Bursaria spinosa var. australis',
#    'Bursaria pantonii',
#    'Bursaria spinosa var. lanceolata'],
#   'genus': 'Bursaria',
#   'family': 'Pittosporaceae',
#   'links': {'self': '/api/v1/species/bursaria-spinosa',
#    'plant': '/api/v1/plants/bursaria-spinosa',
#    'genus': '/api/v1/genus/bursaria'}},
#  {'id': 153206,
#   'common_name': 'Inundated clubmoss',
#   'slug': 'lycopodiella-inundata',
#   'scientific_name': 'Lycopodiella inundata',
#   'year': 1964,
#   'bibliography': 'Preslia 36: 21 (1964)',
#   'author': 'L.',
#   'status': 'accepted',
#   'rank': 'species',
#   'family_common_name': 'Club-moss family',
#   'genus_id': 4331,
#   'image_url': 'https://bs.plantnet.org/image/o/25b9748cf3f629e5a27f077d307f77dc7fe2af08',
#   'synonyms': ['Lycopodium inundatum', 'Lepidotis inundata'],
#   'genus': 'Lycopodiella',
#   'family': 'Lycopodiaceae',
#   'links': {'self': '/api/v1/species/lycopodiella-inundata',
#    'plant': '/api/v1/plants/lycopodiella-inundata',
#    'genus': '/api/v1/genus/lycopodiella'}},
#  {'id': 108770,
#   'common_name': 'Green spleenwort',
#   'slug': 'asplenium-viride',
#   'scientific_name': 'Asplenium viride',
#   'year': 1762,
#   'bibliography': 'Fl. Angl.: 385 (1762)',
#   'author': 'L.',
#   'status': 'accepted',
#   'rank': 'species',
#   'family_common_name': 'Spleenwort family',
#   'genus_id': 747,
#   'image_url': 'https://bs.plantnet.org/image/o/3bc8b704391a0b12b76509bfb87f49aea16b5a94',
#   'synonyms': ['Asplenium trichomanes-ramosum',
#    'Trichomanes viride',
#    'Chamaefilix ramosa',
#    'Asplenium vogesiacum',
#    'Asplenium viride subsp. incisum',
#    'Asplenium viride var. robustum'],
#   'genus': 'Asplenium',
#   'family': 'Aspleniaceae',
#   'links': {'self': '/api/v1/species/asplenium-viride',
#    'plant': '/api/v1/plants/asplenium-viride',
#    'genus': '/api/v1/genus/asplenium'}},
#  {'id': 952928,
#   'common_name': None,
#   'slug': 'elymus-athericus',
#   'scientific_name': 'Elymus athericus',
#   'year': 1983,
#   'bibliography': 'Lejeunia, n.s., 110: 57 (1983)',
#   'author': 'L.',
#   'status': 'accepted',
#   'rank': 'species',
#   'family_common_name': 'Grass family',
#   'genus_id': 2703,
#   'image_url': 'https://d2seqvvyy3b8p2.cloudfront.net/1925a596491ac2ecb3e0b296e6a6bd9a.jpg',
#   'synonyms': ['Agropyron littorale',
#    'Elytrigia atherica',
#    'Elytrigia laxula',
#    'Elymus pycnanthus var. setiger',
#    'Elytrigia atherica f. setigera',
#    'Agropyron concinnum',
#    'Triticum athericum',
#    'Elymus laxulus',
#    'Triticum litorale',
#    'Agropyron athericum',
#    'Psammopyrum athericum',
#    'Elytrigia littoralis'],
#   'genus': 'Elymus',
#   'family': 'Poaceae',
#   'links': {'self': '/api/v1/species/elymus-athericus',
#    'plant': '/api/v1/plants/elymus-athericus',
#    'genus': '/api/v1/genus/elymus'}},
#  {'id': 169878,
#   'common_name': 'Northern hollyfern',
#   'slug': 'polystichum-lonchitis',
#   'scientific_name': 'Polystichum lonchitis',
#   'year': 1799,
#   'bibliography': 'Tent. Fl. Germ. 3(1): 71 (1799)',
#   'author': 'L.',
#   'status': 'accepted',
#   'rank': 'species',
#   'family_common_name': 'Polypody family',
#   'genus_id': 2266,
#   'image_url': 'https://bs.plantnet.org/image/o/0f9b4988b38940d2344da74f8dff60145abb5988',
#   'synonyms': ['Aspidium asperum',
#    'Dryopteris lonchitis',
#    'Hypopeltis lonchitis',
#    'Aetopteron lonchitis',
#    'Polystichum lonchitis f. marginale',
#    'Aspidium lonchitis',
#    'Polypodium lonchitis',
#    'Polystichum asperum'],
#   'genus': 'Polystichum',
#   'family': 'Polypodiaceae',
#   'links': {'self': '/api/v1/species/polystichum-lonchitis',
#    'plant': '/api/v1/plants/polystichum-lonchitis',
#    'genus': '/api/v1/genus/polystichum'}},
#  {'id': 143188,
#   'common_name': 'Seaside sandplant',
#   'slug': 'honckenya-peploides',
#   'scientific_name': 'Honckenya peploides',
#   'year': 1783,
#   'bibliography': 'Neues Mag. Aerzte 5: 206 (1783)',
#   'author': 'L.',
#   'status': 'accepted',
#   'rank': 'species',
#   'family_common_name': 'Pink family',
#   'genus_id': 3607,
#   'image_url': 'https://bs.plantnet.org/image/o/6ea0a23c3b5417e5f08565d5a751e7fc88af216c',
#   'synonyms': ['Arenaria peploides',
#    'Arenaria peploides f. lamoureuxii',
#    'Cerastium succulentum',
#    'Arenaria portulacea',
#    'Ammonalia peploides',
#    'Ammodenia peploides',
#    'Halianthus peploides',
#    'Honckenya maritima',
#    'Arenaria peploides var. diffusa',
#    'Honckenya frigida',
#    'Minuartia peploides subsp. latifolia',
#    'Arenaria sitchensis',
#    'Ammodenia peploides var. diffusa',
#    'Minuartia peploides',
#    'Ammodenia peploides subsp. maritima',
#    'Ammodenia maritima',
#    'Holosteum succulentum',
#    'Adenarium maritimum',
#    'Adenarium marinum',
#    'Minuartia peploides var. diffusa',
#    'Merckia peploides',
#    'Arenaria littoralis',
#    'Adenarium peploides',
#    'Honckenya peploides var. latifolia',
#    'Honckenya diffusa',
#    'Honckenya peploides var. diffusa',
#    'Alsine peploides'],
#   'genus': 'Honckenya',
#   'family': 'Caryophyllaceae',
#   'links': {'self': '/api/v1/species/honckenya-peploides',
#    'plant': '/api/v1/plants/honckenya-peploides',
#    'genus': '/api/v1/genus/honckenya'}},
#  {'id': 146779,
#   'common_name': 'Sharpleaf cancerwort',
#   'slug': 'kickxia-elatine',
#   'scientific_name': 'Kickxia elatine',
#   'year': 1827,
#   'bibliography': 'Fl. Belg.: 35 (1827)',
#   'author': 'L.',
#   'status': 'accepted',
#   'rank': 'species',
#   'family_common_name': 'Plantain family',
#   'genus_id': 3888,
#   'image_url': 'https://bs.plantnet.org/image/o/ce8421114b03f9624ae674ed9c9b02a33fe3e2e7',
#   'synonyms': ['Linaria elatine',
#    'Antirrhinum elatine',
#    'Elatine hastata',
#    'Linaria auriculata',
#    'Anarrhinum elatum',
#    'Linaria × brebissonii',
#    'Antirrhinum auriculatum',
#    'Tursitis elatine',
#    'Antirrhinum cymbalaria',
#    'Tursitis filifera',
#    'Tursitis flexuosa',
#    'Linaria commutata',
#    'Antirrhinum elatiniflorum',
#    'Cymbalaria commuta',
#    'Linaria crenifolia',
#    'Elatinoides elatine',
#    'Simbuleta elata',
#    'Cymbalaria elatine'],
#   'genus': 'Kickxia',
#   'family': 'Plantaginaceae',
#   'links': {'self': '/api/v1/species/kickxia-elatine',
#    'plant': '/api/v1/plants/kickxia-elatine',
#    'genus': '/api/v1/genus/kickxia'}},
#  {'id': 106589,
#   'common_name': 'Woolly burdock',
#   'slug': 'arctium-tomentosum',
#   'scientific_name': 'Arctium tomentosum',
#   'year': 1768,
#   'bibliography': 'Gard. Dict. ed. 8: n.º 3 (1768)',
#   'author': 'L.',
#   'status': 'accepted',
#   'rank': 'species',
#   'family_common_name': 'Aster family',
#   'genus_id': 588,
#   'image_url': 'https://bs.plantnet.org/image/o/caffbfbc018c3798d28607ef04010d8cde7a64c7',
#   'synonyms': ['Arctium leptophyllum',
#    'Lappa tomentosa',
#    'Arctium lappa var. tomentosum'],
#   'genus': 'Arctium',
#   'family': 'Asteraceae',
#   'links': {'self': '/api/v1/species/arctium-tomentosum',
#    'plant': '/api/v1/plants/arctium-tomentosum',
#    'genus': '/api/v1/genus/arctium'}},
#  {'id': 162791,
#   'common_name': 'Dallisgrass',
#   'slug': 'paspalum-dilatatum',
#   'scientific_name': 'Paspalum dilatatum',
#   'year': 1804,
#   'bibliography': 'J.B.A.M.de Lamarck, Encycl. 5: 35 (1804)',
#   'author': 'L.',
#   'status': 'accepted',
#   'rank': 'species',
#   'family_common_name': 'Grass family',
#   'genus_id': 2451,
#   'image_url': 'https://bs.plantnet.org/image/o/4d598e0790de0b4edd515714dcd3c775d034c932',
#   'synonyms': ['Paspalum pedunculare',
#    'Paspalum ovatum',
#    'Paspalum dilatatum f. paucispica',
#    'Paspalum selloi',
#    'Paspalum moluccanum',
#    'Paspalum ovatum var. grandiflorum',
#    'Digitaria dilatata',
#    'Paspalum platense',
#    'Paspalum dilatatum var. sacchariferum',
#    'Panicum platense',
#    'Paspalum dilatatum var. decumbens',
#    'Paspalum dilatatum subsp. flavescens'],
#   'genus': 'Paspalum',
#   'family': 'Poaceae',
#   'links': {'self': '/api/v1/species/paspalum-dilatatum',
#    'plant': '/api/v1/plants/paspalum-dilatatum',
#    'genus': '/api/v1/genus/paspalum'}},
#  {'id': 191969,
#   'common_name': 'Mung bean',
#   'slug': 'vigna-radiata',
#   'scientific_name': 'Vigna radiata',
#   'year': 1954,
#   'bibliography': 'Fl. Congo Belge 6: 286 (1954)',
#   'author': 'L.',
#   'status': 'accepted',
#   'rank': 'species',
#   'family_common_name': 'Pea family',
#   'genus_id': 6303,
#   'image_url': 'https://bs.plantnet.org/image/o/0457e52a60ae8a99c399730f8d3719b937c37f13',
#   'synonyms': ['Phaseolus radiatus',
#    'Pueraria chanetii',
#    'Azukia radiata',
#    'Phaseolus aureus',
#    'Phaseolus trinervius',
#    'Vigna perrieriana',
#    'Phasellus roseus',
#    'Phasellus farinosus',
#    'Vigna brachycarpa',
#    'Phasellus lanatus',
#    'Vigna trinervia',
#    'Phaseolus farinosus',
#    'Phaseolus bundoo',
#    'Phaseolus opisotrichus',
#    'Phaseolus citrinus',
#    'Rudua aurea',
#    'Phaseolus abyssinicus'],
#   'genus': 'Vigna',
#   'family': 'Fabaceae',
#   'links': {'self': '/api/v1/species/vigna-radiata',
#    'plant': '/api/v1/plants/vigna-radiata',
#    'genus': '/api/v1/genus/vigna'}},
#  {'id': 641928,
#   'common_name': 'Spiny broom',
#   'slug': 'calicotome-villosa',
#   'scientific_name': 'Calicotome villosa',
#   'year': 1808,
#   'bibliography': 'Neues J. Bot. 2(2): 51 (1808)',
#   'author': 'L.',
#   'status': 'accepted',
#   'rank': 'species',
#   'family_common_name': 'Pea family',
#   'genus_id': 13040,
#   'image_url': 'https://bs.plantnet.org/image/o/6032fde46086a376650901a94fea7aab2277684f',
#   'synonyms': ['Cytisus laniger',
#    'Genista lanigera',
#    'Spartium lanigerum',
#    'Spartium villosum',
#    'Lygoplis villosum',
#    'Laburnum lanigerum',
#    'Cytisus preslii'],
#   'genus': 'Calicotome',
#   'family': 'Fabaceae',
#   'links': {'self': '/api/v1/species/calicotome-villosa',
#    'plant': '/api/v1/plants/calicotome-villosa',
#    'genus': '/api/v1/genus/calicotome'}},
#  {'id': 131643,
#   'common_name': 'Fewflower spikerush',
#   'slug': 'eleocharis-quinqueflora',
#   'scientific_name': 'Eleocharis quinqueflora',
#   'year': 1949,
#   'bibliography': 'Mitt. Thüring. Bot. Ges. 1: 89 (1949)',
#   'author': 'L.',
#   'status': 'accepted',
#   'rank': 'species',
#   'family_common_name': 'Sedge family',
#   'genus_id': 2672,
#   'image_url': None,
#   'synonyms': ['Scirpus campestris',
#    'Eleocharis pauciflora',
#    'Scirpus quinqueflorus',
#    'Scirpus pauciflorus',
#    'Eleocharis pauciflora var. fernaldii',
#    'Cyperus pauciflorus',
#    'Eleocharis meridionalis',
#    'Eleocharis atacamensis',
#    'Eleocharis obscura',
#    'Scirpus graecus',
#    'Trichophorum pauciflorum',
#    'Eleocharis vierhapperi',
#    'Baeothryon halleri',
#    'Scirpus sepium',
#    'Isolepis andina',
#    'Eleocharis czernjajevi',
#    'Scirpus pauciflorus var. fernaldii',
#    'Eleocharis quinqueflora subsp. meridionalis',
#    'Eleocharis fernaldii',
#    'Trichophorum vierhapperi',
#    'Limnochloa baeothryon',
#    'Clavula boeotryon',
#    'Limnochloa pauciflora',
#    'Scirpus baeothryon',
#    'Baeothryon pauciflorum',
#    'Scirpus cespitosus',
#    'Eleocharis baeothryon',
#    'Scirpus atacamensis',
#    'Eleocharis quinqueflora subsp. fernaldii'],
#   'genus': 'Eleocharis',
#   'family': 'Cyperaceae',
#   'links': {'self': '/api/v1/species/eleocharis-quinqueflora',
#    'plant': '/api/v1/plants/eleocharis-quinqueflora',
#    'genus': '/api/v1/genus/eleocharis'}},
#  {'id': 409980,
#   'common_name': 'Woolly thistle',
#   'slug': 'cirsium-eriophorum',
#   'scientific_name': 'Cirsium eriophorum',
#   'year': 1771,
#   'bibliography': 'Fl. Carniol., ed. 2, 2: 130 (1771)',
#   'author': 'L.',
#   'status': 'accepted',
#   'rank': 'species',
#   'family_common_name': 'Aster family',
#   'genus_id': 1787,
#   'image_url': 'https://bs.plantnet.org/image/o/723f243bd0d20ff006a4f0799fab593eecc97cb5',
#   'synonyms': ['Cirsium ligulare var. bosniacum',
#    'Tetralix eriophora',
#    'Cynara eriocephala',
#    'Carduus tomentosus',
#    'Cnicus velenowskyi',
#    'Cirsium longebracteatum',
#    'Cirsium velenowskyi',
#    'Carduus spurius',
#    'Cirsium eriophorum subsp. degenii',
#    'Cirsium corbariense',
#    'Cirsium eriophorum subsp. chodatii',
#    'Cirsium vandasii',
#    'Cirsium chodatii',
#    'Cnicus eriophorus',
#    'Cirsium eriophorum var. bosniacum',
#    'Cirsium insubricum',
#    'Cirsium eriophorum var. costae',
#    'Cirsium corbariense var. costae'],
#   'genus': 'Cirsium',
#   'family': 'Asteraceae',
#   'links': {'self': '/api/v1/species/cirsium-eriophorum',
#    'plant': '/api/v1/plants/cirsium-eriophorum',
#    'genus': '/api/v1/genus/cirsium'}}]

# %%
for plant in plants:
    if plant['bibliography'] != None and plant['bibliography'].startswith('Sp. Pl.'):
            plant['author'] = 'L.'

# %% [markdown]
# <details>
#     <summary>
#         Answer
#     </summary>
#
# ```python
# for plant in plants:
#     try:
#         if plant['bibliography'].startswith('Sp. Pl.'):
#             plant['author'] = 'L.'
#     except:
#         continue
#
#
# or
#
#
# for plant in plants:
#     if plant['bibliography'] != None and plant['bibliography'].startswith('Sp. Pl.'):
#             plant['author'] = 'L.'
# ```
# </details>

# %% [markdown]
# # Teaser: Bringing in `pandas`: Back to Synonyms

# %% [markdown]
# Let's take advantage of the DataFrame tools from `pandas`:

# %%
plants_df = pd.DataFrame(plants)

# %%
plants_df.head()
# Out:
#        id          common_name                  slug       scientific_name  \
# 0  678281        Evergreen oak  quercus-rotundifolia  Quercus rotundifolia
# 1  190500      Stinging nettle         urtica-dioica         Urtica dioica
# 2  126957         Orchardgrass    dactylis-glomerata    Dactylis glomerata
# 3  167888  Narrowleaf plantain   plantago-lanceolata   Plantago lanceolata
# 4  173327          English oak         quercus-robur         Quercus robur
#
#      year           bibliography author    status     rank family_common_name  \
# 0  1785.0  Encycl. 1: 723 (1785)   Lam.  accepted  species       Beech family
# 1  1753.0    Sp. Pl.: 984 (1753)     L.  accepted  species      Nettle family
# 2  1753.0     Sp. Pl.: 71 (1753)     L.  accepted  species       Grass family
# 3  1753.0    Sp. Pl.: 113 (1753)     L.  accepted  species    Plantain family
# 4  1753.0    Sp. Pl.: 996 (1753)     L.  accepted  species       Beech family
#
#    genus_id                                          image_url  \
# 0      5778  https://bs.plantnet.org/image/o/1a03948baf0300...
# 1      1028  https://bs.plantnet.org/image/o/85256a1c2c098e...
# 2      2284  https://bs.plantnet.org/image/o/428f40dadfa028...
# 3      5418  https://bs.plantnet.org/image/o/78a8374f009e6e...
# 4      5778  https://bs.plantnet.org/image/o/2292b670683abd...
#
#                                             synonyms     genus  \
# 0  [Quercus lyauteyi, Quercus rotundifolia f. cra...   Quercus
# 1  [Urtica major, Urtica tibetica, Urtica sicula,...    Urtica
# 2  [Koeleria dactylis, Festuca glomerata, Trachyp...  Dactylis
# 3  [Plantago lanceolata var. sphaerostachya, Plan...  Plantago
# 4  [Quercus longaeva, Quercus salicifolia, Quercu...   Quercus
#
#            family                                              links
# 0        Fagaceae  {'self': '/api/v1/species/quercus-rotundifolia...
# 1      Urticaceae  {'self': '/api/v1/species/urtica-dioica', 'pla...
# 2         Poaceae  {'self': '/api/v1/species/dactylis-glomerata',...
# 3  Plantaginaceae  {'self': '/api/v1/species/plantago-lanceolata'...
# 4        Fagaceae  {'self': '/api/v1/species/quercus-robur', 'pla...

# %% [markdown]
# ## Exercises for Later

# %% [markdown]
# 1. Add the number of synonyms as a new column called "num_syn".
# 2. Sort the DataFrame by number of synonyms in descending order.
# 3. Grab the Image URL of the plant that has the fourth-highest number of synonyms.
# 4. Paste it into your browser and take a look!

# %% [markdown]
# <details>
#     <summary>Answer here
#     </summary>
#
# ```python
# plants_df['num_syn'] = plants_df['synonyms'].map(len)
# sorted_ = plants_df.sort_values('num_syn', ascending=False)
# sorted_.loc[3, 'image_url']
# ```
# </details>

# %% [markdown]
# # Year

# %% [markdown]
# The year is an indication of when a valid name for the plant first appeared in print. Let's build a simple histogram of these years:

# %%
fig, ax = plt.subplots()

ax.hist(plants_df[plants_df['year'] > 0]['year'], color='darkgreen');

# %% [markdown]
# ## Exercise

# %% [markdown]
# How many plants have first been written about just in the last 20 years? Make a bar chart or pie chart that shows the distribution by family of these plants.

# %% [markdown]
# <details>
#     <summary>
#         One answer here
#     </summary>
#
# ```python
# recent = plants_df[plants_df['year'] >= 2001]
# fig, ax = plt.subplots(1, 2, figsize=(14, 6))
# ax[0].bar(recent['family_common_name'].value_counts().index,
#        recent['family_common_name'].value_counts(),
#       color='darkgreen')
# # Rotate x-axis labels for the first subplot
# ax[0].set_xticklabels(recent['family_common_name'].value_counts().index, rotation=45, ha='right')
#
# ax[1].pie(recent['family_common_name'].value_counts(),
#       labels=recent['family_common_name'].value_counts().index,
#       radius=1.2, labeldistance=0.4);
# ```
# </details>

# %%
def c(x):
    t= defaultdict(int)
    for i in x:
        if i.isalnum():
            i =i.lower()
            t[i] += 1
    return t

# %%
c("manhaTtan?323")
# Out:
# defaultdict(int, {'m': 1, 'a': 3, 'n': 2, 'h': 1, 't': 2, '3': 2, '2': 1})

# %%
plant_dict = defaultdict(int)
for plant in plants:
    plant_dict[plant['family_common_name']] += 1

# %%
def char_count_dict(dict_string):
    counts = {}
    for letter in dict_string:
        if letter in counts:
            counts[letter] += 1
        else:
            counts[letter] = 1
    return counts

foo = char_count_dict("testing 1, 2   3")
print(foo)
# Out:
# {'t': 2, 'e': 1, 's': 1, 'i': 1, 'n': 1, 'g': 1, ' ': 5, '1': 1, ',': 1, '2': 1, '3': 1}

# %%
def count_freq(s):
    word_counts = defaultdict(int)
    char_list = list(s)
    print(char_list)
for char in char_list:
    word_counts[char]+=1
    print(word_counts)

count_freq("code")
count_freq("manhattan")
count_freq("SHOOP da WHOOP!!!")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[61], line 5
#       3     char_list = list(s)
#       4     print(char_list)
# ----> 5 for char in char_list:
#       6     word_counts[char]+=1
#       7     print(word_counts)
#
# NameError: name 'char_list' is not defined

# %%
def freq_count (string):
    letter_dict = {}
    string = string.lower()
    for letter in string:
        if letter in letter_dict:
            letter_dict[letter] +=1
        else:
            letter_dict[letter] =1
    return letter_dict
print(freq_count("Hello There"))
# Out:
# {'h': 2, 'e': 3, 'l': 2, 'o': 1, ' ': 1, 't': 1, 'r': 1}
